# %% [markdown]
# # GPSIR defined with classes

# %%
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Definition of Some Random Variables

# %%
def Bernoulli(p):
    """Simulates a random variable with Bernoulli distribution
    with parameter p.
        
    Parameters
    ----------
    p : float
        The parameter of the Bernoulli distribution.

    Returns
    -------
    int
        0 or 1 depending of the result of the experiment
        
    """
    u = random.random()
    if u < p:
        return 1
    else:
        return 0

def Geometric(p):
    """Simulates a random variable with Gemoetric distribution
    with probability of success p.
        
    Parameters
    ----------
    p : float
        The probability of success of a Bernoulli trial.

    Returns
    -------
    L : int
        The number L of Bernoulli trials needed to get one success.
        
    """
    L = 0
    aux = 0
    while aux == 0:
        if Bernoulli(p) == 1:
            aux = 1
        L += 1
    return L

def Constant(c):
    """Simulates a random variable, X, with constant distribution.
        
    Parameters
    ----------
    c : float
        The constant such that P(X = c) = 1.

    Returns
    -------
    c : float
        The constant such that P(X = c) = 1.
        
    """
    return c

def Uniform(limits):
    """Simulates a random variable with Uniform distribution
    over the interval [limits[0],limits[1]].
        
    Parameters
    ----------
    limits : list
        List with the lower bownd of the interval where the random
        variable is defined as first item and the upper bownd
        as second item.

    Returns
    -------
    float
        A number between [limits[0],limits[1]].
    """
    return limits[0] + (limits[1]-limits[0])*random.random()

# %% [markdown]
# ## Definition of the Class Person

# %%
class Person(object):
    """
    A class used to represent an individual participating in the dynamics of the epidemy 

    ...

    Attributes
    ----------
    contacts: dict
        An empty dictionary in which the individual's contacts are recorded 
        with the contact time as the key and a list of the individuals with 
        whom there was contact as the value.
        
    infections: dict
        An empty dictionary in which the individual's contagions are recorded 
        with the contagions time as the key and thw number of  individuals that
        where infected by the individual.
    
    tau : int
        The number of days that the individual will be infected
        (default 0).
    
    index : int
        The index with which the person is identified.
    
    status : dict
        A dictionary in which the individual's status at each time is recorded 
        with the time as the key and the population to which it belongs.
    
    age : int
        The age of the individual.
    
    comorbidities : list
        A list with the comorbidities of the individual 
        (default an empty list []).

    Methods
    -------
    set_tau():
        Sets the number of days that the infection will last depending
        on the comorbidities of the individual.
    
    set_status(t, s):
        Adds the status, s, of the individual at time, t, to the dictionary
        estatus.
        
    set_contact(t, person):
        It adds a contact with a person at the time t to the dictionary of 
        contacts.
        
    get_contacts():
        Prints the contacts of the individual at each time showing the time of
        the contact and a tuple containing the index of the person with whom 
        there was contact and the population to which it belongs.
    """
    
    def __init__(self, index, status, age, comorbidities = []):
        """
        Parameters
        ----------
        index : int
            The index with which the person is identified.
        
        status : dict
            A dictionary in which the individual's status at each time is recorded 
            with the time as the key and the population to which it belongs.
    
        age : int
            The age of the individual.
    
        comorbidities : list
            A list with the comorbidities of the individual 
            (default an empty list []).
        """
        
        self.contacts = {}
        self.infections = {}
        self.tau = 0
        self.index = index
        self.status = status
        self.age = age
        self.comorbidities = comorbidities
        
    def set_tau(self, distribution, parameter):
        """Sets the number of days that the infection will last depending
        on the comorbidities of the individual.
        
        Parameters
        ----------
        distribution : function
            probability distribution of the length of the infectious state for an
            individual (tau).
        parameter : float
            parameter of the probability distribution of the length of the infectious 
            state for an individual (tau).
        """
        
        self.tau = distribution(parameter)

    def set_status(self, t, s):
        """Sets the status, s, of the individual at time, t, to the dictionary
        estatus.
        
        Parameters
        ----------
        t : int
            The time for which the status will be seted.
        s : str
            The population to which it the individual belongs at time t
            (S = susceptible, I = infected, R = removed).
        """
        
        self.status[t] = s

    def set_contact(self, t, person):
        """It adds a contact with a person at the time t to the dictionary of 
        contacts.
        
        This method receives as parameters the time in which the contact was made 
        and the person with whom it was made. If there has not been a contact in 
        that time, it creates a new time key and assigns it a list with the person 
        with whom there was contact. In case there was already a contact at that time, 
        the person is added to the contacts list.
        
        Parameters
        ----------
        t : int
            The time in which the contact happened.
        person : Person
            The individual with whom there was contact.
        """

        if t in self.contacts:
            self.contacts[t].append(person)
        else:
            self.contacts[t] = [person]
            
    def add_infection(self, t):
        """
        
        Parameters
        ----------
        t : int
            The time in which the ifection happened.
        """

        if t in self.infections:
            self.infections[t] += 1
        else:
            self.infections[t] = 1

    def get_contacts(self):
        """Prints the contacts of the individual at each time showing the time of
        the contact and a tuple containing the index of the person with whom 
        there was contact and the population to which it belongs."""
        
        print("\nContacts of person {}:".format(self.index))
        for t in self.contacts:
            s = str(t)+ " :"
            for c in self.contacts[t]:
                s += " ({},{})".format(c.index,c.status[t])
            print(s)

    def __eq__(self, other):
        """
        We overwrite the method __eq__ in orther to give sense to the boolean
        operator == in the class Persona. In orther to overwirte this method
        we recibe as parameters the object itself and other object to compare.
        The new coparison criterion is the index.
        """
        return (self.index == other.index)

# %% [markdown]
# ## 1.1 Simple Model

# %%
def GPSIR_1(S12, I10, I20, R0, T, alpha, beta1, beta2, tau_distribution = Geometric, 
          tau_parameter = 1/21, inoculation_distribution = Constant,
          inoculation_parameter = 1, inoculation_threshold = 1):
    """Simulates the dynamics of the epidemy
        
    Parameters
    ----------
    S12 : int
        Initial population of susceptible individuals.
    
    I10 : int
        Initial population of individuals infected with the 
        strain 1.
        
    I20 : int
        Initial population of individuals infected with the 
        strain 2.
    
    R0 : int
        Initial population of recovered individuals.
    
    T : int
        Number of days of the simulation.
    
    alpha: float
        Probability of formation of an edge.
    
    beta1: float
        Probability of contagion given infectious contagion of
        the strain 1.
        
    beta2: float
        Probability of contagion given infectious contagion of
        the strain 2.
    
    tau_distribution : function, optional
        Distribution of the number of days that the individual 
        will be infected (default is Gemoetric).
    
    tau_parameter: float, optional
        Parameter of the distribution of the number of days that
        the individual will be infected (default is 1/7).
        
    inoculation_distribution: function, optional
        Distribution of the viral load to which a susceptible 
        individual is exposed in an infectious contact
        (default is Constant).
        
    inoculation_parameter: float, optional
        Parameter of the distribution of the viral load to 
        which a susceptible is exposed in an infectious contact
        (default is 1).
    
    inoculation_threshold: float, optional
        Viral load threshold for contagion (default is 1).
    

    Returns
    -------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 
        
    """

    Population   = []

    # The susceptible are added to the population
    for i in range(1,S12+1):
        p = Person(i,{0:'S12'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    # The infected with strain 1 are added to the population
    for i in range(S12+1,S12+I10+1):
        p = Person(i,{0:'I1'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
        
    # The infected with strain 2 are added to the population
    for i in range(S12+I10+1,S12+I10+I20+1):
        p = Person(i,{0:'I2'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    
    # We iterate over the days of the simulation
    for t in range(1,T+1):
        
        random.shuffle(Population)
        # Iteration per day over each individual of the population
        for p1 in Population:

            # Iteration per individual over the rest of the population in 
            # orther to generate contats between individuals.
            for p2 in Population:
                if p1.status[t-1] == 'S12' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)

            # Here starts the modification of the populations S, I, and R.

            # Modifications over the Suceptible population
            if p1.status[t-1] == 'S12':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load_1 = 0
                    viral_load_2 = 0
                    
                    # for each contact we check if there was efective infection
                    temp = 0
                    
                    while temp < len(p1.contacts[t-1]) and p1.status[t-1] == 'S12':
                        
                        if p1.contacts[t-1][temp].status[t-1] == 'I1' and Bernoulli(beta1):
                            
                            viral_load_1 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I1')
                            p1.contacts[t-1][temp].add_infection(t)
                            break
                            
                        elif p1.contacts[t-1][temp].status[t-1] == 'I2' and Bernoulli(beta2):
                            
                            viral_load_2 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I2')
                            p1.contacts[t-1][temp].add_infection(t)
                            break
                        
                        temp += 1
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    if (viral_load_1 + viral_load_2 == 0):
                        p1.set_status(t,'S12')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S12')

            # Modifications over the Infected population
            elif p1.status[t-1] == 'I1':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I1')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R')
                    
            elif p1.status[t-1] == 'I2':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I2')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R')

            # Modifications over the Removed population
            else:
                p1.set_status(t,'R')
    
    return Population

# %% [markdown]
# ## Results

# %%
T = 200
Population_1 = GPSIR_1(1450, 45, 5, 0, T, alpha = 0.1, beta1 = 0.005, beta2 = 0.015)

# %% [markdown]
# ### Final Number of Susceptible, Infectous, and Removed Individuals

# %%
def final_populations_1(Population):
    """Counts de number of susceptible, infected, and recovered individuals at the
    end of the simulation.
        
    This function receives as parameter the list of the population after the simulation 
    has been run. It counts the number of susceptible, infected, and recovered individuals 
    at the end of the simulation and prints them.
        
    Parameters
    ----------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 

    """
    S12f = 0; I1f = 0; I2f = 0; Rf = 0;
    for person in Population:
        if person.status[T] == 'S12':
            S12f += 1
        elif person.status[T] == 'I1':
            I1f += 1
        elif person.status[T] == 'I2':
            I2f += 1
        else:
            Rf += 1
    print("Susceptible: {}\nInfectious 1: {}\nInfectious 2: {}\nRemoved: {}".format(S12f,I1f,I2f,Rf))
    
final_populations_1(Population_1)
# Out:
# Susceptible: 0
# Infectious 1: 0
# Infectious 2: 0
# Removed: 1500

# %% [markdown]
# ### Dynamics for Each Individual

# %%
#for person in Population_1:
#    print("\nDynamics for the individual {}:".format(person.index))
#    print(person.status)

# %% [markdown]
# ### Contacts for One Individual

# %%
#Population_1[336].get_contacts()

# %% [markdown]
# ### Infections Generated by each individual indexed by time

# %%
for person in Population_1:
    if len(person.infections) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(person.infections)
# Out:
# Infections generated by person 850:
# {5: 1, 6: 1}
#
# Infections generated by person 1231:
# {4: 2}
#
# Infections generated by person 200:
# {5: 1, 6: 1, 7: 1}
#
# Infections generated by person 586:
# {5: 1}
#
# Infections generated by person 1249:
# {4: 2}
#
# Infections generated by person 73:
# {5: 1}
#
# Infections generated by person 235:
# {5: 1, 6: 1}
#
# Infections generated by person 1089:
# {6: 1}
#
# Infections generated by person 1486:
# {1: 2, 3: 2, 4: 1}
#
# Infections generated by person 146:
# {5: 1, 6: 1}
#
# Infections generated by person 694:
# {5: 2}
#
# Infections generated by person 1052:
# {4: 5, 7: 1}
#
# Infections generated by person 796:
# {5: 1}
#
# Infections generated by person 1340:
# {4: 2}
#
# Infections generated by person 886:
# {6: 1}
#
# Infections generated by person 88:
# {3: 3, 4: 2}
#
# Infections generated by person 838:
# {6: 1}
#
# Infections generated by person 1465:
# {1: 1}
#
# Infections generated by person 1315:
# {5: 1}
#
# Infections generated by person 711:
# {5: 1}
#
# Infections generated by person 1333:
# {6: 1}
#
# Infections generated by person 9:
# {6: 1}
#
# Infections generated by person 659:
# {5: 1}
#
# Infections generated by person 502:
# {3: 1, 4: 1}
#
# Infections generated by person 1473:
# {1: 2}
#
# Infections generated by person 207:
# {4: 1}
#
# Infections generated by person 1199:
# {5: 1}
#
# Infections generated by person 1362:
# {6: 2}
#
# Infections generated by person 947:
# {3: 3, 4: 2}
#
# Infections generated by person 309:
# {7: 1}
#
# Infections generated by person 8:
# {5: 2}
#
# Infections generated by person 1295:
# {6: 2}
#
# Infections generated by person 1394:
# {4: 2}
#
# Infections generated by person 955:
# {4: 1}
#
# Infections generated by person 1101:
# {3: 1}
#
# Infections generated by person 662:
# {2: 1, 5: 1}
#
# Infections generated by person 562:
# {3: 1, 4: 1}
#
# Infections generated by person 866:
# {3: 2, 4: 3}
#
# Infections generated by person 535:
# {3: 2, 5: 1}
#
# Infections generated by person 806:
# {4: 1, 5: 1}
#
# Infections generated by person 1470:
# {1: 2, 2: 2, 4: 1}
#
# Infections generated by person 674:
# {6: 1}
#
# Infections generated by person 1276:
# {3: 2, 4: 1, 5: 3}
#
# Infections generated by person 1056:
# {4: 1, 5: 1}
#
# Infections generated by person 397:
# {6: 1}
#
# Infections generated by person 266:
# {5: 1, 6: 1}
#
# Infections generated by person 1390:
# {4: 1, 5: 1}
#
# Infections generated by person 1462:
# {2: 1, 3: 1}
#
# Infections generated by person 456:
# {4: 1, 6: 1}
#
# Infections generated by person 395:
# {3: 2, 4: 1}
#
# Infections generated by person 1094:
# {4: 1}
#
# Infections generated by person 357:
# {8: 1}
#
# Infections generated by person 57:
# {5: 1}
#
# Infections generated by person 187:
# {3: 2, 4: 1}
#
# Infections generated by person 1454:
# {1: 3, 2: 1, 3: 1, 4: 1}
#
# Infections generated by person 240:
# {4: 2}
#
# Infections generated by person 504:
# {4: 2}
#
# Infections generated by person 353:
# {4: 1}
#
# Infections generated by person 818:
# {5: 2}
#
# Infections generated by person 510:
# {4: 3}
#
# Infections generated by person 158:
# {5: 1}
#
# Infections generated by person 915:
# {6: 1}
#
# Infections generated by person 865:
# {6: 1}
#
# Infections generated by person 358:
# {4: 1, 5: 1}
#
# Infections generated by person 51:
# {5: 1}
#
# Infections generated by person 1257:
# {3: 2, 5: 2}
#
# Infections generated by person 31:
# {4: 1}
#
# Infections generated by person 731:
# {6: 1}
#
# Infections generated by person 167:
# {5: 1}
#
# Infections generated by person 982:
# {2: 3, 3: 2, 4: 1, 5: 1, 6: 1}
#
# Infections generated by person 121:
# {6: 1}
#
# Infections generated by person 169:
# {5: 3}
#
# Infections generated by person 837:
# {5: 1}
#
# Infections generated by person 49:
# {5: 3}
#
# Infections generated by person 984:
# {5: 2}
#
# Infections generated by person 1033:
# {5: 1}
#
# Infections generated by person 660:
# {5: 1}
#
# Infections generated by person 959:
# {2: 2, 3: 2, 4: 1}
#
# Infections generated by person 596:
# {4: 4, 5: 2}
#
# Infections generated by person 953:
# {5: 1}
#
# Infections generated by person 846:
# {5: 2}
#
# Infections generated by person 1348:
# {4: 2}
#
# Infections generated by person 1463:
# {3: 2}
#
# Infections generated by person 1319:
# {4: 2}
#
# Infections generated by person 957:
# {4: 2, 6: 2}
#
# Infections generated by person 1201:
# {7: 1}
#
# Infections generated by person 853:
# {3: 1, 4: 2}
#
# Infections generated by person 490:
# {5: 1}
#
# Infections generated by person 20:
# {5: 2}
#
# Infections generated by person 645:
# {8: 1}
#
# Infections generated by person 184:
# {2: 2, 3: 1, 4: 4}
#
# Infections generated by person 1481:
# {1: 1, 3: 1, 4: 1}
#
# Infections generated by person 275:
# {5: 2}
#
# Infections generated by person 831:
# {5: 1}
#
# Infections generated by person 280:
# {4: 3}
#
# Infections generated by person 636:
# {5: 3, 6: 1}
#
# Infections generated by person 1379:
# {5: 2}
#
# Infections generated by person 1267:
# {4: 3}
#
# Infections generated by person 829:
# {7: 1}
#
# Infections generated by person 283:
# {5: 1}
#
# Infections generated by person 1494:
# {1: 3, 2: 1, 3: 1}
#
# Infections generated by person 952:
# {5: 1, 6: 1}
#
# Infections generated by person 1142:
# {5: 1}
#
# Infections generated by person 912:
# {4: 2}
#
# Infections generated by person 864:
# {2: 4, 3: 1, 4: 1, 5: 1}
#
# Infections generated by person 1193:
# {5: 2}
#
# Infections generated by person 1070:
# {4: 3}
#
# Infections generated by person 1015:
# {5: 1}
#
# Infections generated by person 116:
# {3: 1}
#
# Infections generated by person 1181:
# {5: 2}
#
# Infections generated by person 465:
# {3: 1, 4: 1}
#
# Infections generated by person 960:
# {6: 1}
#
# Infections generated by person 667:
# {3: 1, 4: 1, 5: 1}
#
# Infections generated by person 185:
# {4: 3, 5: 1}
#
# Infections generated by person 231:
# {6: 1}
#
# Infections generated by person 1075:
# {7: 1}
#
# Infections generated by person 1127:
# {5: 2, 6: 1}
#
# Infections generated by person 1162:
# {4: 1, 5: 4}
#
# Infections generated by person 1217:
# {3: 3, 4: 1, 5: 1}
#
# Infections generated by person 505:
# {4: 1, 5: 2}
#
# Infections generated by person 1263:
# {4: 1, 5: 1}
#
# Infections generated by person 741:
# {5: 2}
#
# Infections generated by person 129:
# {4: 2, 6: 1}
#
# Infections generated by person 497:
# {4: 1}
#
# Infections generated by person 480:
# {5: 1}
#
# Infections generated by person 981:
# {2: 1, 3: 2, 4: 1}
#
# Infections generated by person 334:
# {5: 1}
#
# Infections generated by person 920:
# {4: 2, 5: 2}
#
# Infections generated by person 460:
# {5: 1}
#
# Infections generated by person 878:
# {5: 1}
#
# Infections generated by person 316:
# {5: 2}
#
# Infections generated by person 401:
# {5: 1}
#
# Infections generated by person 123:
# {3: 1, 4: 2, 5: 1}
#
# Infections generated by person 1391:
# {2: 3, 3: 2, 4: 2}
#
# Infections generated by person 527:
# {5: 1}
#
# Infections generated by person 841:
# {4: 1, 5: 4, 6: 1}
#
# Infections generated by person 1400:
# {4: 1, 5: 1}
#
# Infections generated by person 1120:
# {6: 1}
#
# Infections generated by person 365:
# {5: 1}
#
# Infections generated by person 789:
# {5: 1}
#
# Infections generated by person 651:
# {6: 1}
#
# Infections generated by person 1096:
# {4: 1}
#
# Infections generated by person 5:
# {3: 2, 4: 2}
#
# Infections generated by person 1458:
# {1: 1}
#
# Infections generated by person 1253:
# {4: 1}
#
# Infections generated by person 327:
# {2: 2, 3: 1, 4: 2}
#
# Infections generated by person 1083:
# {5: 1}
#
# Infections generated by person 693:
# {7: 1}
#
# Infections generated by person 1382:
# {3: 1, 4: 1}
#
# Infections generated by person 282:
# {4: 1}
#
# Infections generated by person 476:
# {4: 1}
#
# Infections generated by person 393:
# {6: 1}
#
# Infections generated by person 1173:
# {5: 1}
#
# Infections generated by person 518:
# {6: 1}
#
# Infections generated by person 308:
# {4: 1, 5: 1}
#
# Infections generated by person 706:
# {4: 1, 6: 1}
#
# Infections generated by person 823:
# {3: 2, 4: 2, 5: 1}
#
# Infections generated by person 371:
# {5: 2}
#
# Infections generated by person 1031:
# {4: 1, 5: 2}
#
# Infections generated by person 320:
# {3: 1}
#
# Infections generated by person 1331:
# {4: 2}
#
# Infections generated by person 855:
# {4: 1, 5: 1}
#
# Infections generated by person 1018:
# {4: 3}
#
# Infections generated by person 988:
# {5: 1}
#
# Infections generated by person 1378:
# {4: 1}
#
# Infections generated by person 884:
# {5: 1}
#
# Infections generated by person 221:
# {3: 5, 5: 1}
#
# Infections generated by person 1280:
# {4: 3}
#
# Infections generated by person 477:
# {4: 2, 6: 1}
#
# Infections generated by person 848:
# {4: 4, 5: 1}
#
# Infections generated by person 170:
# {5: 1}
#
# Infections generated by person 1492:
# {1: 3, 2: 1, 3: 1}
#
# Infections generated by person 1155:
# {4: 2, 5: 1, 6: 1}
#
# Infections generated by person 690:
# {4: 1}
#
# Infections generated by person 1022:
# {3: 5, 6: 1, 7: 1}
#
# Infections generated by person 227:
# {7: 1}
#
# Infections generated by person 588:
# {5: 1}
#
# Infections generated by person 1408:
# {6: 1}
#
# Infections generated by person 763:
# {2: 1, 4: 1}
#
# Infections generated by person 1172:
# {4: 2, 5: 1}
#
# Infections generated by person 800:
# {6: 1}
#
# Infections generated by person 311:
# {5: 1}
#
# Infections generated by person 196:
# {6: 1}
#
# Infections generated by person 322:
# {3: 1, 5: 1}
#
# Infections generated by person 429:
# {6: 1, 7: 1}
#
# Infections generated by person 1214:
# {9: 1}
#
# Infections generated by person 364:
# {6: 2}
#
# Infections generated by person 1099:
# {5: 1}
#
# Infections generated by person 208:
# {5: 1}
#
# Infections generated by person 640:
# {3: 2}
#
# Infections generated by person 692:
# {3: 3, 4: 1}
#
# Infections generated by person 720:
# {4: 1}
#
# Infections generated by person 1251:
# {6: 1}
#
# Infections generated by person 402:
# {5: 1}
#
# Infections generated by person 582:
# {4: 1}
#
# Infections generated by person 197:
# {5: 1, 6: 1}
#
# Infections generated by person 1395:
# {6: 2}
#
# Infections generated by person 44:
# {6: 1}
#
# Infections generated by person 1232:
# {4: 1}
#
# Infections generated by person 1296:
# {3: 1, 4: 3}
#
# Infections generated by person 394:
# {5: 2}
#
# Infections generated by person 220:
# {3: 1, 4: 1}
#
# Infections generated by person 186:
# {4: 1}
#
# Infections generated by person 1427:
# {5: 1}
#
# Infections generated by person 458:
# {6: 1}
#
# Infections generated by person 1168:
# {4: 2, 5: 4}
#
# Infections generated by person 1074:
# {3: 1, 5: 2}
#
# Infections generated by person 753:
# {4: 3}
#
# Infections generated by person 1457:
# {3: 1, 4: 1}
#
# Infections generated by person 567:
# {2: 1}
#
# Infections generated by person 946:
# {4: 1, 6: 1}
#
# Infections generated by person 784:
# {4: 2}
#
# Infections generated by person 747:
# {5: 2}
#
# Infections generated by person 653:
# {3: 1, 5: 1}
#
# Infections generated by person 1102:
# {4: 2, 5: 1}
#
# Infections generated by person 1262:
# {4: 1, 5: 1}
#
# Infections generated by person 1495:
# {3: 1}
#
# Infections generated by person 63:
# {5: 1}
#
# Infections generated by person 1237:
# {5: 1}
#
# Infections generated by person 641:
# {4: 1, 8: 1}
#
# Infections generated by person 849:
# {3: 2, 5: 1, 6: 1}
#
# Infections generated by person 1254:
# {3: 2, 4: 1}
#
# Infections generated by person 437:
# {5: 2}
#
# Infections generated by person 708:
# {5: 1}
#
# Infections generated by person 249:
# {3: 1}
#
# Infections generated by person 103:
# {6: 1}
#
# Infections generated by person 304:
# {4: 2}
#
# Infections generated by person 125:
# {3: 1}
#
# Infections generated by person 1466:
# {2: 1, 3: 1, 4: 1}
#
# Infections generated by person 214:
# {5: 1}
#
# Infections generated by person 668:
# {6: 1}
#
# Infections generated by person 69:
# {6: 1}
#
# Infections generated by person 1338:
# {5: 1, 6: 1}
#
# Infections generated by person 746:
# {4: 1}
#
# Infections generated by person 127:
# {5: 2}
#
# Infections generated by person 1076:
# {6: 1}
#
# Infections generated by person 515:
# {5: 1}
#
# Infections generated by person 1154:
# {6: 2}
#
# Infections generated by person 1417:
# {3: 1, 4: 1, 5: 1}
#
# Infections generated by person 1239:
# {2: 2, 4: 2, 5: 2}
#
# Infections generated by person 770:
# {5: 1, 6: 2}
#
# Infections generated by person 241:
# {4: 1, 5: 2}
#
# Infections generated by person 377:
# {4: 2, 6: 1}
#
# Infections generated by person 934:
# {5: 1}
#
# Infections generated by person 426:
# {4: 2}
#
# Infections generated by person 1235:
# {5: 1}
#
# Infections generated by person 1450:
# {6: 2}
#
# Infections generated by person 211:
# {5: 1}
#
# Infections generated by person 821:
# {5: 1}
#
# Infections generated by person 262:
# {5: 1}
#
# Infections generated by person 1445:
# {5: 1, 6: 2}
#
# Infections generated by person 1441:
# {6: 1}
#
# Infections generated by person 469:
# {6: 1}
#
# Infections generated by person 1149:
# {7: 1}
#
# Infections generated by person 882:
# {4: 2, 5: 1}
#
# Infections generated by person 898:
# {6: 1}
#
# Infections generated by person 1032:
# {7: 1}
#
# Infections generated by person 1138:
# {5: 2, 6: 1}
#
# Infections generated by person 728:
# {4: 2}
#
# Infections generated by person 350:
# {4: 1}
#
# Infections generated by person 1023:
# {4: 1, 6: 2}
#
# Infections generated by person 804:
# {5: 2}
#
# Infections generated by person 1091:
# {4: 1}
#
# Infections generated by person 37:
# {6: 1, 7: 1}
#
# Infections generated by person 1130:
# {6: 1}
#
# Infections generated by person 1270:
# {5: 1}
#
# Infections generated by person 99:
# {6: 1}
#
# Infections generated by person 1041:
# {7: 1}
#
# Infections generated by person 1478:
# {3: 1}
#
# Infections generated by person 1152:
# {4: 1, 6: 1}
#
# Infections generated by person 795:
# {6: 1}
#
# Infections generated by person 300:
# {4: 1}
#
# Infections generated by person 1255:
# {6: 1}
#
# Infections generated by person 828:
# {5: 2}
#
# Infections generated by person 1485:
# {2: 2}
#
# Infections generated by person 814:
# {4: 3}
#
# Infections generated by person 420:
# {7: 1}
#
# Infections generated by person 548:
# {2: 2, 3: 2, 5: 1}
#
# Infections generated by person 493:
# {4: 2}
#
# Infections generated by person 297:
# {4: 2}
#
# Infections generated by person 417:
# {5: 1}
#
# Infections generated by person 1325:
# {4: 1}
#
# Infections generated by person 1053:
# {5: 1}
#
# Infections generated by person 1196:
# {5: 2}
#
# Infections generated by person 1453:
# {2: 1, 3: 1, 4: 1}
#
# Infections generated by person 1456:
# {1: 1, 3: 2}
#
# Infections generated by person 145:
# {4: 1, 5: 2}
#
# Infections generated by person 1474:
# {2: 1, 4: 1, 7: 1}
#
# Infections generated by person 712:
# {6: 1}
#
# Infections generated by person 1209:
# {5: 1}
#
# Infections generated by person 128:
# {6: 1}
#
# Infections generated by person 560:
# {7: 1}
#
# Infections generated by person 976:
# {3: 5, 4: 3, 5: 1}
#
# Infections generated by person 958:
# {6: 1}
#
# Infections generated by person 1145:
# {5: 1}
#
# Infections generated by person 306:
# {4: 1, 6: 1}
#
# Infections generated by person 683:
# {6: 1}
#
# Infections generated by person 287:
# {4: 1}
#
# Infections generated by person 1129:
# {4: 1, 5: 1}
#
# Infections generated by person 1482:
# {1: 2}
#
# Infections generated by person 1289:
# {4: 1}
#
# Infections generated by person 713:
# {6: 1}
#
# Infections generated by person 82:
# {6: 1}
#
# Infections generated by person 1489:
# {2: 1}
#
# Infections generated by person 1072:
# {4: 1}
#
# Infections generated by person 1300:
# {7: 1}
#
# Infections generated by person 707:
# {5: 1}
#
# Infections generated by person 1443:
# {6: 1}
#
# Infections generated by person 836:
# {4: 2, 6: 1}
#
# Infections generated by person 1491:
# {3: 1, 4: 1, 5: 1}
#
# Infections generated by person 928:
# {5: 1}
#
# Infections generated by person 1113:
# {4: 1, 5: 1}
#
# Infections generated by person 1487:
# {1: 2, 2: 4, 4: 1, 5: 1}
#
# Infections generated by person 148:
# {4: 1}
#
# Infections generated by person 391:
# {4: 1, 5: 1}
#
# Infections generated by person 481:
# {6: 1}
#
# Infections generated by person 1176:
# {5: 1}
#
# Infections generated by person 111:
# {3: 3, 4: 2, 7: 1}
#
# Infections generated by person 38:
# {6: 1}
#
# Infections generated by person 25:
# {4: 1}
#
# Infections generated by person 617:
# {5: 1}
#
# Infections generated by person 974:
# {6: 1}
#
# Infections generated by person 1326:
# {4: 3, 5: 2}
#
# Infections generated by person 1224:
# {3: 1}
#
# Infections generated by person 703:
# {5: 1}
#
# Infections generated by person 676:
# {4: 1}
#
# Infections generated by person 1133:
# {3: 2, 4: 2, 6: 1, 7: 1}
#
# Infections generated by person 100:
# {3: 1}
#
# Infections generated by person 239:
# {4: 1, 5: 1, 6: 1}
#
# Infections generated by person 1418:
# {7: 1}
#
# Infections generated by person 455:
# {3: 1}
#
# Infections generated by person 501:
# {4: 4, 5: 2}
#
# Infections generated by person 771:
# {5: 1}
#
# Infections generated by person 1381:
# {3: 3, 4: 1}
#
# Infections generated by person 575:
# {3: 1}
#
# Infections generated by person 774:
# {5: 1}
#
# Infections generated by person 798:
# {3: 1, 4: 1, 5: 1, 6: 1}
#
# Infections generated by person 877:
# {4: 1, 5: 1}
#
# Infections generated by person 610:
# {5: 2}
#
# Infections generated by person 1244:
# {5: 2, 6: 1}
#
# Infections generated by person 524:
# {4: 1}
#
# Infections generated by person 893:
# {5: 1}
#
# Infections generated by person 833:
# {3: 1, 4: 1, 5: 1}
#
# Infections generated by person 969:
# {6: 1}
#
# Infections generated by person 944:
# {6: 1}
#
# Infections generated by person 1184:
# {5: 1}
#
# Infections generated by person 1030:
# {5: 1}
#
# Infections generated by person 1245:
# {4: 1}
#
# Infections generated by person 1472:
# {1: 2, 2: 1, 3: 2, 6: 1}
#
# Infections generated by person 384:
# {7: 1}
#
# Infections generated by person 1029:
# {6: 1}
#
# Infections generated by person 999:
# {5: 1}
#
# Infections generated by person 1288:
# {6: 1}
#
# Infections generated by person 619:
# {5: 1}
#
# Infections generated by person 590:
# {2: 1}
#
# Infections generated by person 791:
# {5: 3}
#
# Infections generated by person 321:
# {4: 2, 5: 2}
#
# Infections generated by person 840:
# {5: 2, 7: 1}
#
# Infections generated by person 1225:
# {6: 1}
#
# Infections generated by person 459:
# {4: 2}
#
# Infections generated by person 1291:
# {5: 1}
#
# Infections generated by person 1459:
# {2: 1, 3: 1}
#
# Infections generated by person 1207:
# {5: 2}
#
# Infections generated by person 376:
# {4: 3, 5: 1}
#
# Infections generated by person 932:
# {8: 1}
#
# Infections generated by person 748:
# {5: 1}
#
# Infections generated by person 914:
# {5: 2}
#
# Infections generated by person 98:
# {5: 1}
#
# Infections generated by person 7:
# {6: 1}
#
# Infections generated by person 1497:
# {1: 3, 2: 2, 3: 2, 4: 1, 5: 1}
#
# Infections generated by person 183:
# {5: 1}
#
# Infections generated by person 160:
# {6: 1}
#
# Infections generated by person 1012:
# {7: 1}
#
# Infections generated by person 438:
# {5: 1}
#
# Infections generated by person 1386:
# {4: 2, 5: 1}
#
# Infections generated by person 908:
# {5: 1}
#
# Infections generated by person 1278:
# {5: 2}
#
# Infections generated by person 644:
# {5: 1}
#
# Infections generated by person 1194:
# {3: 1, 4: 1, 6: 2}
#
# Infections generated by person 805:
# {4: 1}
#
# Infections generated by person 11:
# {3: 2, 4: 3, 5: 1, 6: 2}
#
# Infections generated by person 1444:
# {4: 1}
#
# Infections generated by person 1440:
# {6: 1}
#
# Infections generated by person 895:
# {6: 1}
#
# Infections generated by person 1086:
# {5: 2, 6: 1}
#
# Infections generated by person 1467:
# {4: 1}
#
# Infections generated by person 894:
# {6: 1}
#
# Infections generated by person 1158:
# {5: 1}
#
# Infections generated by person 87:
# {5: 1}
#
# Infections generated by person 1290:
# {6: 1}
#
# Infections generated by person 911:
# {4: 2, 5: 1}
#
# Infections generated by person 571:
# {8: 1}
#
# Infections generated by person 913:
# {5: 2}
#
# Infections generated by person 772:
# {3: 2}
#
# Infections generated by person 1493:
# {3: 1, 5: 1}
#
# Infections generated by person 790:
# {6: 1}
#
# Infections generated by person 1426:
# {3: 1, 5: 1}
#
# Infections generated by person 530:
# {4: 1}
#
# Infections generated by person 869:
# {5: 1}
#
# Infections generated by person 1117:
# {5: 1}
#
# Infections generated by person 569:
# {6: 2}
#
# Infections generated by person 811:
# {4: 1, 5: 1}
#
# Infections generated by person 1401:
# {3: 1, 4: 1}
#
# Infections generated by person 162:
# {4: 2, 6: 2, 7: 1}
#
# Infections generated by person 421:
# {6: 1}
#
# Infections generated by person 538:
# {5: 1}
#
# Infections generated by person 1256:
# {6: 1}
#
# Infections generated by person 436:
# {6: 1, 7: 1}
#
# Infections generated by person 246:
# {6: 1}
#
# Infections generated by person 28:
# {6: 1}
#
# Infections generated by person 1195:
# {3: 1}
#
# Infections generated by person 656:
# {5: 1, 6: 2}
#
# Infections generated by person 113:
# {5: 2, 6: 1}
#
# Infections generated by person 919:
# {6: 1}
#
# Infections generated by person 499:
# {4: 1}
#
# Infections generated by person 302:
# {5: 2}
#
# Infections generated by person 1354:
# {4: 1}
#
# Infections generated by person 1220:
# {7: 1}
#
# Infections generated by person 1469:
# {1: 1}
#
# Infections generated by person 1351:
# {4: 1, 5: 1}
#
# Infections generated by person 1037:
# {6: 1}
#
# Infections generated by person 367:
# {7: 1}
#
# Infections generated by person 223:
# {6: 1}
#
# Infections generated by person 1307:
# {7: 1}
#
# Infections generated by person 124:
# {4: 1, 5: 1, 6: 1}
#
# Infections generated by person 335:
# {7: 1}
#
# Infections generated by person 215:
# {4: 2, 5: 3}
#
# Infections generated by person 32:
# {4: 1, 5: 1}
#
# Infections generated by person 1311:
# {4: 2, 5: 1, 6: 1}
#
# Infections generated by person 626:
# {3: 2, 4: 3, 5: 1}
#
# Infections generated by person 573:
# {4: 2, 5: 1}
#
# Infections generated by person 1430:
# {6: 1}
#
# Infections generated by person 206:
# {4: 1, 5: 2}
#
# Infections generated by person 773:
# {2: 1, 3: 4, 4: 3, 6: 1}
#
# Infections generated by person 851:
# {2: 2, 3: 4, 4: 2, 5: 1}
#
# Infections generated by person 801:
# {4: 1}
#
# Infections generated by person 1141:
# {2: 1}
#
# Infections generated by person 224:
# {3: 3, 4: 1, 5: 1}
#
# Infections generated by person 1344:
# {10: 1}
#
# Infections generated by person 478:
# {3: 1}
#
# Infections generated by person 449:
# {3: 1, 6: 1}
#
# Infections generated by person 1292:
# {4: 1}
#
# Infections generated by person 858:
# {5: 2}
#
# Infections generated by person 1479:
# {1: 1, 2: 2, 3: 2, 4: 1, 5: 1, 6: 1}
#
# Infections generated by person 943:
# {4: 2, 5: 1}
#
# Infections generated by person 1412:
# {4: 1, 5: 2, 6: 1, 7: 1}
#
# Infections generated by person 192:
# {6: 3}
#
# Infections generated by person 424:
# {5: 2, 7: 1}
#
# Infections generated by person 906:
# {5: 2}
#
# Infections generated by person 140:
# {4: 1, 5: 5}
#
# Infections generated by person 1500:
# {1: 3, 2: 1, 3: 3}
#
# Infections generated by person 331:
# {3: 1, 5: 4}
#
# Infections generated by person 271:
# {4: 1, 5: 1}
#
# Infections generated by person 339:
# {6: 2}
#
# Infections generated by person 1132:
# {4: 1, 6: 1}
#
# Infections generated by person 802:
# {6: 1}
#
# Infections generated by person 781:
# {6: 1}
#
# Infections generated by person 1265:
# {6: 1, 7: 1}
#
# Infections generated by person 54:
# {6: 1}
#
# Infections generated by person 764:
# {3: 1, 4: 1, 5: 1}
#
# Infections generated by person 997:
# {4: 2}
#
# Infections generated by person 1182:
# {6: 1}
#
# Infections generated by person 453:
# {5: 1}
#
# Infections generated by person 65:
# {4: 2}
#
# Infections generated by person 551:
# {7: 1}
#
# Infections generated by person 250:
# {4: 3}
#
# Infections generated by person 10:
# {4: 1}
#
# Infections generated by person 566:
# {5: 2, 7: 1}
#
# Infections generated by person 587:
# {2: 5, 3: 2, 4: 2}
#
# Infections generated by person 1499:
# {1: 5, 2: 6, 3: 1, 4: 2}
#
# Infections generated by person 109:
# {5: 1}
#
# Infections generated by person 188:
# {2: 1, 6: 1}
#
# Infections generated by person 269:
# {3: 1, 4: 1}
#
# Infections generated by person 1451:
# {2: 1, 3: 2, 5: 1, 6: 1}
#
# Infections generated by person 760:
# {5: 2}
#
# Infections generated by person 577:
# {4: 1}
#
# Infections generated by person 47:
# {8: 1}
#
# Infections generated by person 825:
# {4: 2, 5: 2, 6: 1}
#
# Infections generated by person 1229:
# {4: 1, 6: 1}
#
# Infections generated by person 403:
# {5: 2}
#
# Infections generated by person 1285:
# {5: 2, 6: 1}
#
# Infections generated by person 1071:
# {7: 1}
#
# Infections generated by person 289:
# {5: 1}
#
# Infections generated by person 1287:
# {4: 2, 5: 1}
#
# Infections generated by person 253:
# {4: 2, 5: 1}
#
# Infections generated by person 1298:
# {5: 2}
#
# Infections generated by person 159:
# {6: 1}
#
# Infections generated by person 1357:
# {4: 2, 5: 1}
#
# Infections generated by person 233:
# {4: 2}
#
# Infections generated by person 1496:
# {1: 3, 2: 4, 3: 3, 4: 1, 5: 1}
#
# Infections generated by person 930:
# {7: 1}
#
# Infections generated by person 1468:
# {1: 1, 3: 1, 4: 4}
#
# Infections generated by person 76:
# {5: 1, 8: 1}
#
# Infections generated by person 17:
# {3: 1, 4: 4}
#
# Infections generated by person 1197:
# {4: 1}
#
# Infections generated by person 1490:
# {1: 1}
#
# Infections generated by person 1282:
# {4: 1}
#
# Infections generated by person 1483:
# {2: 1, 4: 1}
#
# Infections generated by person 161:
# {5: 1, 6: 1}
#
# Infections generated by person 552:
# {5: 1}
#
# Infections generated by person 601:
# {3: 1, 4: 4}
#
# Infections generated by person 198:
# {6: 1}
#
# Infections generated by person 1103:
# {5: 1}
#
# Infections generated by person 899:
# {4: 3}
#
# Infections generated by person 362:
# {5: 1, 6: 1}
#
# Infections generated by person 1321:
# {5: 1}
#
# Infections generated by person 479:
# {3: 3, 4: 4, 6: 1}
#
# Infections generated by person 164:
# {5: 2}
#
# Infections generated by person 1105:
# {4: 4}
#
# Infections generated by person 1322:
# {4: 1, 6: 1}
#
# Infections generated by person 1484:
# {2: 1}
#
# Infections generated by person 13:
# {5: 2}
#
# Infections generated by person 1192:
# {5: 2, 7: 1}
#
# Infections generated by person 1002:
# {2: 2, 3: 3, 4: 1, 5: 1}
#
# Infections generated by person 133:
# {5: 1}
#
# Infections generated by person 1345:
# {3: 4, 4: 1}
#
# Infections generated by person 71:
# {6: 2}
#
# Infections generated by person 267:
# {7: 1}
#
# Infections generated by person 1177:
# {3: 2, 4: 4, 5: 1}
#
# Infections generated by person 1051:
# {7: 1}
#
# Infections generated by person 579:
# {5: 1}
#
# Infections generated by person 1206:
# {6: 1}
#
# Infections generated by person 340:
# {5: 2}
#
# Infections generated by person 305:
# {6: 1}
#
# Infections generated by person 1234:
# {6: 1}
#
# Infections generated by person 1003:
# {5: 3}
#
# Infections generated by person 1475:
# {2: 1, 3: 2, 4: 1}
#
# Infections generated by person 204:
# {4: 1, 5: 1}
#
# Infections generated by person 673:
# {4: 3, 5: 1}
#
# Infections generated by person 117:
# {4: 4, 5: 1}
#
# Infections generated by person 396:
# {2: 1, 4: 1}
#
# Infections generated by person 743:
# {5: 1}
#
# Infections generated by person 1476:
# {2: 2, 3: 1, 6: 1}
#
# Infections generated by person 461:
# {5: 2}
#
# Infections generated by person 592:
# {2: 1, 3: 1, 4: 2}
#
# Infections generated by person 372:
# {3: 2, 4: 1, 5: 2}
#
# Infections generated by person 1365:
# {6: 2}
#
# Infections generated by person 1460:
# {4: 1}
#
# Infections generated by person 1208:
# {6: 1}
#
# Infections generated by person 1279:
# {3: 1, 4: 1}
#
# Infections generated by person 93:
# {3: 3, 4: 1}
#
# Infections generated by person 216:
# {4: 1, 5: 1}
#
# Infections generated by person 578:
# {7: 1}
#
# Infections generated by person 112:
# {4: 1, 5: 3}
#
# Infections generated by person 1477:
# {1: 1, 2: 1, 3: 1}
#
# Infections generated by person 1306:
# {5: 1}
#
# Infections generated by person 584:
# {4: 2}
#
# Infections generated by person 78:
# {5: 1}
#
# Infections generated by person 268:
# {5: 1}
#
# Infections generated by person 649:
# {5: 1}
#
# Infections generated by person 1448:
# {5: 1}
#
# Infections generated by person 1413:
# {4: 2, 6: 1}
#
# Infections generated by person 155:
# {5: 2, 6: 1}
#
# Infections generated by person 407:
# {6: 1}
#
# Infections generated by person 776:
# {4: 2}
#
# Infections generated by person 1183:
# {5: 2}
#
# Infections generated by person 1446:
# {6: 1}
#
# Infections generated by person 1314:
# {2: 2, 3: 3, 4: 1, 5: 3}
#
# Infections generated by person 1250:
# {6: 1}
#
# Infections generated by person 1368:
# {6: 1}
#
# Infections generated by person 1159:
# {5: 2}
#
# Infections generated by person 759:
# {3: 3, 5: 1}
#
# Infections generated by person 464:
# {5: 1}
#
# Infections generated by person 70:
# {5: 1, 6: 1}
#
# Infections generated by person 427:
# {5: 1}
#
# Infections generated by person 761:
# {5: 3}
#
# Infections generated by person 758:
# {5: 2, 6: 1}
#
# Infections generated by person 482:
# {5: 1}
#
# Infections generated by person 279:
# {4: 1, 5: 2}
#
# Infections generated by person 1005:
# {5: 1}
#
# Infections generated by person 219:
# {5: 1}
#
# Infections generated by person 19:
# {4: 1}
#
# Infections generated by person 631:
# {2: 2, 3: 3, 4: 1}
#
# Infections generated by person 803:
# {4: 3}
#
# Infections generated by person 545:
# {4: 2}
#
# Infections generated by person 520:
# {5: 4, 9: 1}
#
# Infections generated by person 217:
# {5: 1, 7: 1}
#
# Infections generated by person 1498:
# {1: 5, 2: 2, 3: 3, 4: 1, 5: 1}
#
# Infections generated by person 1104:
# {4: 1}
#
# Infections generated by person 1388:
# {3: 2, 4: 4}
#
# Infections generated by person 881:
# {3: 1, 5: 1}
#
# Infections generated by person 754:
# {3: 2, 4: 2}
#
# Infections generated by person 528:
# {3: 1, 4: 2}
#
# Infections generated by person 1036:
# {6: 1}
#
# Infections generated by person 494:
# {5: 1}
#
# Infections generated by person 1161:
# {7: 1}
#
# Infections generated by person 39:
# {5: 2}
#
# Infections generated by person 863:
# {4: 1}
#
# Infections generated by person 203:
# {4: 1, 5: 1}
#
# Infections generated by person 621:
# {5: 1}
#
# Infections generated by person 245:
# {6: 1}
#
# Infections generated by person 521:
# {6: 1}
#
# Infections generated by person 595:
# {5: 1}
#
# Infections generated by person 1488:
# {2: 1, 3: 1, 4: 1}
#
# Infections generated by person 807:
# {5: 1, 6: 2}
#
# Infections generated by person 257:
# {5: 1}
#
# Infections generated by person 360:
# {5: 3}
#
# Infections generated by person 336:
# {5: 1}
#
# Infections generated by person 1420:
# {5: 2}
#
# Infections generated by person 1128:
# {4: 2, 5: 1}
#
# Infections generated by person 1312:
# {3: 2, 6: 1, 7: 1}
#
# Infections generated by person 1461:
# {2: 1}
#
# Infections generated by person 374:
# {6: 1}
#
# Infections generated by person 348:
# {7: 1}
#
# Infections generated by person 727:
# {4: 1}
#
# Infections generated by person 885:
# {7: 1}
#
# Infections generated by person 26:
# {3: 2, 5: 1}
#
# Infections generated by person 328:
# {5: 1}
#
# Infections generated by person 564:
# {6: 1}
#
# Infections generated by person 1455:
# {1: 3, 2: 2, 3: 1, 4: 1}
#
# Infections generated by person 938:
# {5: 1, 6: 1}
#
# Infections generated by person 624:
# {5: 1}
#
# Infections generated by person 254:
# {6: 2}
#
# Infections generated by person 1385:
# {5: 1, 6: 1, 9: 1}
#
# Infections generated by person 1221:
# {5: 1}
#
# Infections generated by person 1054:
# {5: 2}
#
# Infections generated by person 136:
# {4: 1, 5: 1}
#
# Infections generated by person 1471:
# {1: 1}
#
# Infections generated by person 1009:
# {6: 1}
#
# Infections generated by person 970:
# {4: 1}
#
# Infections generated by person 50:
# {5: 2}
#
# Infections generated by person 702:
# {6: 1}
#
# Infections generated by person 1261:
# {4: 2, 6: 1}
#
# Infections generated by person 1387:
# {6: 2}
#
# Infections generated by person 1383:
# {4: 3, 5: 1}
#
# Infections generated by person 1356:
# {4: 1}
#
# Infections generated by person 168:
# {4: 1}
#
# Infections generated by person 1007:
# {4: 2, 5: 1, 6: 1}
#
# Infections generated by person 629:
# {5: 1}
#
# Infections generated by person 46:
# {6: 1}
#
# Infections generated by person 258:
# {5: 1}
#
# Infections generated by person 1248:
# {2: 1, 5: 1}
#
# Infections generated by person 375:
# {3: 7, 4: 2, 5: 2}
#
# Infections generated by person 780:
# {5: 1}
#
# Infections generated by person 318:
# {3: 1}
#
# Infections generated by person 42:
# {6: 1}
#
# Infections generated by person 312:
# {5: 1}
#
# Infections generated by person 923:
# {4: 1, 5: 1}
#
# Infections generated by person 242:
# {3: 2, 4: 1}
#
# Infections generated by person 229:
# {4: 3, 5: 1}
#
# Infections generated by person 399:
# {5: 1}
#
# Infections generated by person 716:
# {2: 4, 4: 1, 5: 2, 6: 1}
#
# Infections generated by person 472:
# {6: 1}
#
# Infections generated by person 35:
# {3: 6, 4: 1}
#
# Infections generated by person 213:
# {5: 3, 7: 1}
#
# Infections generated by person 270:
# {4: 1}
#
# Infections generated by person 597:
# {4: 2}
#
# Infections generated by person 1121:
# {5: 1}

# %% [markdown]
# ### Infections Generated by each individual

# %%
for person in Population_1:
    if len(person.infections) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(sum(person.infections.values()))
# Out:
# Infections generated by person 850:
# 2
#
# Infections generated by person 1231:
# 2
#
# Infections generated by person 200:
# 3
#
# Infections generated by person 586:
# 1
#
# Infections generated by person 1249:
# 2
#
# Infections generated by person 73:
# 1
#
# Infections generated by person 235:
# 2
#
# Infections generated by person 1089:
# 1
#
# Infections generated by person 1486:
# 5
#
# Infections generated by person 146:
# 2
#
# Infections generated by person 694:
# 2
#
# Infections generated by person 1052:
# 6
#
# Infections generated by person 796:
# 1
#
# Infections generated by person 1340:
# 2
#
# Infections generated by person 886:
# 1
#
# Infections generated by person 88:
# 5
#
# Infections generated by person 838:
# 1
#
# Infections generated by person 1465:
# 1
#
# Infections generated by person 1315:
# 1
#
# Infections generated by person 711:
# 1
#
# Infections generated by person 1333:
# 1
#
# Infections generated by person 9:
# 1
#
# Infections generated by person 659:
# 1
#
# Infections generated by person 502:
# 2
#
# Infections generated by person 1473:
# 2
#
# Infections generated by person 207:
# 1
#
# Infections generated by person 1199:
# 1
#
# Infections generated by person 1362:
# 2
#
# Infections generated by person 947:
# 5
#
# Infections generated by person 309:
# 1
#
# Infections generated by person 8:
# 2
#
# Infections generated by person 1295:
# 2
#
# Infections generated by person 1394:
# 2
#
# Infections generated by person 955:
# 1
#
# Infections generated by person 1101:
# 1
#
# Infections generated by person 662:
# 2
#
# Infections generated by person 562:
# 2
#
# Infections generated by person 866:
# 5
#
# Infections generated by person 535:
# 3
#
# Infections generated by person 806:
# 2
#
# Infections generated by person 1470:
# 5
#
# Infections generated by person 674:
# 1
#
# Infections generated by person 1276:
# 6
#
# Infections generated by person 1056:
# 2
#
# Infections generated by person 397:
# 1
#
# Infections generated by person 266:
# 2
#
# Infections generated by person 1390:
# 2
#
# Infections generated by person 1462:
# 2
#
# Infections generated by person 456:
# 2
#
# Infections generated by person 395:
# 3
#
# Infections generated by person 1094:
# 1
#
# Infections generated by person 357:
# 1
#
# Infections generated by person 57:
# 1
#
# Infections generated by person 187:
# 3
#
# Infections generated by person 1454:
# 6
#
# Infections generated by person 240:
# 2
#
# Infections generated by person 504:
# 2
#
# Infections generated by person 353:
# 1
#
# Infections generated by person 818:
# 2
#
# Infections generated by person 510:
# 3
#
# Infections generated by person 158:
# 1
#
# Infections generated by person 915:
# 1
#
# Infections generated by person 865:
# 1
#
# Infections generated by person 358:
# 2
#
# Infections generated by person 51:
# 1
#
# Infections generated by person 1257:
# 4
#
# Infections generated by person 31:
# 1
#
# Infections generated by person 731:
# 1
#
# Infections generated by person 167:
# 1
#
# Infections generated by person 982:
# 8
#
# Infections generated by person 121:
# 1
#
# Infections generated by person 169:
# 3
#
# Infections generated by person 837:
# 1
#
# Infections generated by person 49:
# 3
#
# Infections generated by person 984:
# 2
#
# Infections generated by person 1033:
# 1
#
# Infections generated by person 660:
# 1
#
# Infections generated by person 959:
# Infections generated by person 1388:
# 6
#
# Infections generated by person 881:
# 2
#
# Infections generated by person 754:
# 4
#
# Infections generated by person 528:
# 3
#
# Infections generated by person 1036:
# 1
#
# Infections generated by person 494:
# 1
#
# Infections generated by person 1161:
# 1
#
# Infections generated by person 39:
# 2
#
# Infections generated by person 863:
# 1
#
# Infections generated by person 203:
# 2
#
# Infections generated by person 621:
# 1
#
# Infections generated by person 245:
# 1
#
# Infections generated by person 521:
# 1
#
# Infections generated by person 595:
# 1
#
# Infections generated by person 1488:
# 3
#
# Infections generated by person 807:
# 3
#
# Infections generated by person 257:
# 1
#
# Infections generated by person 360:
# 3
#
# Infections generated by person 336:
# 1
#
# Infections generated by person 1420:
# 2
#
# Infections generated by person 1128:
# 3
#
# Infections generated by person 1312:
# 4
#
# Infections generated by person 1461:
# 1
#
# Infections generated by person 374:
# 1
#
# Infections generated by person 348:
# 1
#
# Infections generated by person 727:
# 1
#
# Infections generated by person 885:
# 1
#
# Infections generated by person 26:
# 3
#
# Infections generated by person 328:
# 1
#
# Infections generated by person 564:
# 1
#
# Infections generated by person 1455:
# 7
#
# Infections generated by person 938:
# 2
#
# Infections generated by person 624:
# 1
#
# Infections generated by person 254:
# 2
#
# Infections generated by person 1385:
# 3
#
# Infections generated by person 1221:
# 1
#
# Infections generated by person 1054:
# 2
#
# Infections generated by person 136:
# 2
#
# Infections generated by person 1471:
# 1
#
# Infections generated by person 1009:
# 1
#
# Infections generated by person 970:
# 1
#
# Infections generated by person 50:
# 2
#
# Infections generated by person 702:
# 1
#
# Infections generated by person 1261:
# 3
#
# Infections generated by person 1387:
# 2
#
# Infections generated by person 1383:
# 4
#
# Infections generated by person 1356:
# 1
#
# Infections generated by person 168:
# 1
#
# Infections generated by person 1007:
# 4
#
# Infections generated by person 629:
# 1
#
# Infections generated by person 46:
# 1
#
# Infections generated by person 258:
# 1
#
# Infections generated by person 1248:
# 2
#
# Infections generated by person 375:
# 11
#
# Infections generated by person 780:
# 1
#
# Infections generated by person 318:
# 1
#
# Infections generated by person 42:
# 1
#
# Infections generated by person 312:
# 1
#
# Infections generated by person 923:
# 2
#
# Infections generated by person 242:
# 3
#
# Infections generated by person 229:
# 4
#
# Infections generated by person 399:
# 1
#
# Infections generated by person 716:
# 8
#
# Infections generated by person 472:
# 1
#
# Infections generated by person 35:
# 7
#
# Infections generated by person 213:
# 4
#
# Infections generated by person 270:
# 1
#
# Infections generated by person 597:
# 2
#
# Infections generated by person 1121:
# 1

# %% [markdown]
# ### Plot of The Simulation

# %%
def Plot_Dynamics_11(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S12 = []; I1 = []; I2 = []; R = [];
    for t in range(T+1):
        S12t = 0; I1t = 0; I2t = 0; Rt = 0;
        for person in simulation:
            if person.status[t] == 'S12':
                S12t += 1
            elif person.status[t] == 'I1':
                I1t += 1
            elif person.status[t] == 'I2':
                I2t += 1
            else:
                Rt += 1
        S12.append(S12t)
        I1.append(I1t)
        I2.append(I2t)
        R.append(Rt)

    plt.plot(range(T+1), S12, 'b-', label = 'S12')
    plt.plot(range(T+1), I1, 'r-', label = 'I1')
    plt.plot(range(T+1), I2, 'g-', label = 'I2')
    plt.plot(range(T+1), R, 'k-', label = 'R')
    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()

# %%
Plot_Dynamics_11(Population_1, 100)

# %%
def Plot_Dynamics_12(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S = []; I = []; R = [];
    for t in range(T+1):
        St = 0; It = 0; Rt = 0;
        for person in simulation:
            if person.status[t] == 'S12':
                St += 1
            elif person.status[t] == 'I1' or person.status[t] == 'I2':
                It += 1
            else:
                Rt += 1
        S.append(St)
        I.append(It)
        R.append(Rt)

    plt.plot(range(T+1), S, 'b-', label = 'S')
    plt.plot(range(T+1), I, 'r-', label = 'I')
    plt.plot(range(T+1), R, 'k-', label = 'R')
    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()

# %%
Plot_Dynamics_12(Population_1, 100)

# %% [markdown]
# ## 1.2. An Even More Complex Model

# %%
def GPSIR_2(pop_init, T, alpha, beta1, beta2, tau_distribution = Geometric, 
          tau_parameter = 1/21, inoculation_distribution = Constant,
          inoculation_parameter = 1, inoculation_threshold = 1):
    """Simulates the dynamics of the epidemy
        
    Parameters
    ----------
    pop_init : tuple
        A tuple with the initial conditions for each population
        in the graphic probabilistic SIR for two strains
    
    T : int
        Number of days of the simulation.
    
    alpha: float
        Probability of formation of an edge.
    
    beta1: float
        Probability of contagion given infectious contagion of
        the strain 1.
        
    beta2: float
        Probability of contagion given infectious contagion of
        the strain 2.
    
    tau_distribution : function, optional
        Distribution of the number of days that the individual 
        will be infected (default is Gemoetric).
    
    tau_parameter: float, optional
        Parameter of the distribution of the number of days that
        the individual will be infected (default is 1/21).
        
    inoculation_distribution: function, optional
        Distribution of the viral load to which a susceptible 
        individual is exposed in an infectious contact
        (default is Constant).
        
    inoculation_parameter: float, optional
        Parameter of the distribution of the viral load to 
        which a susceptible is exposed in an infectious contact
        (default is 1).
    
    inoculation_threshold: float, optional
        Viral load threshold for contagion (default is 1).
    

    Returns
    -------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 
        
    """
    S120, I10, I20, R10, R10, S10, S20, I12, I21, R12 = pop_init
    
    Population = []

    # The susceptible are added to the population
    for i in range(1,S120+1):
        p = Person(i,{0:'S12'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    # The infected with strain 1 are added to the population
    for i in range(S120+1,S120+I10+1):
        p = Person(i,{0:'I1'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
        
    # The infected with strain 2 are added to the population
    for i in range(S120+I10+1,S120+I10+I20+1):
        p = Person(i,{0:'I2'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    
    # We iterate over the days of the simulation
    for t in range(1,T+1):

        random.shuffle(Population)
        # Iteration per day over each individual of the population
        for p1 in Population:

            # Iteration per individual over the rest of the population in 
            # orther to generate contats between individuals.
            for p2 in Population:
                if p1.status[t-1] == 'S12' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)
                if p1.status[t-1] == 'S1' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)
                if p1.status[t-1] == 'S2' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)

            # Here starts the modification of the populations S, I, and R.

            # Modifications over the Suceptible population
            if p1.status[t-1] == 'S12':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load_1 = 0
                    viral_load_2 = 0
                    
                    # for each contact we check if there was efective infection
                    temp = 0
                    
                    while temp < len(p1.contacts[t-1]) and p1.status[t-1] == 'S12':
                        
                        if p1.contacts[t-1][temp].status[t-1] == 'I1' and Bernoulli(beta1):
                            viral_load_1 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I1')
                            p1.contacts[t-1][temp].add_infection(t)
                            break
                            
                        if p1.contacts[t-1][temp].status[t-1] == 'I2' and Bernoulli(beta2):
                            viral_load_2 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I2')
                            p1.contacts[t-1][temp].add_infection(t)
                            break
                        
                        temp += 1
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    if (viral_load_1 + viral_load_2 == 0):
                        p1.set_status(t,'S12')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S12')

            # Modifications over the Infected population
            elif p1.status[t-1] == 'I1':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I1')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R1')
                    
            elif p1.status[t-1] == 'I2':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I2')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R2')
                    
            elif p1.status[t-1] == 'R1':
                
                # Case in which the days of infection aren´t over
                if Bernoulli(1):
                    p1.set_status(t,'S2')
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R1')
                    
            elif p1.status[t-1] == 'R2':
                
                # Case in which the days of infection aren´t over
                if Bernoulli(1):
                    p1.set_status(t,'S1')
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R2')
            
            elif p1.status[t-1] == 'S2':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load = 0
                    
                    # for each contact we check if there was efective infection
                    for contact in p1.contacts[t-1]:
                        if (contact.status[t-1] == 'I2' or contact.status[t-1] == 'I12') and Bernoulli(beta2):
                            viral_load += inoculation_distribution(inoculation_parameter)
                            contact.add_infection(t)
                            break
                    
                    # Case in which the viral load surpassed the inoculation threshold
                    if viral_load >= inoculation_threshold:
                        p1.set_status(t,'I12')
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    else:
                        p1.set_status(t,'S2')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S2')
                    
            elif p1.status[t-1] == 'S1':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load = 0
                    
                    # for each contact we check if there was efective infection
                    for contact in p1.contacts[t-1]:
                        if (contact.status[t-1] == 'I1' or contact.status[t-1] == 'I21') and Bernoulli(beta1):
                            viral_load += inoculation_distribution(inoculation_parameter)
                            contact.add_infection(t)
                            break
                    
                    # Case in which the viral load surpassed the inoculation threshold
                    if viral_load >= inoculation_threshold:
                        p1.set_status(t,'I21')
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    else:
                        p1.set_status(t,'S1')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S1')
                    
            elif p1.status[t-1] == 'I12':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I12')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R12')
                    
            elif p1.status[t-1] == 'I21':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I21')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R12')

            # Modifications over the Removed population
            else:
                p1.set_status(t,'R12')
    
    return Population

# %% [markdown]
# ## Results

# %%
T = 200
P_init = (1450, 45, 5, 0, 0, 0, 0, 0, 0, 0)
Population_2 = GPSIR_2(P_init, T, alpha = 0.1, beta1 = 0.005, beta2 = 0.015)

# %% [markdown]
# ### Infections indexed by time

# %%
for person in Population_2:
    if len(person.infections) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(person.infections)
# Out:
# Infections generated by person 1369:
# {4: 1, 6: 1}
#
# Infections generated by person 1120:
# {6: 1}
#
# Infections generated by person 936:
# {15: 1, 17: 1, 19: 1}
#
# Infections generated by person 734:
# {17: 1, 25: 1, 27: 1, 35: 1, 44: 1, 57: 1, 72: 1, 73: 1}
#
# Infections generated by person 62:
# {5: 1, 88: 1, 97: 1}
#
# Infections generated by person 1016:
# {30: 1, 36: 1}
#
# Infections generated by person 1093:
# {5: 1, 6: 1}
#
# Infections generated by person 340:
# {20: 1}
#
# Infections generated by person 362:
# {31: 1}
#
# Infections generated by person 45:
# {7: 1}
#
# Infections generated by person 310:
# {6: 1}
#
# Infections generated by person 1453:
# {3: 1, 12: 1, 29: 1}
#
# Infections generated by person 191:
# {4: 1}
#
# Infections generated by person 66:
# {5: 1, 13: 1}
#
# Infections generated by person 53:
# {6: 1, 17: 1}
#
# Infections generated by person 1136:
# {4: 1, 5: 1, 6: 1}
#
# Infections generated by person 225:
# {24: 1}
#
# Infections generated by person 238:
# {6: 2}
#
# Infections generated by person 439:
# {5: 2, 21: 1}
#
# Infections generated by person 274:
# {5: 1, 6: 1}
#
# Infections generated by person 657:
# {6: 2, 19: 1}
#
# Infections generated by person 1432:
# {4: 1, 5: 2, 7: 1}
#
# Infections generated by person 258:
# {4: 1, 10: 1}
#
# Infections generated by person 1314:
# {3: 2, 4: 1, 5: 1}
#
# Infections generated by person 1050:
# {5: 2}
#
# Infections generated by person 646:
# {3: 1, 13: 1, 24: 1}
#
# Infections generated by person 104:
# {5: 1, 16: 1}
#
# Infections generated by person 417:
# {6: 2, 7: 1, 8: 1}
#
# Infections generated by person 124:
# {2: 1, 3: 1, 20: 1, 23: 1}
#
# Infections generated by person 642:
# {21: 1, 22: 2}
#
# Infections generated by person 1476:
# {1: 1, 2: 1, 3: 2, 4: 1}
#
# Infections generated by person 840:
# {3: 2, 5: 1}
#
# Infections generated by person 797:
# {6: 1}
#
# Infections generated by person 94:
# {11: 1}
#
# Infections generated by person 1323:
# {6: 1}
#
# Infections generated by person 759:
# {9: 1, 36: 1}
#
# Infections generated by person 1271:
# {5: 1, 6: 1}
#
# Infections generated by person 403:
# {6: 1}
#
# Infections generated by person 750:
# {5: 1, 12: 1, 25: 1, 43: 2}
#
# Infections generated by person 1132:
# {23: 1}
#
# Infections generated by person 1437:
# {4: 1, 5: 1, 7: 1, 14: 1, 62: 1}
#
# Infections generated by person 974:
# {3: 3, 4: 1, 5: 1, 6: 3}
#
# Infections generated by person 732:
# {68: 1}
#
# Infections generated by person 546:
# {13: 1}
#
# Infections generated by person 1101:
# {8: 1, 10: 1}
#
# Infections generated by person 1004:
# {48: 1, 72: 1, 88: 1, 111: 1, 115: 1, 121: 1}
#
# Infections generated by person 413:
# {4: 2}
#
# Infections generated by person 932:
# {5: 1, 21: 1, 25: 1}
#
# Infections generated by person 745:
# {7: 1, 12: 1, 20: 1, 33: 1, 68: 1, 70: 1, 74: 1, 85: 1, 87: 1, 99: 2, 109: 1, 110: 1, 119: 2}
#
# Infections generated by person 370:
# {3: 1, 4: 3, 6: 1}
#
# Infections generated by person 1189:
# {4: 3, 6: 1, 7: 1}
#
# Infections generated by person 1159:
# {5: 3, 6: 2, 8: 1}
#
# Infections generated by person 204:
# {14: 1, 19: 1}
#
# Infections generated by person 709:
# {5: 1}
#
# Infections generated by person 385:
# {6: 2, 32: 1, 39: 1}
#
# Infections generated by person 1072:
# {5: 1, 6: 2}
#
# Infections generated by person 70:
# {23: 1, 24: 1}
#
# Infections generated by person 955:
# {6: 2}
#
# Infections generated by person 1184:
# {3: 1, 4: 1, 6: 2, 15: 1, 31: 1}
#
# Infections generated by person 1029:
# {13: 1}
#
# Infections generated by person 302:
# {30: 1}
#
# Infections generated by person 1356:
# {11: 1}
#
# Infections generated by person 28:
# {3: 4, 5: 1}
#
# Infections generated by person 953:
# {8: 3, 20: 1, 22: 2}
#
# Infections generated by person 242:
# {6: 1}
#
# Infections generated by person 144:
# {16: 1, 17: 1}
#
# Infections generated by person 916:
# {9: 1}
#
# Infections generated by person 1059:
# {18: 1}
#
# Infections generated by person 762:
# {7: 1, 19: 1, 34: 1}
#
# Infections generated by person 126:
# {5: 3, 6: 1, 13: 1, 16: 1, 36: 1}
#
# Infections generated by person 500:
# {14: 1}
#
# Infections generated by person 1351:
# {6: 1, 12: 1, 26: 1}
#
# Infections generated by person 1343:
# {6: 3, 22: 1, 42: 1}
#
# Infections generated by person 1198:
# {11: 1}
#
# Infections generated by person 820:
# {10: 1}
#
# Infections generated by person 1228:
# {4: 1, 6: 1, 7: 1}
#
# Infections generated by person 860:
# {5: 1}
#
# Infections generated by person 1:
# {3: 1, 4: 5}
#
# Infections generated by person 858:
# {6: 1}
#
# Infections generated by person 897:
# {6: 1}
#
# Infections generated by person 1488:
# {1: 1, 3: 3, 4: 1}
#
# Infections generated by person 870:
# {2: 2, 3: 2, 4: 2}
#
# Infections generated by person 810:
# {11: 1, 15: 1, 22: 1, 45: 1}
#
# Infections generated by person 507:
# {4: 4, 5: 5}
#
# Infections generated by person 451:
# {7: 1}
#
# Infections generated by person 721:
# {7: 1, 30: 1}
#
# Infections generated by person 899:
# {24: 1, 34: 1, 52: 1}
#
# Infections generated by person 891:
# {6: 4, 27: 1}
#
# Infections generated by person 911:
# {7: 3, 10: 1, 42: 1, 49: 1, 90: 1}
#
# Infections generated by person 6:
# {2: 2, 3: 3}
#
# Infections generated by person 578:
# {7: 1}
#
# Infections generated by person 560:
# {6: 2, 22: 1, 30: 1}
#
# Infections generated by person 412:
# {18: 1, 20: 1, 29: 1}
#
# Infections generated by person 839:
# {4: 3, 5: 1, 12: 1, 13: 1}
#
# Infections generated by person 255:
# {6: 1, 12: 1}
#
# Infections generated by person 1155:
# {6: 1, 7: 1}
#
# Infections generated by person 1270:
# {15: 1, 16: 1, 23: 1, 40: 1}
#
# Infections generated by person 561:
# {4: 4, 5: 1}
#
# Infections generated by person 85:
# {5: 1, 6: 1}
#
# Infections generated by person 1283:
# {8: 1, 27: 1}
#
# Infections generated by person 1243:
# {4: 1, 5: 1, 51: 1, 70: 1, 79: 1, 81: 1, 84: 1, 85: 1}
#
# Infections generated by person 1338:
# {5: 1}
#
# Infections generated by person 1111:
# {4: 2}
#
# Infections generated by person 1326:
# {3: 2, 4: 2, 5: 1, 7: 1, 33: 1}
#
# Infections generated by person 51:
# {16: 1, 21: 1, 33: 2}
#
# Infections generated by person 408:
# {7: 1}
#
# Infections generated by person 90:
# {8: 1}
#
# Infections generated by person 1291:
# {12: 1}
#
# Infections generated by person 975:
# {28: 1}
#
# Infections generated by person 837:
# {6: 2, 7: 1, 8: 1}
#
# Infections generated by person 3:
# {3: 1, 4: 1, 5: 1, 17: 1, 19: 1}
#
# Infections generated by person 1053:
# {5: 2}
#
# Infections generated by person 905:
# {14: 1}
#
# Infections generated by person 120:
# {4: 2, 6: 1}
#
# Infections generated by person 1499:
# {1: 1, 2: 1, 3: 1, 5: 2}
#
# Infections generated by person 1039:
# {5: 1, 7: 1, 11: 1}
#
# Infections generated by person 880:
# {8: 1}
#
# Infections generated by person 963:
# {6: 1}
#
# Infections generated by person 187:
# {6: 1}
#
# Infections generated by person 956:
# {5: 3, 6: 1, 27: 1}
#
# Infections generated by person 1002:
# {25: 1}
#
# Infections generated by person 767:
# {7: 1, 28: 1}
#
# Infections generated by person 1422:
# {13: 1}
#
# Infections generated by person 443:
# {22: 1, 25: 1}
#
# Infections generated by person 743:
# {2: 5, 3: 1, 4: 3}
#
# Infections generated by person 309:
# {5: 1, 6: 1, 28: 1}
#
# Infections generated by person 1255:
# {7: 1}
#
# Infections generated by person 49:
# {6: 1}
#
# Infections generated by person 772:
# {17: 1, 19: 1}
#
# Infections generated by person 1318:
# {3: 1, 4: 3, 5: 1}
#
# Infections generated by person 885:
# {3: 1, 5: 2}
#
# Infections generated by person 136:
# {5: 1, 13: 1}
#
# Infections generated by person 1156:
# {5: 1}
#
# Infections generated by person 140:
# {35: 1}
#
# Infections generated by person 1070:
# {32: 1}
#
# Infections generated by person 113:
# {13: 1, 25: 1}
#
# Infections generated by person 747:
# {4: 1, 17: 1, 28: 1, 33: 1, 37: 1, 47: 1}
#
# Infections generated by person 496:
# {5: 1, 21: 1}
#
# Infections generated by person 1334:
# {7: 1, 13: 1, 18: 1, 35: 1, 47: 1}
#
# Infections generated by person 277:
# {5: 1, 6: 1, 8: 1}
#
# Infections generated by person 456:
# {3: 2, 4: 2, 33: 1}
#
# Infections generated by person 706:
# {29: 1, 32: 1, 36: 1, 39: 1}
#
# Infections generated by person 1207:
# {37: 1}
#
# Infections generated by person 64:
# {9: 1}
#
# Infections generated by person 465:
# {31: 1, 46: 1}
#
# Infections generated by person 390:
# {12: 1, 24: 1, 38: 1, 53: 1}
#
# Infections generated by person 701:
# {5: 1}
#
# Infections generated by person 951:
# {5: 1, 7: 1}
#
# Infections generated by person 523:
# {23: 1}
#
# Infections generated by person 865:
# {6: 2}
#
# Infections generated by person 427:
# {6: 2}
#
# Infections generated by person 761:
# {11: 1}
#
# Infections generated by person 358:
# {18: 1, 20: 1, 24: 2}
#
# Infections generated by person 275:
# {6: 1}
#
# Infections generated by person 1416:
# {4: 2, 5: 2}
#
# Infections generated by person 663:
# {9: 1}
#
# Infections generated by person 792:
# {7: 1, 13: 1, 18: 1, 21: 1, 40: 1, 42: 1, 45: 1, 47: 2}
#
# Infections generated by person 1412:
# {5: 1, 6: 2}
#
# Infections generated by person 1123:
# {7: 1, 49: 1, 68: 1}
#
# Infections generated by person 52:
# {6: 1}
#
# Infections generated by person 991:
# {15: 1, 24: 1, 25: 1, 26: 1, 39: 1}
#
# Infections generated by person 95:
# {6: 1}
#
# Infections generated by person 1446:
# {7: 1, 50: 1}
#
# Infections generated by person 1346:
# {7: 1}
#
# Infections generated by person 169:
# {19: 2, 37: 1}
#
# Infections generated by person 1052:
# {3: 1}
#
# Infections generated by person 1220:
# {12: 1, 16: 1}
#
# Infections generated by person 1480:
# {1: 2}
#
# Infections generated by person 733:
# {6: 1, 10: 1}
#
# Infections generated by person 1199:
# {18: 1}
#
# Infections generated by person 328:
# {6: 1}
#
# Infections generated by person 508:
# {19: 1}
#
# Infections generated by person 648:
# {6: 1, 7: 1}
#
# Infections generated by person 812:
# {5: 1}
#
# Infections generated by person 1079:
# {5: 1}
#
# Infections generated by person 435:
# {6: 1}
#
# Infections generated by person 247:
# {11: 1}
#
# Infections generated by person 147:
# {19: 1}
#
# Infections generated by person 973:
# {6: 1}
#
# Infections generated by person 34:
# {6: 1, 24: 1, 25: 1}
#
# Infections generated by person 343:
# {5: 2, 6: 1}
#
# Infections generated by person 1142:
# {12: 1}
#
# Infections generated by person 796:
# {7: 4, 8: 1}
#
# Infections generated by person 301:
# {7: 2}
#
# Infections generated by person 558:
# {7: 1}
#
# Infections generated by person 1119:
# {5: 1}
#
# Infections generated by person 836:
# {9: 1}
#
# Infections generated by person 941:
# {6: 1}
#
# Infections generated by person 440:
# {3: 1, 4: 1, 34: 1, 38: 1}
#
# Infections generated by person 1276:
# {9: 1, 25: 1, 28: 1, 34: 2, 36: 1}
#
# Infections generated by person 527:
# {50: 1}
#
# Infections generated by person 985:
# {36: 1}
#
# Infections generated by person 406:
# {15: 2}
#
# Infections generated by person 1373:
# {7: 1}
#
# Infections generated by person 1277:
# {4: 1}
#
# Infections generated by person 1020:
# {5: 2, 54: 1, 61: 1}
#
# Infections generated by person 1292:
# {23: 1}
#
# Infections generated by person 889:
# {31: 1, 35: 1, 36: 2}
#
# Infections generated by person 1143:
# {3: 1, 4: 1, 5: 1, 6: 1}
#
# Infections generated by person 1355:
# {14: 1}
#
# Infections generated by person 1058:
# {5: 3, 6: 1, 11: 1, 19: 1}
#
# Infections generated by person 961:
# {3: 1, 4: 2, 7: 1}
#
# Infections generated by person 1360:
# {4: 1, 5: 2}
#
# Infections generated by person 415:
# {6: 1, 23: 1}
#
# Infections generated by person 71:
# {20: 1}
#
# Infections generated by person 1308:
# {5: 1, 21: 1, 60: 1}
#
# Infections generated by person 128:
# {7: 1}
#
# Infections generated by person 1217:
# {16: 1}
#
# Infections generated by person 1293:
# {14: 1, 18: 1}
#
# Infections generated by person 168:
# {6: 1, 10: 1, 16: 1}
#
# Infections generated by person 491:
# {16: 1, 19: 1}
#
# Infections generated by person 1044:
# {6: 2}
#
# Infections generated by person 1161:
# {7: 1, 17: 1, 30: 1}
#
# Infections generated by person 32:
# {7: 1, 19: 1}
#
# Infections generated by person 1410:
# {4: 2, 8: 1}
#
# Infections generated by person 141:
# {6: 3, 17: 1, 43: 1}
#
# Infections generated by person 205:
# {6: 1, 12: 1}
#
# Infections generated by person 102:
# {7: 1, 29: 1, 40: 1}
#
# Infections generated by person 519:
# {10: 1}
#
# Infections generated by person 158:
# {6: 2, 8: 1, 10: 1}
#
# Infections generated by person 103:
# {17: 1}
#
# Infections generated by person 112:
# {27: 1, 28: 1}
#
# Infections generated by person 1038:
# {5: 1, 29: 1}
#
# Infections generated by person 506:
# {6: 1}
#
# Infections generated by person 952:
# {6: 1}
#
# Infections generated by person 873:
# {3: 1, 4: 3, 31: 1, 33: 1, 42: 1}
#
# Infections generated by person 1006:
# {7: 4, 17: 1}
#
# Infections generated by person 601:
# {8: 1, 23: 1}
#
# Infections generated by person 608:
# {4: 4, 5: 2, 6: 1}
#
# Infections generated by person 1467:
# {1: 1}
#
# Infections generated by person 1074:
# {5: 1}
#
# Infections generated by person 1219:
# {6: 1}
#
# Infections generated by person 1479:
# {3: 1, 5: 1}
#
# Infections generated by person 1403:
# {16: 1}
#
# Infections generated by person 1154:
# {6: 1, 7: 1, 31: 1, 33: 1}
#
# Infections generated by person 198:
# {6: 1}
#
# Infections generated by person 1317:
# {6: 1, 12: 1}
#
# Infections generated by person 1330:
# {3: 1, 5: 2, 6: 1, 48: 1}
#
# Infections generated by person 222:
# {23: 1, 24: 1, 29: 1, 38: 1, 39: 2, 40: 1, 41: 1, 46: 1}
#
# Infections generated by person 1113:
# {14: 1, 39: 1}
#
# Infections generated by person 622:
# {4: 2, 5: 3}
#
# Infections generated by person 1067:
# {2: 1, 5: 1}
#
# Infections generated by person 861:
# {11: 1, 17: 1, 32: 1}
#
# Infections generated by person 1150:
# {5: 1, 14: 1}
#
# Infections generated by person 1194:
# {6: 1}
#
# Infections generated by person 628:
# {5: 2, 31: 1, 45: 1, 74: 1}
#
# Infections generated by person 1176:
# {5: 1, 14: 1}
#
# Infections generated by person 862:
# {7: 1, 8: 1}
#
# Infections generated by person 453:
# {26: 1, 39: 1}
#
# Infections generated by person 1134:
# {4: 1}
#
# Infections generated by person 424:
# {6: 1, 7: 1}
#
# Infections generated by person 1335:
# {11: 1}
#
# Infections generated by person 1211:
# {5: 1, 6: 1, 14: 1}
#
# Infections generated by person 261:
# {5: 1, 36: 1, 45: 1, 53: 1, 58: 1}
#
# Infections generated by person 540:
# {7: 1, 19: 1}
#
# Infections generated by person 894:
# {5: 2}
#
# Infections generated by person 1259:
# {8: 1, 24: 2, 26: 1}
#
# Infections generated by person 1104:
# {3: 1, 4: 1}
#
# Infections generated by person 1174:
# {4: 2, 5: 1}
#
# Infections generated by person 1285:
# {5: 1, 29: 2}
#
# Infections generated by person 804:
# {27: 1}
#
# Infections generated by person 1376:
# {6: 1}
#
# Infections generated by person 966:
# {2: 1, 3: 1, 4: 2}
#
# Infections generated by person 139:
# {6: 1, 13: 1}
#
# Infections generated by person 918:
# {5: 1}
#
# Infections generated by person 1257:
# {5: 3}
#
# Infections generated by person 1478:
# {1: 1, 4: 3}
#
# Infections generated by person 1289:
# {5: 3}
#
# Infections generated by person 555:
# {17: 1}
#
# Infections generated by person 380:
# {6: 2}
#
# Infections generated by person 882:
# {7: 1}
#
# Infections generated by person 348:
# {32: 1}
#
# Infections generated by person 946:
# {5: 4, 35: 1}
#
# Infections generated by person 1117:
# {6: 1}
#
# Infections generated by person 134:
# {9: 1, 22: 1}
#
# Infections generated by person 110:
# {4: 1, 5: 2, 7: 1}
#
# Infections generated by person 638:
# {10: 1, 72: 1}
#
# Infections generated by person 921:
# {6: 1, 10: 1, 17: 1, 21: 1, 34: 1, 40: 1, 44: 1, 56: 1, 57: 1}
#
# Infections generated by person 27:
# {15: 1}
#
# Infections generated by person 75:
# {4: 2, 5: 1}
#
# Infections generated by person 718:
# {8: 1, 81: 1}
#
# Infections generated by person 320:
# {5: 1}
#
# Infections generated by person 1362:
# {31: 1}
#
# Infections generated by person 554:
# {5: 1, 6: 2}
#
# Infections generated by person 678:
# {5: 1}
#
# Infections generated by person 1131:
# {5: 1, 20: 1, 30: 1, 32: 3, 36: 1, 56: 1, 69: 1, 71: 1}
#
# Infections generated by person 1381:
# {10: 1, 44: 1}
#
# Infections generated by person 665:
# {26: 1, 33: 1, 37: 1}
#
# Infections generated by person 557:
# {6: 2, 7: 1}
#
# Infections generated by person 1455:
# {3: 1, 14: 1, 26: 1}
#
# Infections generated by person 416:
# {7: 1}
#
# Infections generated by person 521:
# {11: 1, 35: 1, 40: 1, 45: 1, 48: 1, 51: 1, 53: 1, 66: 1, 67: 1}
#
# Infections generated by person 1179:
# {8: 1}
#
# Infections generated by person 717:
# {4: 1, 6: 1}
#
# Infections generated by person 40:
# {7: 1, 34: 1}
#
# Infections generated by person 1385:
# {3: 3}
#
# Infections generated by person 645:
# {5: 1, 6: 1}
#
# Infections generated by person 579:
# {5: 2, 7: 1, 46: 2}
#
# Infections generated by person 1128:
# {16: 2, 21: 1, 25: 1}
#
# Infections generated by person 514:
# {6: 2, 25: 1}
#
# Infections generated by person 1341:
# {29: 1}
#
# Infections generated by person 115:
# {3: 3, 4: 1}
#
# Infections generated by person 988:
# {9: 1}
#
# Infections generated by person 1056:
# {5: 3, 7: 1}
#
# Infections generated by person 1003:
# {7: 1}
#
# Infections generated by person 672:
# {31: 2}
#
# Infections generated by person 783:
# {10: 1, 35: 1}
#
# Infections generated by person 92:
# {5: 1, 31: 1, 32: 1, 89: 1}
#
# Infections generated by person 376:
# {18: 1, 27: 1, 43: 1, 50: 1, 55: 1}
#
# Infections generated by person 563:
# {6: 1}
#
# Infections generated by person 1049:
# {7: 1}
#
# Infections generated by person 60:
# {8: 1}
#
# Infections generated by person 272:
# {4: 3, 5: 1}
#
# Infections generated by person 1429:
# {12: 1}
#
# Infections generated by person 503:
# {3: 1, 4: 1, 22: 1, 29: 1, 37: 1, 41: 1, 48: 1, 51: 1, 65: 1}
#
# Infections generated by person 331:
# {5: 2, 6: 1}
#
# Infections generated by person 1164:
# {3: 1, 30: 2, 32: 1, 44: 1, 45: 1, 53: 1, 57: 1, 61: 1, 64: 1, 72: 1, 78: 1, 81: 1, 91: 1, 97: 1, 101: 1, 102: 1, 105: 1, 128: 1}
#
# Infections generated by person 1490:
# {1: 1}
#
# Infections generated by person 173:
# {16: 1, 22: 1}
#
# Infections generated by person 949:
# {7: 1}
#
# Infections generated by person 562:
# {15: 1}
#
# Infections generated by person 1459:
# {37: 2, 40: 1, 43: 1, 48: 1, 79: 1}
#
# Infections generated by person 16:
# {5: 1, 31: 1}
#
# Infections generated by person 674:
# {8: 1}
#
# Infections generated by person 1278:
# {4: 1, 5: 1, 13: 1}
#
# Infections generated by person 1253:
# {6: 1}
#
# Infections generated by person 522:
# {30: 1}
#
# Infections generated by person 1451:
# {1: 1, 2: 1}
#
# Infections generated by person 499:
# {17: 1, 18: 1, 36: 1}
#
# Infections generated by person 1177:
# {7: 1}
#
# Infections generated by person 420:
# {17: 1, 20: 1, 21: 2, 24: 1}
#
# Infections generated by person 336:
# {6: 1, 7: 2, 24: 1, 41: 1}
#
# Infections generated by person 534:
# {10: 1}
#
# Infections generated by person 903:
# {10: 1, 30: 1, 31: 1, 33: 1, 53: 1}
#
# Infections generated by person 614:
# {6: 1, 14: 1, 18: 1, 20: 1, 28: 1, 33: 1}
#
# Infections generated by person 232:
# {5: 1}
#
# Infections generated by person 486:
# {6: 1, 12: 1}
#
# Infections generated by person 754:
# {4: 1}
#
# Infections generated by person 969:
# {7: 1, 12: 1}
#
# Infections generated by person 504:
# {2: 3, 4: 1}
#
# Infections generated by person 1324:
# {5: 1, 7: 1}
#
# Infections generated by person 1484:
# {1: 1, 2: 1, 4: 1}
#
# Infections generated by person 257:
# {5: 1, 17: 2, 18: 1, 24: 1}
#
# Infections generated by person 719:
# {4: 1, 5: 1, 6: 1}
#
# Infections generated by person 664:
# {4: 2, 5: 1}
#
# Infections generated by person 1382:
# {4: 1, 11: 1, 13: 1}
#
# Infections generated by person 948:
# {7: 1}
#
# Infections generated by person 186:
# {4: 4, 5: 1, 6: 1, 7: 1, 8: 1}
#
# Infections generated by person 84:
# {23: 1}
#
# Infections generated by person 1282:
# {21: 1, 24: 1}
#
# Infections generated by person 209:
# {16: 1, 18: 1, 21: 1, 41: 1}
#
# Infections generated by person 1221:
# {17: 1, 19: 1, 29: 1, 36: 1, 75: 1, 77: 1}
#
# Infections generated by person 1497:
# {3: 4, 4: 2}
#
# Infections generated by person 196:
# {3: 5, 4: 1, 5: 2}
#
# Infections generated by person 41:
# {4: 2}
#
# Infections generated by person 775:
# {5: 3, 28: 1}
#
# Infections generated by person 1094:
# {4: 2, 7: 1}
#
# Infections generated by person 1214:
# {6: 1, 8: 1, 19: 1}
#
# Infections generated by person 597:
# {6: 2}
#
# Infections generated by person 1233:
# {7: 1, 11: 1}
#
# Infections generated by person 231:
# {21: 1, 31: 1}
#
# Infections generated by person 730:
# {6: 1}
#
# Infections generated by person 1462:
# {1: 3, 2: 1, 3: 1}
#
# Infections generated by person 153:
# {8: 1, 14: 1, 26: 1}
#
# Infections generated by person 660:
# {7: 1, 39: 1, 52: 1}
#
# Infections generated by person 1444:
# {22: 1}
#
# Infections generated by person 1435:
# {6: 1, 20: 1, 44: 1, 47: 1}
#
# Infections generated by person 190:
# {14: 1}
#
# Infections generated by person 428:
# {6: 1, 23: 1}
#
# Infections generated by person 542:
# {4: 1, 5: 1, 6: 2}
#
# Infections generated by person 1407:
# {3: 2}
#
# Infections generated by person 278:
# {9: 1}
#
# Infections generated by person 399:
# {4: 1, 5: 1, 6: 1}
#
# Infections generated by person 634:
# {7: 1, 17: 1}
#
# Infections generated by person 1201:
# {30: 1, 61: 1, 108: 1, 126: 1}
#
# Infections generated by person 495:
# {4: 1, 5: 1, 15: 1, 16: 1, 29: 1, 31: 1, 37: 1}
#
# Infections generated by person 1082:
# {5: 1, 15: 1, 24: 1}
#
# Infections generated by person 1471:
# {1: 1, 2: 1, 4: 1}
#
# Infections generated by person 740:
# {6: 1}
#
# Infections generated by person 1383:
# {5: 2, 6: 3}
#
# Infections generated by person 983:
# {5: 1}
#
# Infections generated by person 184:
# {9: 1, 24: 1}
#
# Infections generated by person 1433:
# {7: 1, 93: 1}
#
# Infections generated by person 466:
# {5: 4}
#
# Infections generated by person 644:
# {7: 1, 9: 1}
#
# Infections generated by person 823:
# {28: 1, 30: 1}
#
# Infections generated by person 1237:
# {4: 2, 5: 1, 6: 2}
#
# Infections generated by person 1325:
# {7: 1, 49: 1}
#
# Infections generated by person 1048:
# {5: 2, 29: 1, 37: 1, 45: 1, 46: 1, 57: 1, 61: 2, 79: 1, 84: 1, 90: 1, 92: 1, 93: 1}
#
# Infections generated by person 157:
# {6: 1}
#
# Infections generated by person 619:
# {16: 1, 21: 1}
#
# Infections generated by person 705:
# {5: 1, 6: 1, 13: 1}
#
# Infections generated by person 356:
# {25: 1, 38: 1}
#
# Infections generated by person 237:
# {4: 1}
#
# Infections generated by person 81:
# {9: 1, 37: 1}
#
# Infections generated by person 423:
# {3: 1}
#
# Infections generated by person 43:
# {6: 1}
#
# Infections generated by person 392:
# {8: 1, 103: 1}
#
# Infections generated by person 742:
# {10: 1}
#
# Infections generated by person 758:
# {7: 1}
#
# Infections generated by person 18:
# {12: 2}
#
# Infections generated by person 1095:
# {5: 1, 6: 1}
#
# Infections generated by person 234:
# {6: 2}
#
# Infections generated by person 826:
# {3: 2, 4: 3, 5: 1, 6: 1}
#
# Infections generated by person 774:
# {6: 1}
#
# Infections generated by person 178:
# {6: 2, 7: 1, 14: 1, 18: 1}
#
# Infections generated by person 776:
# {4: 2, 5: 1, 6: 1}
#
# Infections generated by person 746:
# {16: 1}
#
# Infections generated by person 1473:
# {1: 1, 3: 1, 13: 1}
#
# Infections generated by person 900:
# {4: 4}
#
# Infections generated by person 915:
# {4: 2, 6: 1}
#
# Infections generated by person 934:
# {3: 1, 5: 1, 27: 1, 30: 1, 35: 1, 43: 1}
#
# Infections generated by person 1260:
# {33: 1}
#
# Infections generated by person 1339:
# {4: 5, 11: 1}
#
# Infections generated by person 728:
# {17: 1}
#
# Infections generated by person 93:
# {16: 2, 22: 1}
#
# Infections generated by person 599:
# {58: 1}
#
# Infections generated by person 795:
# {6: 1, 7: 1}
#
# Infections generated by person 1483:
# {1: 2}
#
# Infections generated by person 950:
# {6: 1, 31: 1, 36: 1}
#
# Infections generated by person 821:
# {6: 1}
#
# Infections generated by person 1460:
# {2: 1, 4: 2}
#
# Infections generated by person 979:
# {4: 2}
#
# Infections generated by person 355:
# {8: 1}
#
# Infections generated by person 197:
# {2: 3}
#
# Infections generated by person 944:
# {11: 1}
#
# Infections generated by person 904:
# {6: 1}
#
# Infections generated by person 1125:
# {16: 1, 22: 1, 26: 1, 28: 1, 30: 1}
#
# Infections generated by person 224:
# {3: 1, 5: 1, 28: 1}
#
# Infections generated by person 1409:
# {6: 3, 7: 1}
#
# Infections generated by person 1379:
# {6: 1, 12: 1, 22: 1, 26: 1, 29: 1}
#
# Infections generated by person 1097:
# {5: 2}
#
# Infections generated by person 1130:
# {7: 1}
#
# Infections generated by person 88:
# {5: 1, 6: 1}
#
# Infections generated by person 1470:
# {3: 1}
#
# Infections generated by person 1387:
# {7: 1, 20: 1}
#
# Infections generated by person 829:
# {4: 1, 5: 2, 6: 1, 9: 1, 10: 1, 27: 1}
#
# Infections generated by person 108:
# {17: 1}
#
# Infections generated by person 1222:
# {7: 1, 17: 1}
#
# Infections generated by person 300:
# {39: 1}
#
# Infections generated by person 359:
# {21: 1, 26: 1}
#
# Infections generated by person 1456:
# {2: 2, 3: 1, 5: 1, 12: 1}
#
# Infections generated by person 666:
# {5: 1, 24: 1}
#
# Infections generated by person 477:
# {16: 1, 20: 1}
#
# Infections generated by person 8:
# {26: 1, 27: 1}
#
# Infections generated by person 808:
# {22: 1, 23: 1}
#
# Infections generated by person 1135:
# {6: 1}
#
# Infections generated by person 1112:
# {6: 2}
#
# Infections generated by person 1487:
# {1: 1}
#
# Infections generated by person 215:
# {6: 2}
#
# Infections generated by person 859:
# {6: 1, 17: 1, 18: 1, 25: 1}
#
# Infections generated by person 570:
# {3: 2, 4: 3, 5: 1}
#
# Infections generated by person 1000:
# {50: 2, 63: 1, 64: 1}
#
# Infections generated by person 433:
# {7: 1, 8: 1}
#
# Infections generated by person 1121:
# {19: 1}
#
# Infections generated by person 1196:
# {4: 1}
#
# Infections generated by person 731:
# {35: 1, 56: 1, 59: 2}
#
# Infections generated by person 123:
# {6: 2}
#
# Infections generated by person 598:
# {5: 3, 10: 1}
#
# Infections generated by person 580:
# {5: 1}
#
# Infections generated by person 673:
# {5: 2}
#
# Infections generated by person 621:
# {7: 1}
#
# Infections generated by person 1073:
# {23: 1, 27: 1}
#
# Infections generated by person 1475:
# {1: 2, 2: 1, 3: 1, 16: 1}
#
# Infections generated by person 48:
# {11: 1}
#
# Infections generated by person 394:
# {7: 1}
#
# Infections generated by person 296:
# {12: 1, 22: 1, 23: 1}
#
# Infections generated by person 995:
# {2: 3, 4: 1}
#
# Infections generated by person 1218:
# {7: 1}
#
# Infections generated by person 1115:
# {9: 1, 20: 1}
#
# Infections generated by person 1183:
# {25: 1}
#
# Infections generated by person 989:
# {6: 2, 12: 1}
#
# Infections generated by person 1139:
# {9: 2}
#
# Infections generated by person 1114:
# {32: 1}
#
# Infections generated by person 1414:
# {5: 2}
#
# Infections generated by person 830:
# {15: 1, 18: 1, 19: 1, 27: 1, 43: 1, 54: 1, 56: 1, 63: 1, 68: 1}
#
# Infections generated by person 572:
# {12: 1, 38: 1, 58: 1}
#
# Infections generated by person 771:
# {6: 2}
#
# Infections generated by person 129:
# {29: 1, 42: 1}
#
# Infections generated by person 91:
# {12: 1, 14: 1}
#
# Infections generated by person 111:
# {12: 1, 23: 1, 25: 1}
#
# Infections generated by person 984:
# {17: 1}
#
# Infections generated by person 125:
# {24: 1, 89: 1, 101: 1, 104: 1}
#
# Infections generated by person 114:
# {10: 3, 16: 1}
#
# Infections generated by person 957:
# {3: 1, 28: 1}
#
# Infections generated by person 532:
# {4: 2, 13: 1, 16: 1, 23: 1}
#
# Infections generated by person 322:
# {6: 1, 8: 1}
#
# Infections generated by person 1306:
# {38: 1}
#
# Infections generated by person 595:
# {20: 1, 21: 1, 23: 1, 35: 1, 43: 1, 44: 1, 64: 1}
#
# Infections generated by person 838:
# {10: 1}
#
# Infections generated by person 1236:
# {4: 1}
#
# Infections generated by person 1242:
# {30: 1}
#
# Infections generated by person 1272:
# {3: 3, 4: 2, 5: 1, 6: 1, 14: 1, 36: 1, 112: 1}
#
# Infections generated by person 1010:
# {20: 1}
#
# Infections generated by person 1350:
# {8: 1, 17: 1}
#
# Infections generated by person 818:
# {6: 1, 11: 1}
#
# Infections generated by person 378:
# {7: 1, 30: 1}
#
# Infections generated by person 505:
# {31: 1, 37: 1}
#
# Infections generated by person 539:
# {6: 1, 7: 1}
#
# Infections generated by person 269:
# {6: 1, 8: 1, 9: 1}
#
# Infections generated by person 1244:
# {4: 1}
#
# Infections generated by person 1043:
# {5: 1, 6: 2}
#
# Infections generated by person 239:
# {2: 1, 3: 1, 6: 1}
#
# Infections generated by person 1286:
# {7: 1}
#
# Infections generated by person 1477:
# {2: 1, 3: 1, 12: 1, 14: 1}
#
# Infections generated by person 308:
# {10: 1, 17: 1, 20: 1, 27: 1}
#
# Infections generated by person 658:
# {5: 1, 6: 1}
#
# Infections generated by person 1458:
# {4: 2, 5: 1, 6: 1}
#
# Infections generated by person 474:
# {2: 2, 14: 1}
#
# Infections generated by person 524:
# {6: 1}
#
# Infections generated by person 180:
# {5: 3, 31: 1}
#
# Infections generated by person 166:
# {4: 1, 20: 1, 25: 1, 37: 1}
#
# Infections generated by person 799:
# {5: 1, 6: 1, 8: 1}
#
# Infections generated by person 159:
# {6: 1, 24: 1, 40: 1}
#
# Infections generated by person 206:
# {6: 2, 7: 1, 22: 1, 63: 1}
#
# Infections generated by person 1347:
# {7: 1}
#
# Infections generated by person 569:
# {4: 3, 6: 1, 14: 1}
#
# Infections generated by person 1302:
# {6: 1}
#
# Infections generated by person 1423:
# {5: 3, 17: 1}
#
# Infections generated by person 1312:
# {6: 1, 11: 1, 17: 1}
#
# Infections generated by person 266:
# {15: 1, 32: 1}
#
# Infections generated by person 550:
# {6: 1}
#
# Infections generated by person 1005:
# {4: 2}
#
# Infections generated by person 97:
# {3: 2, 12: 1}
#
# Infections generated by person 1469:
# {1: 1, 2: 1, 3: 2, 4: 1}
#
# Infections generated by person 729:
# {4: 4, 5: 1}
#
# Infections generated by person 1060:
# {5: 1}
#
# Infections generated by person 79:
# {6: 3}
#
# Infections generated by person 566:
# {5: 1, 22: 2}
#
# Infections generated by person 87:
# {5: 1}
#
# Infections generated by person 249:
# {6: 1}
#
# Infections generated by person 1269:
# {23: 1}
#
# Infections generated by person 878:
# {5: 2}
#
# Infections generated by person 699:
# {6: 1}
#
# Infections generated by person 1425:
# {6: 1, 15: 1}
#
# Infections generated by person 631:
# {5: 2, 6: 2}
#
# Infections generated by person 651:
# {7: 1, 15: 1}
#
# Infections generated by person 384:
# {4: 1, 6: 1}
#
# Infections generated by person 1390:
# {12: 1, 48: 1}
#
# Infections generated by person 512:
# {7: 1}
#
# Infections generated by person 244:
# {7: 1}
#
# Infections generated by person 365:
# {7: 1}
#
# Infections generated by person 1474:
# {1: 1, 2: 3, 4: 2}
#
# Infections generated by person 1493:
# {1: 1}
#
# Infections generated by person 213:
# {54: 1}
#
# Infections generated by person 819:
# {4: 1, 5: 1, 6: 1}
#
# Infections generated by person 42:
# {7: 1}
#
# Infections generated by person 207:
# {4: 1, 6: 1}
#
# Infections generated by person 615:
# {6: 2, 13: 1}
#
# Infections generated by person 564:
# {6: 1}
#
# Infections generated by person 425:
# {3: 1, 22: 1}
#
# Infections generated by person 925:
# {19: 1}
#
# Infections generated by person 472:
# {8: 1}
#
# Infections generated by person 226:
# {6: 1, 8: 1}
#
# Infections generated by person 855:
# {2: 4, 3: 5, 4: 1, 6: 1, 16: 1}
#
# Infections generated by person 1294:
# {4: 2, 5: 2}
#
# Infections generated by person 1027:
# {4: 2}
#
# Infections generated by person 161:
# {17: 1}
#
# Infections generated by person 333:
# {5: 2, 6: 1}
#
# Infections generated by person 1457:
# {2: 1, 3: 1, 5: 1, 6: 1, 12: 1, 15: 1, 31: 1, 40: 1, 45: 1, 47: 1, 59: 1, 64: 1, 79: 1, 94: 1}
#
# Infections generated by person 1129:
# {5: 1, 12: 1}
#
# Infections generated by person 291:
# {4: 1, 5: 2, 12: 1}
#
# Infections generated by person 1398:
# {11: 1}
#
# Infections generated by person 1345:
# {2: 2, 3: 2}
#
# Infections generated by person 1127:
# {9: 1}
#
# Infections generated by person 938:
# {26: 1}
#
# Infections generated by person 409:
# {6: 2, 26: 1}
#
# Infections generated by person 454:
# {3: 1, 4: 1, 12: 1, 14: 1}
#
# Infections generated by person 446:
# {4: 1}
#
# Infections generated by person 347:
# {15: 1, 17: 1}
#
# Infections generated by person 741:
# {6: 1, 12: 1, 35: 1}
#
# Infections generated by person 702:
# {5: 1}
#
# Infections generated by person 227:
# {5: 1, 7: 1, 17: 1}
#
# Infections generated by person 105:
# {7: 1}
#
# Infections generated by person 19:
# {4: 2, 17: 1, 54: 1}
#
# Infections generated by person 1393:
# {5: 1}
#
# Infections generated by person 553:
# {7: 1}
#
# Infections generated by person 155:
# {18: 1, 39: 1, 47: 1}
#
# Infections generated by person 703:
# {7: 1, 11: 1, 28: 1}
#
# Infections generated by person 1238:
# {21: 1, 38: 1, 45: 1}
#
# Infections generated by person 551:
# {9: 1}
#
# Infections generated by person 1054:
# {6: 1, 20: 1}
#
# Infections generated by person 1165:
# {6: 3, 25: 1, 29: 1, 48: 1}
#
# Infections generated by person 483:
# {29: 1, 31: 1, 34: 1, 58: 1}
#
# Infections generated by person 1064:
# {4: 1, 14: 1}
#
# Infections generated by person 160:
# {5: 1}
#
# Infections generated by person 639:
# {14: 1, 22: 1, 39: 1, 56: 1, 63: 1, 71: 1}
#
# Infections generated by person 1485:
# {2: 2, 3: 1, 5: 1}
#
# Infections generated by person 912:
# {5: 2, 20: 1, 29: 1}
#
# Infections generated by person 690:
# {11: 1}
#
# Infections generated by person 1092:
# {5: 2, 6: 1}
#
# Infections generated by person 432:
# {3: 4, 4: 2, 5: 1}
#
# Infections generated by person 649:
# {20: 1}
#
# Infections generated by person 1087:
# {6: 1}
#
# Infections generated by person 1036:
# {13: 1, 29: 1}
#
# Infections generated by person 404:
# {12: 1, 24: 1, 31: 1}
#
# Infections generated by person 1265:
# {6: 1}
#
# Infections generated by person 14:
# {5: 2}
#
# Infections generated by person 784:
# {6: 1, 7: 1}
#
# Infections generated by person 323:
# {6: 1, 8: 1}
#
# Infections generated by person 289:
# {14: 1, 22: 1, 34: 1, 47: 1, 54: 1}
#
# Infections generated by person 143:
# {6: 1, 9: 1}
#
# Infections generated by person 852:
# {7: 1, 27: 1, 29: 1}
#
# Infections generated by person 1116:
# {5: 1, 6: 2}
#
# Infections generated by person 902:
# {13: 1}
#
# Infections generated by person 1305:
# {5: 1}
#
# Infections generated by person 610:
# {24: 1}
#
# Infections generated by person 350:
# {14: 1}
#
# Infections generated by person 552:
# {19: 1}
#
# Infections generated by person 1274:
# {17: 1, 27: 1, 53: 1}
#
# Infections generated by person 1492:
# {1: 1, 2: 2, 4: 2}
#
# Infections generated by person 853:
# {5: 2, 6: 1}
#
# Infections generated by person 1107:
# {5: 1, 6: 1}
#
# Infections generated by person 1448:
# {4: 1, 5: 2, 38: 1}
#
# Infections generated by person 1231:
# {6: 1, 23: 1, 28: 1}
#
# Infections generated by person 1241:
# {13: 1, 22: 1, 24: 1, 29: 1}
#
# Infections generated by person 1022:
# {5: 2, 6: 1}
#
# Infections generated by person 863:
# {32: 1, 36: 1, 39: 1, 62: 1, 69: 1, 74: 1, 91: 1, 116: 1}
#
# Infections generated by person 755:
# {17: 1}
#
# Infections generated by person 748:
# {5: 1}
#
# Infections generated by person 1206:
# {24: 1}
#
# Infections generated by person 1088:
# {6: 1, 7: 1}
#
# Infections generated by person 1268:
# {4: 1, 5: 1, 6: 1, 9: 1, 11: 1}
#
# Infections generated by person 152:
# {10: 1}
#
# Infections generated by person 896:
# {25: 1}
#
# Infections generated by person 647:
# {6: 1, 32: 1}
#
# Infections generated by person 867:
# {22: 1, 26: 1}
#
# Infections generated by person 167:
# {5: 1, 7: 1}
#
# Infections generated by person 781:
# {4: 1, 17: 1, 19: 1, 23: 2, 24: 1, 29: 1}
#
# Infections generated by person 458:
# {5: 1, 10: 1}
#
# Infections generated by person 150:
# {32: 1}
#
# Infections generated by person 1348:
# {7: 1}
#
# Infections generated by person 616:
# {4: 1}
#
# Infections generated by person 544:
# {7: 1}
#
# Infections generated by person 834:
# {9: 1}
#
# Infections generated by person 1031:
# {18: 1}
#
# Infections generated by person 1248:
# {5: 1, 6: 1}
#
# Infections generated by person 407:
# {4: 1, 7: 1}
#
# Infections generated by person 913:
# {8: 1}
#
# Infections generated by person 131:
# {7: 1, 49: 1}
#
# Infections generated by person 1364:
# {11: 1}
#
# Infections generated by person 735:
# {4: 1, 15: 1, 24: 1}
#
# Infections generated by person 1442:
# {2: 1, 3: 1, 4: 2, 6: 2, 23: 1, 47: 1, 48: 1}
#
# Infections generated by person 398:
# {7: 1}
#
# Infections generated by person 971:
# {3: 4, 6: 1}
#
# Infections generated by person 691:
# {10: 1, 25: 1}
#
# Infections generated by person 1254:
# {5: 2, 10: 1}
#
# Infections generated by person 1055:
# {6: 1}
#
# Infections generated by person 195:
# {32: 1, 34: 1}
#
# Infections generated by person 753:
# {4: 1}
#
# Infections generated by person 259:
# {6: 2}
#
# Infections generated by person 749:
# {13: 2}
#
# Infections generated by person 1033:
# {23: 1}
#
# Infections generated by person 768:
# {4: 1, 6: 1, 7: 1}
#
# Infections generated by person 725:
# {18: 1, 19: 2, 20: 1}
#
# Infections generated by person 940:
# {6: 1, 29: 1, 51: 1}
#
# Infections generated by person 1494:
# {2: 2, 3: 1}
#
# Infections generated by person 149:
# {5: 3}
#
# Infections generated by person 1486:
# {1: 1, 2: 3, 4: 1, 6: 1, 26: 1, 35: 1, 37: 1, 48: 1, 50: 1}
#
# Infections generated by person 290:
# {5: 1}
#
# Infections generated by person 751:
# {5: 1}
#
# Infections generated by person 137:
# {6: 1, 10: 1}
#
# Infections generated by person 1287:
# {7: 1}
#
# Infections generated by person 528:
# {6: 3}
#
# Infections generated by person 589:
# {5: 2}
#
# Infections generated by person 240:
# {5: 1, 18: 1, 22: 1, 23: 1, 25: 1}
#
# Infections generated by person 375:
# {6: 1, 18: 1}
#
# Infections generated by person 189:
# {31: 1}
#
# Infections generated by person 693:
# {6: 1}
#
# Infections generated by person 697:
# {29: 1, 46: 1, 50: 1, 51: 1, 52: 1, 55: 1}
#
# Infections generated by person 681:
# {18: 1, 23: 1}
#
# Infections generated by person 1389:
# {5: 2, 6: 1, 9: 1}
#
# Infections generated by person 1468:
# {1: 1, 2: 1, 4: 1, 24: 1, 26: 1, 38: 1}
#
# Infections generated by person 1280:
# {12: 1, 26: 1, 79: 1}
#
# Infections generated by person 715:
# {3: 1, 5: 1, 15: 1}
#
# Infections generated by person 220:
# {6: 2}
#
# Infections generated by person 541:
# {13: 1, 31: 1, 33: 1}
#
# Infections generated by person 848:
# {5: 1}
#
# Infections generated by person 50:
# {5: 1, 6: 1, 18: 1, 31: 1, 34: 1}
#
# Infections generated by person 497:
# {9: 1}
#
# Infections generated by person 525:
# {7: 1, 13: 1, 19: 1}
#
# Infections generated by person 907:
# {6: 1, 23: 1}
#
# Infections generated by person 845:
# {5: 1, 56: 1}
#
# Infections generated by person 914:
# {15: 1}
#
# Infections generated by person 574:
# {22: 1}
#
# Infections generated by person 1252:
# {18: 1, 40: 1, 95: 1}
#
# Infections generated by person 1013:
# {4: 2}
#
# Infections generated by person 57:
# {4: 1, 14: 1}
#
# Infections generated by person 850:
# {4: 1, 5: 1, 19: 1, 21: 1}
#
# Infections generated by person 337:
# {3: 2, 5: 1, 11: 2}
#
# Infections generated by person 606:
# {16: 1, 22: 1, 41: 1, 62: 1}
#
# Infections generated by person 1102:
# {4: 1, 6: 1, 7: 1, 16: 1, 33: 1, 34: 1}
#
# Infections generated by person 831:
# {5: 2}
#
# Infections generated by person 843:
# {10: 1}
#
# Infections generated by person 1137:
# {19: 1}
#
# Infections generated by person 288:
# {75: 1, 88: 1}
#
# Infections generated by person 1440:
# {4: 2, 6: 1, 12: 1}
#
# Infections generated by person 849:
# {17: 1, 19: 1, 28: 1, 31: 1}
#
# Infections generated by person 387:
# {5: 1, 8: 2, 17: 1}
#
# Infections generated by person 317:
# {6: 1, 7: 1}
#
# Infections generated by person 654:
# {11: 1}
#
# Infections generated by person 584:
# {5: 2, 6: 1, 13: 1, 34: 1}
#
# Infections generated by person 661:
# {4: 1, 5: 1, 17: 1}
#
# Infections generated by person 517:
# {6: 1, 7: 1}
#
# Infections generated by person 1169:
# {7: 1, 32: 1}
#
# Infections generated by person 816:
# {4: 3, 5: 1}
#
# Infections generated by person 61:
# {3: 1, 4: 3, 19: 1}
#
# Infections generated by person 381:
# {7: 1, 27: 1, 40: 1}
#
# Infections generated by person 170:
# {12: 1}
#
# Infections generated by person 1009:
# {6: 1}
#
# Infections generated by person 931:
# {4: 3}
#
# Infections generated by person 1340:
# {6: 1, 31: 1, 49: 1}
#
# Infections generated by person 700:
# {5: 2}
#
# Infections generated by person 581:
# {14: 1, 15: 1}
#
# Infections generated by person 349:
# {2: 1, 3: 1}
#
# Infections generated by person 1344:
# {9: 1, 18: 1, 21: 1}
#
# Infections generated by person 1240:
# {6: 1, 33: 1, 34: 1}
#
# Infections generated by person 109:
# {3: 3, 4: 1, 5: 1, 26: 1}
#
# Infections generated by person 468:
# {4: 1, 5: 2}
#
# Infections generated by person 1182:
# {4: 1, 5: 1}
#
# Infections generated by person 374:
# {5: 1}
#
# Infections generated by person 267:
# {3: 1}
#
# Infections generated by person 1167:
# {5: 2}
#
# Infections generated by person 1434:
# {12: 1, 13: 1, 23: 1}
#
# Infections generated by person 467:
# {4: 2, 7: 1}
#
# Infections generated by person 460:
# {3: 1}
#
# Infections generated by person 44:
# {5: 2, 6: 1}
#
# Infections generated by person 391:
# {16: 1}
#
# Infections generated by person 1041:
# {3: 4, 4: 3, 6: 1}
#
# Infections generated by person 722:
# {6: 1, 7: 1}
#
# Infections generated by person 881:
# {4: 2}
#
# Infections generated by person 363:
# {2: 2, 4: 1, 5: 1}
#
# Infections generated by person 1307:
# {25: 1}
#
# Infections generated by person 1313:
# {3: 1, 4: 2}
#
# Infections generated by person 121:
# {12: 1}
#
# Infections generated by person 471:
# {16: 1, 20: 1, 38: 1, 54: 1, 56: 1, 58: 1}
#
# Infections generated by person 431:
# {31: 1}
#
# Infections generated by person 1075:
# {5: 1, 6: 1, 7: 1}
#
# Infections generated by person 898:
# {5: 2, 6: 1, 14: 1}
#
# Infections generated by person 1071:
# {11: 1, 41: 1}
#
# Infections generated by person 1378:
# {9: 1, 24: 1, 41: 1, 58: 1, 59: 1, 60: 1, 61: 1, 79: 1, 80: 1}
#
# Infections generated by person 1426:
# {24: 1, 33: 1, 38: 1}
#
# Infections generated by person 765:
# {6: 1}
#
# Infections generated by person 211:
# {7: 1, 14: 1}
#
# Infections generated by person 803:
# {14: 1, 32: 1, 34: 1}
#
# Infections generated by person 100:
# {7: 1}
#
# Infections generated by person 927:
# {6: 1}
#
# Infections generated by person 689:
# {17: 1}
#
# Infections generated by person 1498:
# {1: 3, 2: 3, 3: 2, 4: 3, 5: 1, 53: 1}
#
# Infections generated by person 535:
# {14: 1}
#
# Infections generated by person 368:
# {18: 1}
#
# Infections generated by person 694:
# {16: 1, 35: 1}
#
# Infections generated by person 30:
# {9: 1, 13: 1}
#
# Infections generated by person 470:
# {23: 1, 33: 1}
#
# Infections generated by person 712:
# {3: 1, 15: 1}
#
# Infections generated by person 908:
# {6: 1}
#
# Infections generated by person 1152:
# {16: 1, 42: 1}
#
# Infections generated by person 371:
# {5: 1}
#
# Infections generated by person 276:
# {4: 1, 20: 1}
#
# Infections generated by person 1394:
# {6: 1, 49: 1}
#
# Infections generated by person 1019:
# {5: 2, 7: 1, 13: 1}
#
# Infections generated by person 357:
# {5: 1, 6: 1}
#
# Infections generated by person 1256:
# {11: 1}
#
# Infections generated by person 576:
# {4: 1, 5: 1, 16: 1, 21: 1, 27: 1, 29: 1, 36: 1, 41: 1, 51: 1, 52: 1}
#
# Infections generated by person 669:
# {14: 1, 20: 1, 27: 1, 32: 1, 39: 1, 42: 1, 45: 1, 46: 2}
#
# Infections generated by person 130:
# {6: 1, 10: 1, 14: 1}
#
# Infections generated by person 263:
# {5: 1, 28: 1}
#
# Infections generated by person 596:
# {5: 1, 27: 1, 30: 2, 45: 1, 57: 1, 60: 1}
#
# Infections generated by person 1037:
# {10: 1}
#
# Infections generated by person 1188:
# {8: 1, 44: 1}
#
# Infections generated by person 1008:
# {16: 1, 31: 1, 33: 1, 35: 1}
#
# Infections generated by person 382:
# {23: 1}
#
# Infections generated by person 1046:
# {4: 2, 28: 1}
#
# Infections generated by person 208:
# {5: 1, 6: 1, 31: 1}
#
# Infections generated by person 777:
# {24: 1}
#
# Infections generated by person 1193:
# {13: 1}
#
# Infections generated by person 1297:
# {5: 2}
#
# Infections generated by person 874:
# {24: 1, 38: 1}
#
# Infections generated by person 679:
# {5: 2, 6: 2}
#
# Infections generated by person 640:
# {12: 1, 22: 1}
#
# Infections generated by person 910:
# {5: 1}
#
# Infections generated by person 1051:
# {3: 3}
#
# Infections generated by person 488:
# {5: 1, 6: 3}
#
# Infections generated by person 492:
# {4: 3, 5: 1, 6: 1}
#
# Infections generated by person 1185:
# {7: 1, 20: 1, 28: 1, 35: 2, 41: 1}
#
# Infections generated by person 183:
# {7: 1}
#
# Infections generated by person 253:
# {8: 1}
#
# Infections generated by person 1496:
# {1: 2, 2: 3, 3: 3, 4: 4, 28: 1}
#
# Infections generated by person 929:
# {8: 1}
#
# Infections generated by person 986:
# {19: 2}
#
# Infections generated by person 1361:
# {6: 1, 18: 1}
#
# Infections generated by person 1481:
# {2: 1, 5: 2, 16: 1, 27: 1, 46: 1}
#
# Infections generated by person 1163:
# {7: 1}
#
# Infections generated by person 89:
# {30: 1}
#
# Infections generated by person 720:
# {4: 2, 5: 1}
#
# Infections generated by person 438:
# {5: 1, 17: 1, 20: 1, 34: 1}
#
# Infections generated by person 1126:
# {7: 1}
#
# Infections generated by person 1202:
# {8: 1}
#
# Infections generated by person 1377:
# {5: 2, 6: 1}
#
# Infections generated by person 1406:
# {6: 1}
#
# Infections generated by person 677:
# {13: 1}
#
# Infections generated by person 710:
# {7: 1, 23: 1, 53: 1}
#
# Infections generated by person 737:
# {11: 1, 92: 1}
#
# Infections generated by person 450:
# {10: 1, 29: 1}
#
# Infections generated by person 179:
# {11: 1}
#
# Infections generated by person 1449:
# {3: 1, 4: 1}
#
# Infections generated by person 127:
# {32: 1}
#
# Infections generated by person 250:
# {20: 1, 25: 1, 43: 1}
#
# Infections generated by person 1147:
# {4: 1, 14: 1, 26: 1}
#
# Infections generated by person 1200:
# {6: 1}
#
# Infections generated by person 736:
# {6: 1}
#
# Infections generated by person 967:
# {5: 1, 6: 1}
#
# Infections generated by person 1331:
# {25: 1, 27: 1}
#
# Infections generated by person 447:
# {13: 1, 36: 1, 41: 1}
#
# Infections generated by person 434:
# {6: 2, 13: 1}
#
# Infections generated by person 63:
# {6: 1, 7: 1}
#
# Infections generated by person 1122:
# {4: 2, 5: 1, 6: 1, 18: 1}
#
# Infections generated by person 788:
# {20: 1, 30: 1, 35: 1}
#
# Infections generated by person 1445:
# {4: 2}
#
# Infections generated by person 1295:
# {5: 1, 6: 1, 10: 1}
#
# Infections generated by person 895:
# {21: 1, 36: 1, 45: 1, 53: 1, 55: 1, 59: 1, 65: 1, 69: 1, 78: 1, 81: 1, 83: 1, 85: 1, 106: 1}
#
# Infections generated by person 58:
# {4: 3, 5: 3, 35: 1, 52: 1}
#
# Infections generated by person 531:
# {21: 1}
#
# Infections generated by person 1402:
# {4: 2}
#
# Infections generated by person 516:
# {16: 1, 24: 1}
#
# Infections generated by person 73:
# {8: 1, 19: 1}
#
# Infections generated by person 1391:
# {8: 1}
#
# Infections generated by person 459:
# {5: 1, 7: 1, 39: 1}
#
# Infections generated by person 36:
# {18: 1}
#
# Infections generated by person 760:
# {24: 1}
#
# Infections generated by person 982:
# {2: 3, 4: 1}
#
# Infections generated by person 33:
# {4: 1, 10: 1}
#
# Infections generated by person 987:
# {4: 1, 20: 1, 29: 1, 30: 1, 32: 1, 35: 1, 36: 1, 39: 1}
#
# Infections generated by person 960:
# {4: 2}
#
# Infections generated by person 1281:
# {24: 2}
#
# Infections generated by person 686:
# {17: 1}
#
# Infections generated by person 817:
# {12: 1}
#
# Infections generated by person 294:
# {6: 1, 8: 1}
#
# Infections generated by person 436:
# {37: 1}
#
# Infections generated by person 352:
# {13: 1}
#
# Infections generated by person 756:
# {10: 1, 45: 1}
#
# Infections generated by person 214:
# {5: 1, 19: 1, 22: 1}
#
# Infections generated by person 698:
# {5: 1, 6: 1, 23: 1}
#
# Infections generated by person 397:
# {5: 1, 6: 2}
#
# Infections generated by person 1374:
# {6: 1, 28: 1, 104: 1}
#
# Infections generated by person 573:
# {3: 2, 4: 2, 5: 1, 6: 2}
#
# Infections generated by person 1213:
# {6: 2}
#
# Infections generated by person 80:
# {8: 1}
#
# Infections generated by person 405:
# {3: 1, 4: 1}
#
# Infections generated by person 1099:
# {43: 1, 45: 1, 53: 1}
#
# Infections generated by person 312:
# {13: 1, 19: 1, 31: 1, 46: 1}
#
# Infections generated by person 1077:
# {20: 1}
#
# Infections generated by person 632:
# {5: 1}
#
# Infections generated by person 307:
# {3: 1, 4: 1}
#
# Infections generated by person 345:
# {4: 3, 5: 1, 6: 2}
#
# Infections generated by person 1249:
# {9: 1, 16: 1}
#
# Infections generated by person 1108:
# {6: 1, 17: 1, 22: 1}
#
# Infections generated by person 778:
# {12: 2}
#
# Infections generated by person 464:
# {7: 1}
#
# Infections generated by person 919:
# {17: 1}
#
# Infections generated by person 1014:
# {35: 1}
#
# Infections generated by person 901:
# {7: 2}
#
# Infections generated by person 1290:
# {12: 1}
#
# Infections generated by person 1405:
# {8: 1}
#
# Infections generated by person 920:
# {4: 1, 18: 1}
#
# Infections generated by person 1363:
# {10: 1}
#
# Infections generated by person 1195:
# {4: 1, 51: 1, 54: 1, 66: 1}
#
# Infections generated by person 612:
# {5: 2}
#
# Infections generated by person 1246:
# {12: 1, 15: 1}
#
# Infections generated by person 629:
# {22: 1, 23: 1}
#
# Infections generated by person 567:
# {5: 2, 6: 1}
#
# Infections generated by person 659:
# {6: 2}
#
# Infections generated by person 256:
# {2: 1, 3: 1, 10: 1, 28: 1}
#
# Infections generated by person 1368:
# {5: 2}
#
# Infections generated by person 939:
# {7: 2}
#
# Infections generated by person 429:
# {6: 1, 9: 1, 19: 1, 27: 1}
#
# Infections generated by person 422:
# {32: 1, 39: 1}
#
# Infections generated by person 78:
# {5: 1, 6: 1, 33: 1, 41: 1}
#
# Infections generated by person 798:
# {11: 1}
#
# Infections generated by person 688:
# {32: 1}
#
# Infections generated by person 1138:
# {6: 1}
#
# Infections generated by person 305:
# {3: 2, 10: 1, 15: 1, 18: 1}
#
# Infections generated by person 1250:
# {2: 1, 3: 5, 4: 1, 5: 1, 35: 2}
#
# Infections generated by person 1266:
# {5: 1}
#
# Infections generated by person 620:
# {18: 1, 36: 1, 53: 1}
#
# Infections generated by person 154:
# {9: 1}
#
# Infections generated by person 86:
# {12: 1}
#
# Infections generated by person 1358:
# {5: 1, 27: 1}
#
# Infections generated by person 254:
# {36: 1}
#
# Infections generated by person 194:
# {24: 1}
#
# Infections generated by person 177:
# {11: 1, 86: 1}
#
# Infections generated by person 805:
# {18: 1, 20: 1, 23: 1, 37: 1}
#
# Infections generated by person 1208:
# {6: 1}
#
# Infections generated by person 1489:
# {1: 1}
#
# Infections generated by person 1454:
# {1: 2}
#
# Infections generated by person 811:
# {6: 1}
#
# Infections generated by person 480:
# {4: 3, 13: 1, 21: 1, 29: 1, 30: 1, 36: 1, 55: 1, 56: 1, 60: 1, 61: 1, 71: 1, 98: 1}
#
# Infections generated by person 1023:
# {5: 1, 51: 1}
#
# Infections generated by person 543:
# {2: 3, 3: 1}
#
# Infections generated by person 142:
# {8: 1}
#
# Infections generated by person 624:
# {8: 1}
#
# Infections generated by person 1388:
# {27: 1, 102: 1}
#
# Infections generated by person 342:
# {6: 1}
#
# Infections generated by person 1141:
# {5: 2}
#
# Infections generated by person 1395:
# {14: 1}
#
# Infections generated by person 462:
# {6: 1, 23: 1, 31: 1}
#
# Infections generated by person 400:
# {5: 1}
#
# Infections generated by person 1301:
# {32: 1}
#
# Infections generated by person 502:
# {4: 1}
#
# Infections generated by person 1431:
# {7: 1}
#
# Infections generated by person 1315:
# {16: 1}
#
# Infections generated by person 626:
# {14: 1}
#
# Infections generated by person 46:
# {14: 1, 17: 1, 21: 1}
#
# Infections generated by person 1304:
# {5: 1}
#
# Infections generated by person 1465:
# {2: 1, 3: 2, 5: 1, 17: 1, 19: 1}
#
# Infections generated by person 15:
# {7: 3}
#
# Infections generated by person 655:
# {5: 3, 11: 1}
#
# Infections generated by person 498:
# {3: 1, 4: 1}
#
# Infections generated by person 893:
# {5: 1, 6: 1}
#
# Infections generated by person 1140:
# {11: 1, 18: 1}
#
# Infections generated by person 1299:
# {6: 1}
#
# Infections generated by person 785:
# {6: 1}
#
# Infections generated by person 1320:
# {4: 2}
#
# Infections generated by person 119:
# {6: 1, 7: 1, 11: 2}
#
# Infections generated by person 602:
# {15: 1}
#
# Infections generated by person 1261:
# {5: 2}
#
# Infections generated by person 1232:
# {34: 1}
#
# Infections generated by person 565:
# {5: 3, 28: 1, 60: 1, 72: 1}
#
# Infections generated by person 1500:
# {1: 1, 2: 3, 3: 2}
#
# Infections generated by person 77:
# {22: 1}
#
# Infections generated by person 1482:
# {2: 1}
#
# Infections generated by person 591:
# {6: 1}
#
# Infections generated by person 475:
# {7: 1}
#
# Infections generated by person 1495:
# {1: 2, 2: 1, 3: 1, 4: 2, 20: 1, 22: 1, 32: 1}
#
# Infections generated by person 210:
# {5: 1, 6: 3, 7: 2}
#
# Infections generated by person 117:
# {5: 2}
#
# Infections generated by person 770:
# {5: 2, 25: 1, 34: 1, 41: 1, 56: 1, 61: 1, 75: 1, 77: 1, 84: 1, 85: 1}
#
# Infections generated by person 1392:
# {25: 1, 29: 2}
#
# Infections generated by person 724:
# {6: 1}
#
# Infections generated by person 585:
# {12: 1, 21: 1, 22: 1, 23: 1, 27: 1, 29: 1, 31: 1, 32: 1, 33: 1, 34: 1, 37: 1, 55: 1}
#
# Infections generated by person 871:
# {6: 2, 7: 1}
#
# Infections generated by person 1146:
# {6: 1, 48: 1}
#
# Infections generated by person 782:
# {18: 1, 19: 1}
#
# Infections generated by person 692:
# {7: 1, 22: 1, 37: 1, 48: 1}
#
# Infections generated by person 351:
# {6: 1}
#
# Infections generated by person 426:
# {7: 2}
#
# Infections generated by person 324:
# {25: 1}
#
# Infections generated by person 1464:
# {16: 1, 30: 1, 35: 1}
#
# Infections generated by person 4:
# {24: 1}
#
# Infections generated by person 1419:
# {27: 1, 45: 1}
#
# Infections generated by person 683:
# {4: 5, 5: 2, 6: 1}
#
# Infections generated by person 122:
# {5: 1, 8: 1}
#
# Infections generated by person 548:
# {12: 1}
#
# Infections generated by person 437:
# {13: 1}
#
# Infections generated by person 83:
# {13: 1, 34: 1}
#
# Infections generated by person 354:
# {4: 2}
#
# Infections generated by person 268:
# {14: 1}
#
# Infections generated by person 773:
# {12: 1}
#
# Infections generated by person 25:
# {7: 1}
#
# Infections generated by person 1384:
# {14: 1}
#
# Infections generated by person 1397:
# {6: 1, 27: 1}
#
# Infections generated by person 1030:
# {4: 2, 6: 1}
#
# Infections generated by person 935:
# {7: 1}
#
# Infections generated by person 888:
# {3: 2, 4: 2, 13: 1, 33: 1, 35: 1, 40: 1}
#
# Infections generated by person 1061:
# {22: 1, 24: 1}
#
# Infections generated by person 241:
# {6: 1}
#
# Infections generated by person 1181:
# {24: 1, 37: 1}
#
# Infections generated by person 575:
# {5: 1, 16: 1}
#
# Infections generated by person 1017:
# {5: 1, 14: 1}
#
# Infections generated by person 1463:
# {16: 1, 18: 1, 20: 1, 27: 1, 32: 1}
#
# Infections generated by person 106:
# {8: 1, 16: 1}
#
# Infections generated by person 588:
# {3: 1, 4: 2}
#
# Infections generated by person 489:
# {4: 1, 5: 1}
#
# Infections generated by person 321:
# {5: 1}
#
# Infections generated by person 1327:
# {4: 1}
#
# Infections generated by person 1413:
# {2: 1}
#
# Infections generated by person 764:
# {5: 1, 6: 1, 17: 1, 21: 2, 25: 1}
#
# Infections generated by person 99:
# {35: 1, 44: 1}
#
# Infections generated by person 1024:
# {5: 2}
#
# Infections generated by person 1089:
# {12: 1}
#
# Infections generated by person 794:
# {5: 1, 22: 1}
#
# Infections generated by person 386:
# {16: 1}
#
# Infections generated by person 138:
# {3: 2, 4: 2}
#
# Infections generated by person 313:
# {20: 1}
#
# Infections generated by person 325:
# {32: 1}
#
# Infections generated by person 1263:
# {5: 1, 18: 1, 22: 1}
#
# Infections generated by person 815:
# {7: 1}
#
# Infections generated by person 1216:
# {6: 2}
#
# Infections generated by person 696:
# {5: 2, 6: 1}
#
# Infections generated by person 769:
# {14: 1}
#
# Infections generated by person 442:
# {14: 1}
#
# Infections generated by person 164:
# {9: 1, 22: 1}
#
# Infections generated by person 430:
# {4: 4}
#
# Infections generated by person 515:
# {14: 1, 18: 1, 23: 1}
#
# Infections generated by person 172:
# {34: 1}
#
# Infections generated by person 1452:
# {2: 1, 3: 1, 4: 1, 27: 1, 30: 1}
#
# Infections generated by person 487:
# {5: 1}
#
# Infections generated by person 886:
# {2: 1, 4: 1, 5: 1, 6: 2}
#
# Infections generated by person 315:
# {16: 1}
#
# Infections generated by person 671:
# {11: 1, 42: 1}
#
# Infections generated by person 942:
# {16: 1}
#
# Infections generated by person 945:
# {5: 1}
#
# Infections generated by person 653:
# {5: 2, 9: 1}
#
# Infections generated by person 529:
# {18: 1, 19: 1, 34: 2, 44: 1, 52: 1}
#
# Infections generated by person 943:
# {14: 1}
#
# Infections generated by person 193:
# {5: 1, 6: 1, 7: 1, 12: 1}
#
# Infections generated by person 714:
# {42: 1, 62: 1}
#
# Infections generated by person 1180:
# {50: 1, 64: 1}
#
# Infections generated by person 201:
# {11: 1}
#
# Infections generated by person 604:
# {5: 1, 6: 1}
#
# Infections generated by person 469:
# {18: 1, 20: 1, 23: 1}
#
# Infections generated by person 17:
# {6: 1, 36: 1, 38: 1, 90: 1, 114: 1}
#
# Infections generated by person 1168:
# {4: 1, 12: 1}
#
# Infections generated by person 332:
# {6: 1, 17: 1, 29: 1}
#
# Infections generated by person 74:
# {5: 1, 7: 1}
#
# Infections generated by person 410:
# {5: 1, 18: 1}
#
# Infections generated by person 339:
# {6: 1, 8: 1}
#
# Infections generated by person 264:
# {28: 1}
#
# Infections generated by person 824:
# {7: 1, 39: 1}
#
# Infections generated by person 377:
# {4: 1}

# %% [markdown]
# ### Infections

# %%
for person in Population_2:
    if len(person.infections) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(sum(person.infections.values()))
# Out:
# Infections generated by person 1369:
# 2
#
# Infections generated by person 1120:
# 1
#
# Infections generated by person 936:
# 3
#
# Infections generated by person 734:
# 8
#
# Infections generated by person 62:
# 3
#
# Infections generated by person 1016:
# 2
#
# Infections generated by person 1093:
# 2
#
# Infections generated by person 340:
# 1
#
# Infections generated by person 362:
# 1
#
# Infections generated by person 45:
# 1
#
# Infections generated by person 310:
# 1
#
# Infections generated by person 1453:
# 3
#
# Infections generated by person 191:
# 1
#
# Infections generated by person 66:
# 2
#
# Infections generated by person 53:
# 2
#
# Infections generated by person 1136:
# 3
#
# Infections generated by person 225:
# 1
#
# Infections generated by person 238:
# 2
#
# Infections generated by person 439:
# 3
#
# Infections generated by person 274:
# 2
#
# Infections generated by person 657:
# 3
#
# Infections generated by person 1432:
# 4
#
# Infections generated by person 258:
# 2
#
# Infections generated by person 1314:
# 4
#
# Infections generated by person 1050:
# 2
#
# Infections generated by person 646:
# 3
#
# Infections generated by person 104:
# 2
#
# Infections generated by person 417:
# 4
#
# Infections generated by person 124:
# 4
#
# Infections generated by person 642:
# 3
#
# Infections generated by person 1476:
# 5
#
# Infections generated by person 840:
# 3
#
# Infections generated by person 797:
# 1
#
# Infections generated by person 94:
# 1
#
# Infections generated by person 1323:
# 1
#
# Infections generated by person 759:
# 2
#
# Infections generated by person 1271:
# 2
#
# Infections generated by person 403:
# 1
#
# Infections generated by person 750:
# 5
#
# Infections generated by person 1132:
# 1
#
# Infections generated by person 1437:
# 5
#
# Infections generated by person 974:
# 8
#
# Infections generated by person 732:
# 1
#
# Infections generated by person 546:
# 1
#
# Infections generated by person 1101:
# 2
#
# Infections generated by person 1004:
# 6
#
# Infections generated by person 413:
# 2
#
# Infections generated by person 932:
# 3
#
# Infections generated by person 745:
# 15
#
# Infections generated by person 370:
# 5
#
# Infections generated by person 1189:
# 5
#
# Infections generated by person 1159:
# 2
#
# Infections generated by person 321:
# 1
#
# Infections generated by person 1327:
# 1
#
# Infections generated by person 1413:
# 1
#
# Infections generated by person 764:
# 6
#
# Infections generated by person 99:
# 2
#
# Infections generated by person 1024:
# 2
#
# Infections generated by person 1089:
# 1
#
# Infections generated by person 794:
# 2
#
# Infections generated by person 386:
# 1
#
# Infections generated by person 138:
# 4
#
# Infections generated by person 313:
# 1
#
# Infections generated by person 325:
# 1
#
# Infections generated by person 1263:
# 3
#
# Infections generated by person 815:
# 1
#
# Infections generated by person 1216:
# 2
#
# Infections generated by person 696:
# 3
#
# Infections generated by person 769:
# 1
#
# Infections generated by person 442:
# 1
#
# Infections generated by person 164:
# 2
#
# Infections generated by person 430:
# 4
#
# Infections generated by person 515:
# 3
#
# Infections generated by person 172:
# 1
#
# Infections generated by person 1452:
# 5
#
# Infections generated by person 487:
# 1
#
# Infections generated by person 886:
# 5
#
# Infections generated by person 315:
# 1
#
# Infections generated by person 671:
# 2
#
# Infections generated by person 942:
# 1
#
# Infections generated by person 945:
# 1
#
# Infections generated by person 653:
# 3
#
# Infections generated by person 529:
# 6
#
# Infections generated by person 943:
# 1
#
# Infections generated by person 193:
# 4
#
# Infections generated by person 714:
# 2
#
# Infections generated by person 1180:
# 2
#
# Infections generated by person 201:
# 1
#
# Infections generated by person 604:
# 2
#
# Infections generated by person 469:
# 3
#
# Infections generated by person 17:
# 5
#
# Infections generated by person 1168:
# 2
#
# Infections generated by person 332:
# 3
#
# Infections generated by person 74:
# 2
#
# Infections generated by person 410:
# 2
#
# Infections generated by person 339:
# 2
#
# Infections generated by person 264:
# 1
#
# Infections generated by person 824:
# 2
#
# Infections generated by person 377:
# 1

# %%
def final_populations_2(Population):
    """Counts de number of susceptible, infected, and recovered individuals at the
    end of the simulation.
        
    This function receives as parameter the list of the population after the simulation 
    has been run. It counts the number of susceptible, infected, and recovered individuals 
    at the end of the simulation and prints them.
        
    Parameters
    ----------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 

    """
    S12f = 0; I1f = 0; I2f = 0; R1f = 0; R2f = 0;
    S1f = 0; S2f = 0; I12f = 0; I21f = 0; R12f = 0;
    for person in Population:
        if person.status[T] == 'S12':
            S12f += 1
        elif person.status[T] == 'I1':
            I1f += 1
        elif person.status[T] == 'I2':
            I2f += 1
        elif person.status[T] == 'R1':
            R1f += 1
        elif person.status[T] == 'R2':
            R2f += 1
        elif person.status[T] == 'S1':
            S1f += 1
        elif person.status[T] == 'S2':
            S2f += 1
        elif person.status[T] == 'I12':
            I12f += 1
        elif person.status[T] == 'I21':
            I21f += 1
        else:
            R12f += 1
    print("S12: {}\nI1: {}\nI2: {}\nR1: {}\nR2: {}".format(S12f,I1f,I2f,R1f,R2f))
    print("S1: {}\nS2: {}\nI12: {}\nI21: {}\nR12: {}".format(S1f,S2f,I12f,I21f,R12f))

final_populations_2(Population_2)
# Out:
# S12: 0
# I1: 0
# I2: 0
# R1: 0
# R2: 0
# S1: 192
# S2: 17
# I12: 0
# I21: 0
# R12: 1291

# %%
def Plot_Dynamics_21(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S12 = []; I1 = []; I2 = []; R1 = []; R2 = [];
    S1 = []; S2 = []; I12 = []; I21 = []; R12 = [];
    for t in range(T+1):
        S12t = 0; I1t = 0; I2t = 0; R1t = 0; R2t = 0;
        S1t = 0; S2t = 0; I12t = 0; I21t = 0; R12t = 0;
        for person in simulation:
            if person.status[t] == 'S12':
                S12t += 1
            elif person.status[t] == 'I1':
                I1t += 1
            elif person.status[t] == 'I2':
                I2t += 1
            elif person.status[t] == 'R1':
                R1t += 1
            elif person.status[t] == 'R2':
                R2t += 1
            elif person.status[t] == 'S1':
                S1t += 1
            elif person.status[t] == 'S2':
                S2t += 1
            elif person.status[t] == 'I12':
                I12t += 1
            elif person.status[t] == 'I21':
                I21t += 1
            else:
                R12t += 1
        
        S12.append(S12t)
        I1.append(I1t)
        I2.append(I2t)
        R1.append(R1t)
        R2.append(R2t)
        S1.append(S1t)
        S2.append(S2t)
        I12.append(I12t)
        I21.append(I21t)
        R12.append(R12t)

    plt.plot(range(T+1), S12, label = 'S12')
    plt.plot(range(T+1), I1, label = 'I1')
    plt.plot(range(T+1), I2, label = 'I2')
    plt.plot(range(T+1), R1, label = 'R1')
    plt.plot(range(T+1), R2, label = 'R2')
    plt.plot(range(T+1), S1, label = 'S1')
    plt.plot(range(T+1), S2, label = 'S2')
    plt.plot(range(T+1), I12, label = 'I12')
    plt.plot(range(T+1), I21, label = 'I21')
    plt.plot(range(T+1), R12, label = 'R12')
    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()
    
Plot_Dynamics_21(Population_2, T)

# %%
def Plot_Dynamics_22(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S = []; I = []; R = [];
    for t in range(T+1):
        St = 0; It = 0; Rt = 0
        for person in simulation:
            if person.status[t] == 'S12':
                St += 1
            elif person.status[t] == 'I1':
                It += 1
            elif person.status[t] == 'I2':
                It += 1
            elif person.status[t] == 'R1':
                Rt += 1
            elif person.status[t] == 'R2':
                Rt += 1
            elif person.status[t] == 'S1':
                St += 1
            elif person.status[t] == 'S2':
                St += 1
            elif person.status[t] == 'I12':
                It += 1
            elif person.status[t] == 'I21':
                It += 1
            else:
                Rt += 1
        
        S.append(St)
        I.append(It)
        R.append(Rt)


    plt.plot(range(T+1), S, "b-",label = 'S')
    plt.plot(range(T+1), I, "r-",label = 'I')
    plt.plot(range(T+1), R, "k-",label = 'R')

    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()
    
Plot_Dynamics_22(Population_2, T)
