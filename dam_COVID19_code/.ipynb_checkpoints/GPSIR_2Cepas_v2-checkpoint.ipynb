# %% [markdown]
# # GPSIR defined with classes

# %%
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Definition of Some Random Variables

# %%
def Bernoulli(p):
    """Simulates a random variable with Bernoulli distribution
    with parameter p.
        
    Parameters
    ----------
    p : float
        The parameter of the Bernoulli distribution.

    Returns
    -------
    int
        0 or 1 depending of the result of the experiment
        
    """
    u = random.random()
    if u < p:
        return 1
    else:
        return 0

def Geometric(p):
    """Simulates a random variable with Gemoetric distribution
    with probability of success p.
        
    Parameters
    ----------
    p : float
        The probability of success of a Bernoulli trial.

    Returns
    -------
    L : int
        The number L of Bernoulli trials needed to get one success.
        
    """
    L = 0
    aux = 0
    while aux == 0:
        if Bernoulli(p) == 1:
            aux = 1
        L += 1
    return L

def Constant(c):
    """Simulates a random variable, X, with constant distribution.
        
    Parameters
    ----------
    c : float
        The constant such that P(X = c) = 1.

    Returns
    -------
    c : float
        The constant such that P(X = c) = 1.
        
    """
    return c

def Uniform(limits):
    """Simulates a random variable with Uniform distribution
    over the interval [limits[0],limits[1]].
        
    Parameters
    ----------
    limits : list
        List with the lower bownd of the interval where the random
        variable is defined as first item and the upper bownd
        as second item.

    Returns
    -------
    float
        A number between [limits[0],limits[1]].
    """
    return limits[0] + (limits[1]-limits[0])*random.random()

# %% [markdown]
# ## Definition of the Class Person

# %%
class Person(object):
    """
    A class used to represent an individual participating in the dynamics of the epidemy 

    ...

    Attributes
    ----------
    contacts: dict
        An empty dictionary in which the individual's contacts are recorded 
        with the contact time as the key and a list of the individuals with 
        whom there was contact as the value.
        
    infections_s1: dict
        An empty dictionary in which the individual's contagions are recorded 
        with the contagions time as the key and thw number of  individuals that
        where infected by the individual.
        
    infections_s2: dict
        An empty dictionary in which the individual's contagions are recorded 
        with the contagions time as the key and thw number of  individuals that
        where infected by the individual.
    
    tau : int
        The number of days that the individual will be infected
        (default 0).
    
    index : int
        The index with which the person is identified.
    
    status : dict
        A dictionary in which the individual's status at each time is recorded 
        with the time as the key and the population to which it belongs.
    
    age : int
        The age of the individual.
    
    comorbidities : list
        A list with the comorbidities of the individual 
        (default an empty list []).

    Methods
    -------
    set_tau():
        Sets the number of days that the infection will last depending
        on the comorbidities of the individual.
    
    set_status(t, s):
        Adds the status, s, of the individual at time, t, to the dictionary
        estatus.
        
    set_contact(t, person):
        It adds a contact with a person at the time t to the dictionary of 
        contacts.
        
    get_contacts():
        Prints the contacts of the individual at each time showing the time of
        the contact and a tuple containing the index of the person with whom 
        there was contact and the population to which it belongs.
    """
    
    def __init__(self, index, status, age, comorbidities = []):
        """
        Parameters
        ----------
        index : int
            The index with which the person is identified.
        
        status : dict
            A dictionary in which the individual's status at each time is recorded 
            with the time as the key and the population to which it belongs.
    
        age : int
            The age of the individual.
    
        comorbidities : list
            A list with the comorbidities of the individual 
            (default an empty list []).
        """
        
        self.contacts = {}
        self.infections_s1 = {}
        self.infections_s2 = {}
        self.tau = 0
        self.index = index
        self.status = status
        self.age = age
        self.comorbidities = comorbidities
        
    def set_tau(self, distribution, parameter):
        """Sets the number of days that the infection will last depending
        on the comorbidities of the individual.
        
        Parameters
        ----------
        distribution : function
            probability distribution of the length of the infectious state for an
            individual (tau).
        parameter : float
            parameter of the probability distribution of the length of the infectious 
            state for an individual (tau).
        """
        
        self.tau = distribution(parameter)

    def set_status(self, t, s):
        """Sets the status, s, of the individual at time, t, to the dictionary
        estatus.
        
        Parameters
        ----------
        t : int
            The time for which the status will be seted.
        s : str
            The population to which it the individual belongs at time t
            (S = susceptible, I = infected, R = removed).
        """
        
        self.status[t] = s

    def set_contact(self, t, person):
        """It adds a contact with a person at the time t to the dictionary of 
        contacts.
        
        This method receives as parameters the time in which the contact was made 
        and the person with whom it was made. If there has not been a contact in 
        that time, it creates a new time key and assigns it a list with the person 
        with whom there was contact. In case there was already a contact at that time, 
        the person is added to the contacts list.
        
        Parameters
        ----------
        t : int
            The time in which the contact happened.
        person : Person
            The individual with whom there was contact.
        """

        if t in self.contacts:
            self.contacts[t].append(person)
        else:
            self.contacts[t] = [person]
            
    def add_infection_s1(self, t):
        """
        
        Parameters
        ----------
        t : int
            The time in which the ifection happened.
        """

        if t in self.infections_s1:
            self.infections_s1[t] += 1
        else:
            self.infections_s1[t] = 1
            
    def add_infection_s2(self, t):
        """
        
        Parameters
        ----------
        t : int
            The time in which the ifection happened.
        """

        if t in self.infections_s2:
            self.infections_s2[t] += 1
        else:
            self.infections_s2[t] = 1

    def get_contacts(self):
        """Prints the contacts of the individual at each time showing the time of
        the contact and a tuple containing the index of the person with whom 
        there was contact and the population to which it belongs."""
        
        print("\nContacts of person {}:".format(self.index))
        for t in self.contacts:
            s = str(t)+ " :"
            for c in self.contacts[t]:
                s += " ({},{})".format(c.index,c.status[t])
            print(s)

    def __eq__(self, other):
        """
        We overwrite the method __eq__ in orther to give sense to the boolean
        operator == in the class Persona. In orther to overwirte this method
        we recibe as parameters the object itself and other object to compare.
        The new coparison criterion is the index.
        """
        return (self.index == other.index)

# %% [markdown]
# ## 1.1 Simple Model

# %%
def GPSIR_1(S12, I10, I20, R0, T, alpha, beta1, beta2, tau_distribution = Geometric, 
          tau_parameter = 1/21, inoculation_distribution = Constant,
          inoculation_parameter = 1, inoculation_threshold = 1):
    """Simulates the dynamics of the epidemy
        
    Parameters
    ----------
    S12 : int
        Initial population of susceptible individuals.
    
    I10 : int
        Initial population of individuals infected with the 
        strain 1.
        
    I20 : int
        Initial population of individuals infected with the 
        strain 2.
    
    R0 : int
        Initial population of recovered individuals.
    
    T : int
        Number of days of the simulation.
    
    alpha: float
        Probability of formation of an edge.
    
    beta1: float
        Probability of contagion given infectious contagion of
        the strain 1.
        
    beta2: float
        Probability of contagion given infectious contagion of
        the strain 2.
    
    tau_distribution : function, optional
        Distribution of the number of days that the individual 
        will be infected (default is Gemoetric).
    
    tau_parameter: float, optional
        Parameter of the distribution of the number of days that
        the individual will be infected (default is 1/7).
        
    inoculation_distribution: function, optional
        Distribution of the viral load to which a susceptible 
        individual is exposed in an infectious contact
        (default is Constant).
        
    inoculation_parameter: float, optional
        Parameter of the distribution of the viral load to 
        which a susceptible is exposed in an infectious contact
        (default is 1).
    
    inoculation_threshold: float, optional
        Viral load threshold for contagion (default is 1).
    

    Returns
    -------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 
        
    """

    Population   = []

    # The susceptible are added to the population
    for i in range(1,S12+1):
        p = Person(i,{0:'S12'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    # The infected with strain 1 are added to the population
    for i in range(S12+1,S12+I10+1):
        p = Person(i,{0:'I1'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
        
    # The infected with strain 2 are added to the population
    for i in range(S12+I10+1,S12+I10+I20+1):
        p = Person(i,{0:'I2'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    
    # We iterate over the days of the simulation
    for t in range(1,T+1):
        
        random.shuffle(Population)
        # Iteration per day over each individual of the population
        for p1 in Population:

            # Iteration per individual over the rest of the population in 
            # orther to generate contats between individuals.
            for p2 in Population:
                if p1.status[t-1] == 'S12' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)

            # Here starts the modification of the populations S, I, and R.

            # Modifications over the Suceptible population
            if p1.status[t-1] == 'S12':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load_1 = 0
                    viral_load_2 = 0
                    
                    # for each contact we check if there was efective infection
                    temp = 0
                    
                    while temp < len(p1.contacts[t-1]) and p1.status[t-1] == 'S12':
                        
                        if p1.contacts[t-1][temp].status[t-1] == 'I1' and Bernoulli(beta1):
                            
                            viral_load_1 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I1')
                            p1.contacts[t-1][temp].add_infection_s1(t)
                            break
                            
                        elif p1.contacts[t-1][temp].status[t-1] == 'I2' and Bernoulli(beta2):
                            
                            viral_load_2 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I2')
                            p1.contacts[t-1][temp].add_infection_s2(t)
                            break
                        
                        temp += 1
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    if (viral_load_1 + viral_load_2 == 0):
                        p1.set_status(t,'S12')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S12')

            # Modifications over the Infected population
            elif p1.status[t-1] == 'I1':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I1')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R')
                    
            elif p1.status[t-1] == 'I2':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I2')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R')

            # Modifications over the Removed population
            else:
                p1.set_status(t,'R')
    
    return Population

# %% [markdown]
# ## Results

# %%
T = 100
Population_1 = GPSIR_1(500, 23, 3, 0, T, alpha = 0.1, beta1 = 0.005, beta2 = 0.015)

# %% [markdown]
# ### Final Number of Susceptible, Infectous, and Removed Individuals

# %%
def final_populations_1(Population):
    """Counts de number of susceptible, infected, and recovered individuals at the
    end of the simulation.
        
    This function receives as parameter the list of the population after the simulation 
    has been run. It counts the number of susceptible, infected, and recovered individuals 
    at the end of the simulation and prints them.
        
    Parameters
    ----------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 

    """
    S12f = 0; I1f = 0; I2f = 0; Rf = 0;
    for person in Population:
        if person.status[T] == 'S12':
            S12f += 1
        elif person.status[T] == 'I1':
            I1f += 1
        elif person.status[T] == 'I2':
            I2f += 1
        else:
            Rf += 1
    print("Susceptible: {}\nInfectious 1: {}\nInfectious 2: {}\nRemoved: {}".format(S12f,I1f,I2f,Rf))
    
final_populations_1(Population_1)
# Out:
# Susceptible: 0
# Infectious 1: 0
# Infectious 2: 7
# Removed: 519

# %% [markdown]
# ### Dynamics for Each Individual

# %%
#for person in Population_1:
#    print("\nDynamics for the individual {}:".format(person.index))
#    print(person.status)

# %% [markdown]
# ### Contacts for One Individual

# %%
#Population_1[336].get_contacts()

# %% [markdown]
# ### Infections of Strain 1 Generated by each individual indexed by time

# %%
for person in Population_1:
    if len(person.infections_s1) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(person.infections_s1)
# Out:
# Infections generated by person 520:
# {3: 1, 6: 1}
#
# Infections generated by person 513:
# {2: 1}
#
# Infections generated by person 359:
# {11: 1, 12: 1}
#
# Infections generated by person 518:
# {5: 1, 6: 1, 8: 1, 12: 1}
#
# Infections generated by person 298:
# {9: 1}
#
# Infections generated by person 502:
# {4: 1, 6: 1}
#
# Infections generated by person 164:
# {8: 1}
#
# Infections generated by person 61:
# {8: 1}
#
# Infections generated by person 390:
# {9: 1}
#
# Infections generated by person 198:
# {11: 1}
#
# Infections generated by person 214:
# {7: 2, 8: 1}
#
# Infections generated by person 418:
# {5: 1, 6: 1, 7: 1}
#
# Infections generated by person 127:
# {8: 1, 19: 1}
#
# Infections generated by person 514:
# {3: 1}
#
# Infections generated by person 478:
# {3: 3}
#
# Infections generated by person 233:
# {15: 1}
#
# Infections generated by person 62:
# {6: 1}
#
# Infections generated by person 516:
# {1: 1}
#
# Infections generated by person 89:
# {5: 1, 8: 1, 9: 1}
#
# Infections generated by person 15:
# {12: 1}
#
# Infections generated by person 102:
# {5: 1}
#
# Infections generated by person 256:
# {5: 1}
#
# Infections generated by person 335:
# {8: 1}
#
# Infections generated by person 323:
# {8: 1}
#
# Infections generated by person 510:
# {2: 1, 10: 1}
#
# Infections generated by person 495:
# {13: 1}
#
# Infections generated by person 473:
# {13: 1}
#
# Infections generated by person 503:
# {3: 2}
#
# Infections generated by person 521:
# {6: 2, 9: 1}
#
# Infections generated by person 215:
# {12: 1}
#
# Infections generated by person 185:
# {7: 1}
#
# Infections generated by person 199:
# {8: 2, 11: 1}
#
# Infections generated by person 504:
# {5: 1}
#
# Infections generated by person 190:
# {13: 1}
#
# Infections generated by person 438:
# {9: 1}
#
# Infections generated by person 318:
# {6: 1, 7: 1}
#
# Infections generated by person 77:
# {15: 1}
#
# Infections generated by person 515:
# {8: 1, 10: 1}
#
# Infections generated by person 177:
# {9: 1}
#
# Infections generated by person 511:
# {7: 1, 11: 1, 13: 1}
#
# Infections generated by person 267:
# {10: 1}
#
# Infections generated by person 105:
# {8: 1}
#
# Infections generated by person 519:
# {5: 2}
#
# Infections generated by person 325:
# {3: 1}
#
# Infections generated by person 170:
# {12: 1}
#
# Infections generated by person 268:
# {8: 1}
#
# Infections generated by person 122:
# {7: 1, 9: 2}
#
# Infections generated by person 512:
# {2: 1, 9: 2}
#
# Infections generated by person 183:
# {9: 1}
#
# Infections generated by person 13:
# {10: 1}
#
# Infections generated by person 311:
# {12: 1}
#
# Infections generated by person 247:
# {6: 1}
#
# Infections generated by person 509:
# {4: 1}
#
# Infections generated by person 205:
# {10: 1}
#
# Infections generated by person 451:
# {13: 1}
#
# Infections generated by person 293:
# {10: 2}
#
# Infections generated by person 523:
# {2: 1, 3: 1, 13: 1}
#
# Infections generated by person 27:
# {9: 1}
#
# Infections generated by person 150:
# {16: 1}
#
# Infections generated by person 378:
# {15: 1}
#
# Infections generated by person 508:
# {3: 1}
#
# Infections generated by person 408:
# {14: 1}
#
# Infections generated by person 517:
# {5: 1, 8: 1, 13: 1}
#
# Infections generated by person 501:
# {6: 2, 9: 1}
#
# Infections generated by person 78:
# {14: 1}
#
# Infections generated by person 482:
# {11: 1}
#
# Infections generated by person 349:
# {8: 1}

# %% [markdown]
# ### Infections of Strain 1 Generated by each individual

# %%
for person in Population_1:
    if len(person.infections_s1) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(sum(person.infections_s1.values()))
# Out:
# Infections generated by person 520:
# 2
#
# Infections generated by person 513:
# 1
#
# Infections generated by person 359:
# 2
#
# Infections generated by person 518:
# 4
#
# Infections generated by person 298:
# 1
#
# Infections generated by person 502:
# 2
#
# Infections generated by person 164:
# 1
#
# Infections generated by person 61:
# 1
#
# Infections generated by person 390:
# 1
#
# Infections generated by person 198:
# 1
#
# Infections generated by person 214:
# 3
#
# Infections generated by person 418:
# 3
#
# Infections generated by person 127:
# 2
#
# Infections generated by person 514:
# 1
#
# Infections generated by person 478:
# 3
#
# Infections generated by person 233:
# 1
#
# Infections generated by person 62:
# 1
#
# Infections generated by person 516:
# 1
#
# Infections generated by person 89:
# 3
#
# Infections generated by person 15:
# 1
#
# Infections generated by person 102:
# 1
#
# Infections generated by person 256:
# 1
#
# Infections generated by person 335:
# 1
#
# Infections generated by person 323:
# 1
#
# Infections generated by person 510:
# 2
#
# Infections generated by person 495:
# 1
#
# Infections generated by person 473:
# 1
#
# Infections generated by person 503:
# 2
#
# Infections generated by person 521:
# 3
#
# Infections generated by person 215:
# 1
#
# Infections generated by person 185:
# 1
#
# Infections generated by person 199:
# 3
#
# Infections generated by person 504:
# 1
#
# Infections generated by person 190:
# 1
#
# Infections generated by person 438:
# 1
#
# Infections generated by person 318:
# 2
#
# Infections generated by person 77:
# 1
#
# Infections generated by person 515:
# 2
#
# Infections generated by person 177:
# 1
#
# Infections generated by person 511:
# 3
#
# Infections generated by person 267:
# 1
#
# Infections generated by person 105:
# 1
#
# Infections generated by person 519:
# 2
#
# Infections generated by person 325:
# 1
#
# Infections generated by person 170:
# 1
#
# Infections generated by person 268:
# 1
#
# Infections generated by person 122:
# 3
#
# Infections generated by person 512:
# 3
#
# Infections generated by person 183:
# 1
#
# Infections generated by person 13:
# 1
#
# Infections generated by person 311:
# 1
#
# Infections generated by person 247:
# 1
#
# Infections generated by person 509:
# 1
#
# Infections generated by person 205:
# 1
#
# Infections generated by person 451:
# 1
#
# Infections generated by person 293:
# 2
#
# Infections generated by person 523:
# 3
#
# Infections generated by person 27:
# 1
#
# Infections generated by person 150:
# 1
#
# Infections generated by person 378:
# 1
#
# Infections generated by person 508:
# 1
#
# Infections generated by person 408:
# 1
#
# Infections generated by person 517:
# 3
#
# Infections generated by person 501:
# 3
#
# Infections generated by person 78:
# 1
#
# Infections generated by person 482:
# 1
#
# Infections generated by person 349:
# 1

# %% [markdown]
# ### Infections of Strain 2 Generated by each individual indexed by time

# %%
for person in Population_1:
    if len(person.infections_s2) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(person.infections_s2)
# Out:
# Infections generated by person 63:
# {9: 1, 10: 1}
#
# Infections generated by person 14:
# {13: 1}
#
# Infections generated by person 334:
# {8: 1, 9: 1, 10: 1, 12: 1}
#
# Infections generated by person 274:
# {13: 1}
#
# Infections generated by person 30:
# {6: 1, 14: 1}
#
# Infections generated by person 22:
# {13: 1, 15: 1}
#
# Infections generated by person 302:
# {10: 1, 11: 1}
#
# Infections generated by person 341:
# {15: 1}
#
# Infections generated by person 440:
# {9: 1, 11: 1}
#
# Infections generated by person 255:
# {17: 1}
#
# Infections generated by person 82:
# {6: 1, 8: 2, 10: 1}
#
# Infections generated by person 18:
# {11: 1}
#
# Infections generated by person 43:
# {9: 1}
#
# Infections generated by person 158:
# {10: 1, 12: 1, 17: 1}
#
# Infections generated by person 287:
# {9: 1, 12: 1}
#
# Infections generated by person 347:
# {13: 1}
#
# Infections generated by person 106:
# {11: 1}
#
# Infections generated by person 59:
# {9: 2, 12: 2}
#
# Infections generated by person 289:
# {7: 1, 8: 1, 9: 1, 10: 1, 12: 1}
#
# Infections generated by person 252:
# {14: 1}
#
# Infections generated by person 266:
# {12: 1}
#
# Infections generated by person 294:
# {8: 1, 10: 1, 12: 1, 15: 1}
#
# Infections generated by person 235:
# {9: 2, 10: 1}
#
# Infections generated by person 2:
# {11: 1}
#
# Infections generated by person 489:
# {14: 1}
#
# Infections generated by person 493:
# {7: 3, 8: 1, 11: 1}
#
# Infections generated by person 141:
# {14: 1}
#
# Infections generated by person 148:
# {8: 1, 12: 1, 13: 1}
#
# Infections generated by person 281:
# {16: 1}
#
# Infections generated by person 413:
# {11: 1, 14: 2}
#
# Infections generated by person 91:
# {4: 1, 5: 2, 6: 1, 9: 1, 14: 1}
#
# Infections generated by person 409:
# {9: 3}
#
# Infections generated by person 483:
# {9: 1, 11: 1}
#
# Infections generated by person 262:
# {12: 1}
#
# Infections generated by person 296:
# {7: 1, 9: 1}
#
# Infections generated by person 524:
# {3: 1, 4: 1, 7: 1, 13: 2}
#
# Infections generated by person 452:
# {10: 1, 12: 2}
#
# Infections generated by person 209:
# {11: 2}
#
# Infections generated by person 301:
# {8: 1, 9: 1, 10: 1}
#
# Infections generated by person 485:
# {17: 1}
#
# Infections generated by person 120:
# {13: 1}
#
# Infections generated by person 94:
# {12: 1}
#
# Infections generated by person 184:
# {13: 1}
#
# Infections generated by person 439:
# {8: 1, 9: 1, 11: 1, 12: 1}
#
# Infections generated by person 200:
# {13: 1, 14: 1}
#
# Infections generated by person 117:
# {10: 1, 15: 1}
#
# Infections generated by person 4:
# {9: 1, 10: 2, 11: 2, 12: 1, 14: 1}
#
# Infections generated by person 72:
# {10: 1, 11: 1, 12: 1, 14: 1}
#
# Infections generated by person 95:
# {10: 1}
#
# Infections generated by person 336:
# {10: 1}
#
# Infections generated by person 410:
# {15: 1}
#
# Infections generated by person 191:
# {5: 2, 7: 1, 8: 1}
#
# Infections generated by person 457:
# {15: 1}
#
# Infections generated by person 388:
# {8: 1, 11: 1}
#
# Infections generated by person 253:
# {9: 1, 11: 1}
#
# Infections generated by person 288:
# {18: 1}
#
# Infections generated by person 437:
# {12: 1}
#
# Infections generated by person 313:
# {8: 1, 9: 1}
#
# Infections generated by person 96:
# {15: 1}
#
# Infections generated by person 40:
# {11: 2, 15: 1}
#
# Infections generated by person 49:
# {3: 1, 4: 1, 8: 1}
#
# Infections generated by person 404:
# {16: 1}
#
# Infections generated by person 131:
# {11: 1}
#
# Infections generated by person 295:
# {10: 1}
#
# Infections generated by person 389:
# {9: 2}
#
# Infections generated by person 220:
# {9: 1}
#
# Infections generated by person 423:
# {10: 1, 11: 1}
#
# Infections generated by person 257:
# {8: 1, 13: 1, 14: 1}
#
# Infections generated by person 278:
# {10: 1, 12: 1, 14: 1}
#
# Infections generated by person 333:
# {9: 1}
#
# Infections generated by person 309:
# {3: 1, 5: 3, 8: 1}
#
# Infections generated by person 445:
# {7: 1, 8: 1, 10: 1}
#
# Infections generated by person 192:
# {7: 1, 9: 1, 11: 1}
#
# Infections generated by person 327:
# {10: 1}
#
# Infections generated by person 407:
# {12: 1}
#
# Infections generated by person 375:
# {13: 1}
#
# Infections generated by person 299:
# {11: 1, 15: 1, 16: 1}
#
# Infections generated by person 351:
# {10: 1}
#
# Infections generated by person 273:
# {11: 2, 12: 1, 14: 2}
#
# Infections generated by person 126:
# {7: 2, 9: 1}
#
# Infections generated by person 196:
# {11: 1, 14: 1}
#
# Infections generated by person 24:
# {8: 1, 9: 1, 10: 2}
#
# Infections generated by person 237:
# {12: 1}
#
# Infections generated by person 121:
# {7: 2, 8: 1, 14: 1}
#
# Infections generated by person 326:
# {15: 1}
#
# Infections generated by person 263:
# {10: 1, 12: 1}
#
# Infections generated by person 54:
# {10: 2}
#
# Infections generated by person 498:
# {14: 1}
#
# Infections generated by person 453:
# {5: 5, 6: 1, 11: 1}
#
# Infections generated by person 491:
# {11: 1, 12: 1, 14: 2}
#
# Infections generated by person 79:
# {7: 2}
#
# Infections generated by person 31:
# {6: 1}
#
# Infections generated by person 101:
# {8: 1}
#
# Infections generated by person 100:
# {9: 1, 10: 1}
#
# Infections generated by person 370:
# {19: 1}
#
# Infections generated by person 402:
# {8: 2}
#
# Infections generated by person 93:
# {9: 2, 14: 1}
#
# Infections generated by person 271:
# {11: 1, 12: 1}
#
# Infections generated by person 276:
# {15: 1}
#
# Infections generated by person 222:
# {13: 1}
#
# Infections generated by person 124:
# {12: 1}
#
# Infections generated by person 387:
# {10: 1}
#
# Infections generated by person 248:
# {8: 1}
#
# Infections generated by person 315:
# {12: 1, 13: 1}
#
# Infections generated by person 68:
# {11: 1}
#
# Infections generated by person 218:
# {15: 1}
#
# Infections generated by person 480:
# {10: 1}
#
# Infections generated by person 81:
# {12: 1}
#
# Infections generated by person 33:
# {12: 1}
#
# Infections generated by person 488:
# {10: 1}
#
# Infections generated by person 260:
# {6: 1, 10: 2, 11: 1}
#
# Infections generated by person 420:
# {15: 1}
#
# Infections generated by person 428:
# {7: 2, 9: 1, 11: 2}
#
# Infections generated by person 395:
# {8: 1}
#
# Infections generated by person 290:
# {8: 1, 9: 1}
#
# Infections generated by person 88:
# {6: 2, 9: 1}
#
# Infections generated by person 411:
# {15: 1}
#
# Infections generated by person 29:
# {12: 1, 14: 1, 20: 1}
#
# Infections generated by person 159:
# {12: 1, 14: 1}
#
# Infections generated by person 85:
# {8: 2, 12: 1}
#
# Infections generated by person 500:
# {9: 1}
#
# Infections generated by person 348:
# {15: 1}
#
# Infections generated by person 52:
# {11: 1, 14: 1}
#
# Infections generated by person 223:
# {7: 1, 9: 1, 10: 2, 12: 1, 17: 1}
#
# Infections generated by person 494:
# {12: 1}
#
# Infections generated by person 239:
# {27: 1}
#
# Infections generated by person 316:
# {5: 2, 7: 1, 9: 1, 11: 1}
#
# Infections generated by person 272:
# {9: 1, 10: 1}
#
# Infections generated by person 103:
# {5: 1}
#
# Infections generated by person 421:
# {11: 1, 12: 1, 14: 2, 17: 1}
#
# Infections generated by person 358:
# {13: 2}
#
# Infections generated by person 44:
# {10: 1}
#
# Infections generated by person 416:
# {14: 1}
#
# Infections generated by person 134:
# {9: 1, 12: 2}
#
# Infections generated by person 48:
# {10: 1, 11: 1, 14: 1}
#
# Infections generated by person 186:
# {9: 1, 10: 1, 12: 1}
#
# Infections generated by person 419:
# {13: 1}
#
# Infections generated by person 317:
# {7: 1}
#
# Infections generated by person 140:
# {14: 1}
#
# Infections generated by person 470:
# {9: 1, 10: 2, 12: 1}
#
# Infections generated by person 224:
# {12: 1, 13: 1}
#
# Infections generated by person 129:
# {10: 1, 11: 1, 12: 1}
#
# Infections generated by person 399:
# {5: 1, 7: 1}
#
# Infections generated by person 58:
# {4: 3}
#
# Infections generated by person 398:
# {6: 1, 7: 1, 8: 2, 9: 1}
#
# Infections generated by person 19:
# {18: 1}
#
# Infections generated by person 197:
# {8: 1, 13: 1}
#
# Infections generated by person 234:
# {10: 2, 13: 1, 14: 1}
#
# Infections generated by person 176:
# {13: 2}
#
# Infections generated by person 217:
# {9: 1, 13: 1}
#
# Infections generated by person 458:
# {19: 1}
#
# Infections generated by person 12:
# {13: 2, 14: 1}
#
# Infections generated by person 3:
# {7: 1, 11: 1}
#
# Infections generated by person 6:
# {13: 1, 16: 1}
#
# Infections generated by person 167:
# {14: 1, 17: 1}
#
# Infections generated by person 467:
# {10: 1}
#
# Infections generated by person 225:
# {13: 2}
#
# Infections generated by person 51:
# {11: 1}
#
# Infections generated by person 231:
# {12: 1}
#
# Infections generated by person 490:
# {7: 1}
#
# Infections generated by person 104:
# {20: 1}
#
# Infections generated by person 152:
# {13: 1}
#
# Infections generated by person 376:
# {14: 1}
#
# Infections generated by person 83:
# {10: 1}
#
# Infections generated by person 291:
# {9: 1, 17: 1}
#
# Infections generated by person 525:
# {2: 1, 3: 1, 8: 1, 12: 1}
#
# Infections generated by person 364:
# {11: 1, 16: 1}
#
# Infections generated by person 270:
# {9: 1}
#
# Infections generated by person 292:
# {12: 1, 17: 1}
#
# Infections generated by person 74:
# {14: 1}
#
# Infections generated by person 39:
# {6: 2, 7: 1, 8: 1, 10: 1}
#
# Infections generated by person 157:
# {9: 1, 10: 1, 12: 1}
#
# Infections generated by person 228:
# {7: 1, 9: 1, 10: 2}
#
# Infections generated by person 526:
# {2: 2}
#
# Infections generated by person 135:
# {10: 1, 15: 1, 16: 1}
#
# Infections generated by person 146:
# {6: 2, 8: 1, 13: 2}
#
# Infections generated by person 211:
# {15: 1}
#
# Infections generated by person 244:
# {9: 1, 10: 1, 12: 1}
#
# Infections generated by person 226:
# {12: 1}
#
# Infections generated by person 16:
# {6: 1, 7: 1, 9: 1}
#
# Infections generated by person 412:
# {11: 1}
#
# Infections generated by person 360:
# {5: 1, 10: 1, 13: 1}
#
# Infections generated by person 396:
# {12: 1}

# %% [markdown]
# ### Infections of Strain 2 Generated by each individual

# %%
for person in Population_1:
    if len(person.infections_s2) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(sum(person.infections_s2.values()))
# Out:
# Infections generated by person 63:
# 2
#
# Infections generated by person 14:
# 1
#
# Infections generated by person 334:
# 4
#
# Infections generated by person 274:
# 1
#
# Infections generated by person 30:
# 2
#
# Infections generated by person 22:
# 2
#
# Infections generated by person 302:
# 2
#
# Infections generated by person 341:
# 1
#
# Infections generated by person 440:
# 2
#
# Infections generated by person 255:
# 1
#
# Infections generated by person 82:
# 4
#
# Infections generated by person 18:
# 1
#
# Infections generated by person 43:
# 1
#
# Infections generated by person 158:
# 3
#
# Infections generated by person 287:
# 2
#
# Infections generated by person 347:
# 1
#
# Infections generated by person 106:
# 1
#
# Infections generated by person 59:
# 4
#
# Infections generated by person 289:
# 5
#
# Infections generated by person 252:
# 1
#
# Infections generated by person 266:
# 1
#
# Infections generated by person 294:
# 4
#
# Infections generated by person 235:
# 3
#
# Infections generated by person 2:
# 1
#
# Infections generated by person 489:
# 1
#
# Infections generated by person 493:
# 5
#
# Infections generated by person 141:
# 1
#
# Infections generated by person 148:
# 3
#
# Infections generated by person 281:
# 1
#
# Infections generated by person 413:
# 3
#
# Infections generated by person 91:
# 6
#
# Infections generated by person 409:
# 3
#
# Infections generated by person 483:
# 2
#
# Infections generated by person 262:
# 1
#
# Infections generated by person 296:
# 2
#
# Infections generated by person 524:
# 5
#
# Infections generated by person 452:
# 3
#
# Infections generated by person 209:
# 2
#
# Infections generated by person 301:
# 3
#
# Infections generated by person 485:
# 1
#
# Infections generated by person 120:
# 1
#
# Infections generated by person 94:
# 1
#
# Infections generated by person 184:
# 1
#
# Infections generated by person 439:
# 4
#
# Infections generated by person 200:
# 2
#
# Infections generated by person 117:
# 2
#
# Infections generated by person 4:
# 7
#
# Infections generated by person 72:
# 4
#
# Infections generated by person 95:
# 1
#
# Infections generated by person 336:
# 1
#
# Infections generated by person 410:
# 1
#
# Infections generated by person 191:
# 4
#
# Infections generated by person 457:
# 1
#
# Infections generated by person 388:
# 2
#
# Infections generated by person 253:
# 2
#
# Infections generated by person 288:
# 1
#
# Infections generated by person 437:
# 1
#
# Infections generated by person 313:
# 2
#
# Infections generated by person 96:
# 1
#
# Infections generated by person 40:
# 3
#
# Infections generated by person 49:
# 3
#
# Infections generated by person 404:
# 1
#
# Infections generated by person 131:
# 1
#
# Infections generated by person 295:
# 1
#
# Infections generated by person 389:
# 2
#
# Infections generated by person 220:
# 1
#
# Infections generated by person 423:
# 2
#
# Infections generated by person 257:
# 3
#
# Infections generated by person 278:
# 3
#
# Infections generated by person 333:
# 1
#
# Infections generated by person 309:
# 5
#
# Infections generated by person 445:
# 3
#
# Infections generated by person 192:
# 3
#
# Infections generated by person 327:
# 1
#
# Infections generated by person 407:
# 1
#
# Infections generated by person 375:
# 1
#
# Infections generated by person 299:
# 3
#
# Infections generated by person 351:
# 1
#
# Infections generated by person 273:
# 5
#
# Infections generated by person 126:
# 3
#
# Infections generated by person 196:
# 2
#
# Infections generated by person 24:
# 4
#
# Infections generated by person 237:
# 1
#
# Infections generated by person 121:
# 4
#
# Infections generated by person 326:
# 1
#
# Infections generated by person 263:
# 2
#
# Infections generated by person 54:
# 2
#
# Infections generated by person 498:
# 1
#
# Infections generated by person 453:
# 7
#
# Infections generated by person 491:
# 4
#
# Infections generated by person 79:
# 2
#
# Infections generated by person 31:
# 1
#
# Infections generated by person 101:
# 1
#
# Infections generated by person 100:
# 2
#
# Infections generated by person 370:
# 1
#
# Infections generated by person 402:
# 2
#
# Infections generated by person 93:
# 3
#
# Infections generated by person 271:
# 2
#
# Infections generated by person 276:
# 1
#
# Infections generated by person 222:
# 1
#
# Infections generated by person 124:
# 1
#
# Infections generated by person 387:
# 1
#
# Infections generated by person 248:
# 1
#
# Infections generated by person 315:
# 2
#
# Infections generated by person 68:
# 1
#
# Infections generated by person 218:
# 1
#
# Infections generated by person 480:
# 1
#
# Infections generated by person 81:
# 1
#
# Infections generated by person 33:
# 1
#
# Infections generated by person 488:
# 1
#
# Infections generated by person 260:
# 4
#
# Infections generated by person 420:
# 1
#
# Infections generated by person 428:
# 5
#
# Infections generated by person 395:
# 1
#
# Infections generated by person 290:
# 2
#
# Infections generated by person 88:
# 3
#
# Infections generated by person 411:
# 1
#
# Infections generated by person 29:
# 3
#
# Infections generated by person 159:
# 2
#
# Infections generated by person 85:
# 3
#
# Infections generated by person 500:
# 1
#
# Infections generated by person 348:
# 1
#
# Infections generated by person 52:
# 2
#
# Infections generated by person 223:
# 6
#
# Infections generated by person 494:
# 1
#
# Infections generated by person 239:
# 1
#
# Infections generated by person 316:
# 5
#
# Infections generated by person 272:
# 2
#
# Infections generated by person 103:
# 1
#
# Infections generated by person 421:
# 5
#
# Infections generated by person 358:
# 2
#
# Infections generated by person 44:
# 1
#
# Infections generated by person 416:
# 1
#
# Infections generated by person 134:
# 3
#
# Infections generated by person 48:
# 3
#
# Infections generated by person 186:
# 3
#
# Infections generated by person 419:
# 1
#
# Infections generated by person 317:
# 1
#
# Infections generated by person 140:
# 1
#
# Infections generated by person 470:
# 4
#
# Infections generated by person 224:
# 2
#
# Infections generated by person 129:
# 3
#
# Infections generated by person 399:
# 2
#
# Infections generated by person 58:
# 3
#
# Infections generated by person 398:
# 5
#
# Infections generated by person 19:
# 1
#
# Infections generated by person 197:
# 2
#
# Infections generated by person 234:
# 4
#
# Infections generated by person 176:
# 2
#
# Infections generated by person 217:
# 2
#
# Infections generated by person 458:
# 1
#
# Infections generated by person 12:
# 3
#
# Infections generated by person 3:
# 2
#
# Infections generated by person 6:
# 2
#
# Infections generated by person 167:
# 2
#
# Infections generated by person 467:
# 1
#
# Infections generated by person 225:
# 2
#
# Infections generated by person 51:
# 1
#
# Infections generated by person 231:
# 1
#
# Infections generated by person 490:
# 1
#
# Infections generated by person 104:
# 1
#
# Infections generated by person 152:
# 1
#
# Infections generated by person 376:
# 1
#
# Infections generated by person 83:
# 1
#
# Infections generated by person 291:
# 2
#
# Infections generated by person 525:
# 4
#
# Infections generated by person 364:
# 2
#
# Infections generated by person 270:
# 1
#
# Infections generated by person 292:
# 2
#
# Infections generated by person 74:
# 1
#
# Infections generated by person 39:
# 5
#
# Infections generated by person 157:
# 3
#
# Infections generated by person 228:
# 4
#
# Infections generated by person 526:
# 2
#
# Infections generated by person 135:
# 3
#
# Infections generated by person 146:
# 5
#
# Infections generated by person 211:
# 1
#
# Infections generated by person 244:
# 3
#
# Infections generated by person 226:
# 1
#
# Infections generated by person 16:
# 3
#
# Infections generated by person 412:
# 1
#
# Infections generated by person 360:
# 3
#
# Infections generated by person 396:
# 1

# %% [markdown]
# ### Plot of The Simulation

# %%
def Plot_Dynamics_11(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S12 = []; I1 = []; I2 = []; R = [];
    for t in range(T+1):
        S12t = 0; I1t = 0; I2t = 0; Rt = 0;
        for person in simulation:
            if person.status[t] == 'S12':
                S12t += 1
            elif person.status[t] == 'I1':
                I1t += 1
            elif person.status[t] == 'I2':
                I2t += 1
            else:
                Rt += 1
        S12.append(S12t)
        I1.append(I1t)
        I2.append(I2t)
        R.append(Rt)

    plt.plot(range(T+1), S12, 'b-', label = 'S12')
    plt.plot(range(T+1), I1, 'r-', label = 'I1')
    plt.plot(range(T+1), I2, 'g-', label = 'I2')
    plt.plot(range(T+1), R, 'k-', label = 'R')
    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()

# %%
Plot_Dynamics_11(Population_1, 100)

# %%
def Plot_Dynamics_12(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S = []; I = []; R = [];
    for t in range(T+1):
        St = 0; It = 0; Rt = 0;
        for person in simulation:
            if person.status[t] == 'S12':
                St += 1
            elif person.status[t] == 'I1' or person.status[t] == 'I2':
                It += 1
            else:
                Rt += 1
        S.append(St)
        I.append(It)
        R.append(Rt)

    plt.plot(range(T+1), S, 'b-', label = 'S')
    plt.plot(range(T+1), I, 'r-', label = 'I')
    plt.plot(range(T+1), R, 'k-', label = 'R')
    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()

# %%
Plot_Dynamics_12(Population_1, 100)

# %% [markdown]
# ## 1.2. An Even More Complex Model

# %%
def GPSIR_2(pop_init, T, alpha, beta1, beta2, tau_distribution = Geometric, 
          tau_parameter = 1/21, inoculation_distribution = Constant,
          inoculation_parameter = 1, inoculation_threshold = 1):
    """Simulates the dynamics of the epidemy
        
    Parameters
    ----------
    pop_init : tuple
        A tuple with the initial conditions for each population
        in the graphic probabilistic SIR for two strains
    
    T : int
        Number of days of the simulation.
    
    alpha: float
        Probability of formation of an edge.
    
    beta1: float
        Probability of contagion given infectious contagion of
        the strain 1.
        
    beta2: float
        Probability of contagion given infectious contagion of
        the strain 2.
    
    tau_distribution : function, optional
        Distribution of the number of days that the individual 
        will be infected (default is Gemoetric).
    
    tau_parameter: float, optional
        Parameter of the distribution of the number of days that
        the individual will be infected (default is 1/21).
        
    inoculation_distribution: function, optional
        Distribution of the viral load to which a susceptible 
        individual is exposed in an infectious contact
        (default is Constant).
        
    inoculation_parameter: float, optional
        Parameter of the distribution of the viral load to 
        which a susceptible is exposed in an infectious contact
        (default is 1).
    
    inoculation_threshold: float, optional
        Viral load threshold for contagion (default is 1).
    

    Returns
    -------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 
        
    """
    S120, I10, I20, R10, R10, S10, S20, I12, I21, R12 = pop_init
    
    Population = []

    # The susceptible are added to the population
    for i in range(1,S120+1):
        p = Person(i,{0:'S12'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    # The infected with strain 1 are added to the population
    for i in range(S120+1,S120+I10+1):
        p = Person(i,{0:'I1'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
        
    # The infected with strain 2 are added to the population
    for i in range(S120+I10+1,S120+I10+I20+1):
        p = Person(i,{0:'I2'},21)
        p.set_tau(tau_distribution,tau_parameter)
        Population.append(p)
    
    
    # We iterate over the days of the simulation
    for t in range(1,T+1):

        random.shuffle(Population)
        # Iteration per day over each individual of the population
        for p1 in Population:

            # Iteration per individual over the rest of the population in 
            # orther to generate contats between individuals.
            for p2 in Population:
                if p1.status[t-1] == 'S12' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)
                if p1.status[t-1] == 'S1' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)
                if p1.status[t-1] == 'S2' and p1 != p2 and Bernoulli(alpha):
                    p1.set_contact(t-1,p2)

            # Here starts the modification of the populations S, I, and R.

            # Modifications over the Suceptible population
            if p1.status[t-1] == 'S12':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load_1 = 0
                    viral_load_2 = 0
                    
                    # for each contact we check if there was efective infection
                    temp = 0
                    
                    while temp < len(p1.contacts[t-1]) and p1.status[t-1] == 'S12':
                        
                        if p1.contacts[t-1][temp].status[t-1] == 'I1' and Bernoulli(beta1):
                            viral_load_1 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I1')
                            p1.contacts[t-1][temp].add_infection_s1(t)
                            break
                            
                        if p1.contacts[t-1][temp].status[t-1] == 'I2' and Bernoulli(beta2):
                            viral_load_2 += inoculation_distribution(inoculation_parameter)
                            p1.set_status(t,'I2')
                            p1.contacts[t-1][temp].add_infection_s2(t)
                            break
                        
                        temp += 1
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    if (viral_load_1 + viral_load_2 == 0):
                        p1.set_status(t,'S12')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S12')

            # Modifications over the Infected population
            elif p1.status[t-1] == 'I1':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I1')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R1')
                    
            elif p1.status[t-1] == 'I2':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I2')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R2')
                    
            elif p1.status[t-1] == 'R1':
                
                # Case in which the days of infection aren´t over
                if Bernoulli(1):
                    p1.set_status(t,'S2')
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R1')
                    
            elif p1.status[t-1] == 'R2':
                
                # Case in which the days of infection aren´t over
                if Bernoulli(1):
                    p1.set_status(t,'S1')
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R2')
            
            elif p1.status[t-1] == 'S2':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load = 0
                    
                    # for each contact we check if there was efective infection
                    for contact in p1.contacts[t-1]:
                        if (contact.status[t-1] == 'I2' or contact.status[t-1] == 'I12') and Bernoulli(beta2):
                            viral_load += inoculation_distribution(inoculation_parameter)
                            contact.add_infection_s2(t)
                            break
                    
                    # Case in which the viral load surpassed the inoculation threshold
                    if viral_load >= inoculation_threshold:
                        p1.set_status(t,'I12')
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    else:
                        p1.set_status(t,'S2')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S2')
                    
            elif p1.status[t-1] == 'S1':
                
                # Case in which there were contacts
                if (t-1) in p1.contacts:
                    viral_load = 0
                    
                    # for each contact we check if there was efective infection
                    for contact in p1.contacts[t-1]:
                        if (contact.status[t-1] == 'I1' or contact.status[t-1] == 'I21') and Bernoulli(beta1):
                            viral_load += inoculation_distribution(inoculation_parameter)
                            contact.add_infection_s1(t)
                            break
                    
                    # Case in which the viral load surpassed the inoculation threshold
                    if viral_load >= inoculation_threshold:
                        p1.set_status(t,'I21')
                    
                    # Case in which the viral load did not surpassed the inoculation 
                    # threshold
                    else:
                        p1.set_status(t,'S1')
                
                # Case in which there were no contacts
                else:
                    p1.set_status(t,'S1')
                    
            elif p1.status[t-1] == 'I12':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I12')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R12')
                    
            elif p1.status[t-1] == 'I21':
                
                # Case in which the days of infection aren´t over
                if p1.tau > 0:
                    p1.set_status(t,'I21')
                    p1.tau -= 1
                
                # Case in which the days of infection are over
                else:
                    p1.set_status(t,'R12')

            # Modifications over the Removed population
            else:
                p1.set_status(t,'R12')
    
    return Population

# %% [markdown]
# ## Results

# %%
T = 150
P_init = (450, 45, 5, 0, 0, 0, 0, 0, 0, 0)
Population_2 = GPSIR_2(P_init, T, alpha = 0.1, beta1 = 0.005, beta2 = 0.015)

# %% [markdown]
# ### Infections od strain 1 indexed by time

# %%
for person in Population_2:
    if len(person.infections_s1) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(person.infections_s1)
# Out:
# Infections generated by person 98:
# {3: 1, 4: 1, 14: 1}
#
# Infections generated by person 67:
# {2: 1, 3: 1}
#
# Infections generated by person 481:
# {11: 1}
#
# Infections generated by person 492:
# {2: 1}
#
# Infections generated by person 2:
# {31: 1, 33: 1}
#
# Infections generated by person 116:
# {29: 1}
#
# Infections generated by person 226:
# {12: 1}
#
# Infections generated by person 20:
# {7: 1}
#
# Infections generated by person 233:
# {7: 1}
#
# Infections generated by person 468:
# {3: 1, 7: 1}
#
# Infections generated by person 168:
# {33: 1}
#
# Infections generated by person 295:
# {7: 1}
#
# Infections generated by person 332:
# {20: 1, 21: 1}
#
# Infections generated by person 310:
# {9: 1, 45: 1, 51: 1}
#
# Infections generated by person 419:
# {15: 1}
#
# Infections generated by person 466:
# {1: 1, 34: 1}
#
# Infections generated by person 463:
# {21: 2, 44: 2, 45: 1}
#
# Infections generated by person 36:
# {15: 1}
#
# Infections generated by person 346:
# {8: 1}
#
# Infections generated by person 375:
# {37: 1, 45: 1, 59: 1, 62: 1, 81: 1}
#
# Infections generated by person 454:
# {1: 1, 2: 1, 5: 1, 6: 1}
#
# Infections generated by person 38:
# {45: 1}
#
# Infections generated by person 45:
# {38: 1, 50: 1}
#
# Infections generated by person 120:
# {4: 1, 12: 1, 61: 1, 87: 1}
#
# Infections generated by person 405:
# {7: 1, 9: 1, 10: 1, 14: 1}
#
# Infections generated by person 74:
# {41: 1, 43: 1, 72: 1}
#
# Infections generated by person 471:
# {45: 1}
#
# Infections generated by person 458:
# {2: 1}
#
# Infections generated by person 24:
# {5: 1, 18: 1, 68: 1, 70: 1}
#
# Infections generated by person 407:
# {11: 1}
#
# Infections generated by person 137:
# {12: 1}
#
# Infections generated by person 328:
# {20: 1, 30: 1}
#
# Infections generated by person 316:
# {12: 1}
#
# Infections generated by person 442:
# {7: 1}
#
# Infections generated by person 412:
# {6: 1, 17: 1}
#
# Infections generated by person 230:
# {8: 2}
#
# Infections generated by person 495:
# {3: 1, 4: 1, 5: 1}
#
# Infections generated by person 273:
# {6: 1, 25: 1, 34: 1, 37: 1, 41: 1, 63: 1}
#
# Infections generated by person 211:
# {15: 1, 25: 1}
#
# Infections generated by person 491:
# {1: 2, 2: 1, 22: 1}
#
# Infections generated by person 136:
# {13: 1, 17: 1, 46: 1, 50: 1, 52: 1}
#
# Infections generated by person 242:
# {10: 1}
#
# Infections generated by person 360:
# {34: 1}
#
# Infections generated by person 13:
# {7: 1}
#
# Infections generated by person 280:
# {19: 1}
#
# Infections generated by person 370:
# {4: 1}
#
# Infections generated by person 306:
# {3: 1}
#
# Infections generated by person 111:
# {18: 1, 19: 1, 37: 1}
#
# Infections generated by person 54:
# {4: 1}
#
# Infections generated by person 172:
# {7: 1}
#
# Infections generated by person 410:
# {9: 1, 28: 1, 33: 1}
#
# Infections generated by person 289:
# {4: 2, 6: 1, 8: 1}
#
# Infections generated by person 445:
# {22: 1, 32: 1}
#
# Infections generated by person 180:
# {4: 1, 5: 1, 33: 1}
#
# Infections generated by person 480:
# {2: 2, 11: 1}
#
# Infections generated by person 163:
# {20: 1, 25: 1, 76: 1, 78: 1}
#
# Infections generated by person 219:
# {12: 1}
#
# Infections generated by person 104:
# {8: 1}
#
# Infections generated by person 159:
# {22: 1}
#
# Infections generated by person 389:
# {8: 2, 11: 1, 17: 1, 23: 1, 29: 1, 32: 2, 44: 1}
#
# Infections generated by person 476:
# {2: 1, 4: 1, 5: 1}
#
# Infections generated by person 486:
# {5: 1}
#
# Infections generated by person 490:
# {1: 1}
#
# Infections generated by person 438:
# {6: 1, 23: 1}
#
# Infections generated by person 413:
# {9: 1, 27: 1, 33: 1}
#
# Infections generated by person 89:
# {4: 1, 5: 1, 11: 1, 12: 1}
#
# Infections generated by person 472:
# {5: 1}
#
# Infections generated by person 474:
# {3: 1, 25: 1}
#
# Infections generated by person 60:
# {26: 1}
#
# Infections generated by person 453:
# {2: 1}
#
# Infections generated by person 330:
# {4: 1, 13: 1}
#
# Infections generated by person 380:
# {3: 1, 6: 1}
#
# Infections generated by person 487:
# {2: 1}
#
# Infections generated by person 457:
# {1: 1, 10: 2, 21: 1, 39: 1}
#
# Infections generated by person 101:
# {5: 1, 6: 1}
#
# Infections generated by person 467:
# {1: 2, 4: 1}
#
# Infections generated by person 278:
# {4: 1}
#
# Infections generated by person 125:
# {39: 1}
#
# Infections generated by person 464:
# {2: 1}
#
# Infections generated by person 421:
# {2: 1, 5: 1}
#
# Infections generated by person 9:
# {33: 1}
#
# Infections generated by person 31:
# {22: 1}
#
# Infections generated by person 218:
# {6: 1, 7: 1, 30: 1, 34: 1}
#
# Infections generated by person 485:
# {2: 1}
#
# Infections generated by person 16:
# {20: 1}
#
# Infections generated by person 475:
# {2: 2, 5: 1}
#
# Infections generated by person 127:
# {4: 1, 18: 1, 21: 1}
#
# Infections generated by person 153:
# {3: 1, 5: 1}
#
# Infections generated by person 452:
# {2: 1}
#
# Infections generated by person 313:
# {10: 1, 25: 1, 35: 1, 44: 1, 69: 1}
#
# Infections generated by person 277:
# {11: 1, 21: 1}
#
# Infections generated by person 397:
# {26: 1}
#
# Infections generated by person 28:
# {9: 1, 31: 1}
#
# Infections generated by person 329:
# {2: 1, 7: 1, 24: 1, 36: 1}
#
# Infections generated by person 22:
# {63: 1}
#
# Infections generated by person 363:
# {5: 1, 6: 1, 7: 1, 17: 1}
#
# Infections generated by person 80:
# {21: 1, 23: 1, 27: 1}
#
# Infections generated by person 15:
# {18: 1, 28: 1}
#
# Infections generated by person 325:
# {9: 1}
#
# Infections generated by person 477:
# {3: 1, 6: 1, 11: 1, 19: 1}
#
# Infections generated by person 465:
# {3: 1, 4: 1}
#
# Infections generated by person 357:
# {15: 1, 41: 1}
#
# Infections generated by person 402:
# {8: 1}
#
# Infections generated by person 124:
# {8: 1}
#
# Infections generated by person 482:
# {2: 1}
#
# Infections generated by person 62:
# {18: 1, 30: 1, 35: 1, 37: 1}
#
# Infections generated by person 493:
# {2: 1, 7: 1}
#
# Infections generated by person 17:
# {31: 1}
#
# Infections generated by person 461:
# {6: 1}
#
# Infections generated by person 79:
# {4: 1, 7: 3}
#
# Infections generated by person 450:
# {9: 1}
#
# Infections generated by person 470:
# {1: 1, 2: 1, 3: 2}
#
# Infections generated by person 274:
# {4: 2, 6: 1, 7: 1}
#
# Infections generated by person 5:
# {34: 1, 39: 1, 47: 1, 53: 1}
#
# Infections generated by person 488:
# {3: 1, 4: 1}
#
# Infections generated by person 208:
# {10: 1, 41: 1, 43: 1, 44: 1, 46: 1, 53: 1, 62: 1, 64: 1}
#
# Infections generated by person 479:
# {6: 1, 33: 1}
#
# Infections generated by person 361:
# {5: 1}
#
# Infections generated by person 69:
# {3: 1}
#
# Infections generated by person 246:
# {15: 2, 33: 1}
#
# Infections generated by person 451:
# {2: 2, 3: 2}
#
# Infections generated by person 339:
# {8: 1, 9: 1}
#
# Infections generated by person 427:
# {20: 1}
#
# Infections generated by person 350:
# {6: 1}
#
# Infections generated by person 459:
# {4: 1, 28: 1, 29: 1}
#
# Infections generated by person 272:
# {2: 1}
#
# Infections generated by person 11:
# {43: 1, 47: 1, 70: 1}
#
# Infections generated by person 169:
# {19: 1}
#
# Infections generated by person 42:
# {9: 1}
#
# Infections generated by person 150:
# {8: 1, 9: 1}

# %% [markdown]
# ### Infections of strain 1

# %%
for person in Population_2:
    if len(person.infections_s1) != 0:
        print("\nInfections generated by person {}:".format(person.index))
        print(sum(person.infections_s1.values()))
# Out:
# Infections generated by person 98:
# 3
#
# Infections generated by person 67:
# 2
#
# Infections generated by person 481:
# 1
#
# Infections generated by person 492:
# 1
#
# Infections generated by person 2:
# 2
#
# Infections generated by person 116:
# 1
#
# Infections generated by person 226:
# 1
#
# Infections generated by person 20:
# 1
#
# Infections generated by person 233:
# 1
#
# Infections generated by person 468:
# 2
#
# Infections generated by person 168:
# 1
#
# Infections generated by person 295:
# 1
#
# Infections generated by person 332:
# 2
#
# Infections generated by person 310:
# 3
#
# Infections generated by person 419:
# 1
#
# Infections generated by person 466:
# 2
#
# Infections generated by person 463:
# 5
#
# Infections generated by person 36:
# 1
#
# Infections generated by person 346:
# 1
#
# Infections generated by person 375:
# 5
#
# Infections generated by person 454:
# 4
#
# Infections generated by person 38:
# 1
#
# Infections generated by person 45:
# 2
#
# Infections generated by person 120:
# 4
#
# Infections generated by person 405:
# 4
#
# Infections generated by person 74:
# 3
#
# Infections generated by person 471:
# 1
#
# Infections generated by person 458:
# 1
#
# Infections generated by person 24:
# 4
#
# Infections generated by person 407:
# 1
#
# Infections generated by person 137:
# 1
#
# Infections generated by person 328:
# 2
#
# Infections generated by person 316:
# 1
#
# Infections generated by person 442:
# 1
#
# Infections generated by person 412:
# 2
#
# Infections generated by person 230:
# 2
#
# Infections generated by person 495:
# 3
#
# Infections generated by person 273:
# 6
#
# Infections generated by person 211:
# 2
#
# Infections generated by person 491:
# 4
#
# Infections generated by person 136:
# 5
#
# Infections generated by person 242:
# 1
#
# Infections generated by person 360:
# 1
#
# Infections generated by person 13:
# 1
#
# Infections generated by person 280:
# 1
#
# Infections generated by person 370:
# 1
#
# Infections generated by person 306:
# 1
#
# Infections generated by person 111:
# 3
#
# Infections generated by person 54:
# 1
#
# Infections generated by person 172:
# 1
#
# Infections generated by person 410:
# 3
#
# Infections generated by person 289:
# 4
#
# Infections generated by person 445:
# 2
#
# Infections generated by person 180:
# 3
#
# Infections generated by person 480:
# 3
#
# Infections generated by person 163:
# 4
#
# Infections generated by person 219:
# 1
#
# Infections generated by person 104:
# 1
#
# Infections generated by person 159:
# 1
#
# Infections generated by person 389:
# 9
#
# Infections generated by person 476:
# 3
#
# Infections generated by person 486:
# 1
#
# Infections generated by person 490:
# 1
#
# Infections generated by person 438:
# 2
#
# Infections generated by person 413:
# 3
#
# Infections generated by person 89:
# 4
#
# Infections generated by person 472:
# 1
#
# Infections generated by person 474:
# 2
#
# Infections generated by person 60:
# 1
#
# Infections generated by person 453:
# 1
#
# Infections generated by person 330:
# 2
#
# Infections generated by person 380:
# 2
#
# Infections generated by person 487:
# 1
#
# Infections generated by person 457:
# 5
#
# Infections generated by person 101:
# 2
#
# Infections generated by person 467:
# 3
#
# Infections generated by person 278:
# 1
#
# Infections generated by person 125:
# 1
#
# Infections generated by person 464:
# 1
#
# Infections generated by person 421:
# 2
#
# Infections generated by person 9:
# 1
#
# Infections generated by person 31:
# 1
#
# Infections generated by person 218:
# 4
#
# Infections generated by person 485:
# 1
#
# Infections generated by person 16:
# 1
#
# Infections generated by person 475:
# 3
#
# Infections generated by person 127:
# 3
#
# Infections generated by person 153:
# 2
#
# Infections generated by person 452:
# 1
#
# Infections generated by person 313:
# 5
#
# Infections generated by person 277:
# 2
#
# Infections generated by person 397:
# 1
#
# Infections generated by person 28:
# 2
#
# Infections generated by person 329:
# 4
#
# Infections generated by person 22:
# 1
#
# Infections generated by person 363:
# 4
#
# Infections generated by person 80:
# 3
#
# Infections generated by person 15:
# 2
#
# Infections generated by person 325:
# 1
#
# Infections generated by person 477:
# 4
#
# Infections generated by person 465:
# 2
#
# Infections generated by person 357:
# 2
#
# Infections generated by person 402:
# 1
#
# Infections generated by person 124:
# 1
#
# Infections generated by person 482:
# 1
#
# Infections generated by person 62:
# 4
#
# Infections generated by person 493:
# 2
#
# Infections generated by person 17:
# 1
#
# Infections generated by person 461:
# 1
#
# Infections generated by person 79:
# 4
#
# Infections generated by person 450:
# 1
#
# Infections generated by person 470:
# 4
#
# Infections generated by person 274:
# 4
#
# Infections generated by person 5:
# 4
#
# Infections generated by person 488:
# 2
#
# Infections generated by person 208:
# 8
#
# Infections generated by person 479:
# 2
#
# Infections generated by person 361:
# 1
#
# Infections generated by person 69:
# 1
#
# Infections generated by person 246:
# 3
#
# Infections generated by person 451:
# 4
#
# Infections generated by person 339:
# 2
#
# Infections generated by person 427:
# 1
#
# Infections generated by person 350:
# 1
#
# Infections generated by person 459:
# 3
#
# Infections generated by person 272:
# 1
#
# Infections generated by person 11:
# 3
#
# Infections generated by person 169:
# 1
#
# Infections generated by person 42:
# 1
#
# Infections generated by person 150:
# 2

# %%
def final_populations_2(Population):
    """Counts de number of susceptible, infected, and recovered individuals at the
    end of the simulation.
        
    This function receives as parameter the list of the population after the simulation 
    has been run. It counts the number of susceptible, infected, and recovered individuals 
    at the end of the simulation and prints them.
        
    Parameters
    ----------
    Population : list
        List with the individuals and their modified attributes after
        T days of contacts, infections and recoveries. 

    """
    S12f = 0; I1f = 0; I2f = 0; R1f = 0; R2f = 0;
    S1f = 0; S2f = 0; I12f = 0; I21f = 0; R12f = 0;
    for person in Population:
        if person.status[T] == 'S12':
            S12f += 1
        elif person.status[T] == 'I1':
            I1f += 1
        elif person.status[T] == 'I2':
            I2f += 1
        elif person.status[T] == 'R1':
            R1f += 1
        elif person.status[T] == 'R2':
            R2f += 1
        elif person.status[T] == 'S1':
            S1f += 1
        elif person.status[T] == 'S2':
            S2f += 1
        elif person.status[T] == 'I12':
            I12f += 1
        elif person.status[T] == 'I21':
            I21f += 1
        else:
            R12f += 1
    print("S12: {}\nI1: {}\nI2: {}\nR1: {}\nR2: {}".format(S12f,I1f,I2f,R1f,R2f))
    print("S1: {}\nS2: {}\nI12: {}\nI21: {}\nR12: {}".format(S1f,S2f,I12f,I21f,R12f))

final_populations_2(Population_2)
# Out:
# S12: 0
# I1: 0
# I2: 0
# R1: 0
# R2: 0
# S1: 169
# S2: 17
# I12: 0
# I21: 0
# R12: 314

# %%
def Plot_Dynamics_21(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S12 = []; I1 = []; I2 = []; R1 = []; R2 = [];
    S1 = []; S2 = []; I12 = []; I21 = []; R12 = [];
    for t in range(T+1):
        S12t = 0; I1t = 0; I2t = 0; R1t = 0; R2t = 0;
        S1t = 0; S2t = 0; I12t = 0; I21t = 0; R12t = 0;
        for person in simulation:
            if person.status[t] == 'S12':
                S12t += 1
            elif person.status[t] == 'I1':
                I1t += 1
            elif person.status[t] == 'I2':
                I2t += 1
            elif person.status[t] == 'R1':
                R1t += 1
            elif person.status[t] == 'R2':
                R2t += 1
            elif person.status[t] == 'S1':
                S1t += 1
            elif person.status[t] == 'S2':
                S2t += 1
            elif person.status[t] == 'I12':
                I12t += 1
            elif person.status[t] == 'I21':
                I21t += 1
            else:
                R12t += 1
        
        S12.append(S12t)
        I1.append(I1t)
        I2.append(I2t)
        R1.append(R1t)
        R2.append(R2t)
        S1.append(S1t)
        S2.append(S2t)
        I12.append(I12t)
        I21.append(I21t)
        R12.append(R12t)

    plt.plot(range(T+1), S12, label = 'S12')
    plt.plot(range(T+1), I1, label = 'I1')
    plt.plot(range(T+1), I2, label = 'I2')
    plt.plot(range(T+1), R1, label = 'R1')
    plt.plot(range(T+1), R2, label = 'R2')
    plt.plot(range(T+1), S1, label = 'S1')
    plt.plot(range(T+1), S2, label = 'S2')
    plt.plot(range(T+1), I12, label = 'I12')
    plt.plot(range(T+1), I21, label = 'I21')
    plt.plot(range(T+1), R12, label = 'R12')
    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()
    
Plot_Dynamics_21(Population_2, T)

# %%
def Plot_Dynamics_22(simulation, T):
    """Plots the evolution of the populations of susceptible,
    infected and removed individuals over time for a simulation.
        
    Parameters
    ----------
    simulation : list
        List of Persona objects obtained from the function Simulacion_Contagios. 

    T : int
        Number of days in the simulation
    """
        
    S = []; I = []; R = [];
    for t in range(T+1):
        St = 0; It = 0; Rt = 0
        for person in simulation:
            if person.status[t] == 'S12':
                St += 1
            elif person.status[t] == 'I1':
                It += 1
            elif person.status[t] == 'I2':
                It += 1
            elif person.status[t] == 'R1':
                Rt += 1
            elif person.status[t] == 'R2':
                Rt += 1
            elif person.status[t] == 'S1':
                St += 1
            elif person.status[t] == 'S2':
                St += 1
            elif person.status[t] == 'I12':
                It += 1
            elif person.status[t] == 'I21':
                It += 1
            else:
                Rt += 1
        
        S.append(St)
        I.append(It)
        R.append(Rt)


    plt.plot(range(T+1), S, "b-",label = 'S')
    plt.plot(range(T+1), I, "r-",label = 'I')
    plt.plot(range(T+1), R, "k-",label = 'R')

    plt.legend()
    plt.xlabel('Time (days)')
    plt.ylabel('Population Size')
    plt.title('')
    plt.show()
    
Plot_Dynamics_22(Population_2, T)
